# %% [markdown]
# # Miniproject 1: Image Classification
#
# ## Introduction
#
# ### Description
#
# One of the deepest traditions in learning about deep learning is to first [tackle the exciting problem of MNIST classification](http://deeplearning.net/tutorial/logreg.html). [The MNIST database](https://en.wikipedia.org/wiki/MNIST_database) (Modified National Institute of Standards and Technology database) is a large database of handwritten digits that was [recently extended](https://arxiv.org/abs/1702.05373). We break with this tradition (just a little bit) and tackle first the related problem of classifying cropped, downsampled and grayscaled images of house numbers in the [The Street View House Numbers (SVHN) Dataset](http://ufldl.stanford.edu/housenumbers/).
#
#
# ### Prerequisites
#
# - You should have a running installation of [tensorflow](https://www.tensorflow.org/install/) and [keras](https://keras.io/).
# - You should know the concepts "multilayer perceptron", "stochastic gradient descent with minibatches", "training and validation data", "overfitting" and "early stopping".
#
# ### What you will learn
#
# - You will learn how to define feedforward neural networks in keras and fit them to data.
# - You will be guided through a prototyping procedure for the application of deep learning to a specific domain.
# - You will get in contact with concepts discussed later in the lecture, like "regularization", "batch normalization" and "convolutional networks".
# - You will gain some experience on the influence of network architecture, optimizer and regularization choices on the goodness of fit.
# - You will learn to be more patient :) Some fits may take your computer quite a bit of time; run them over night.
#
# ### Evaluation criteria
#
# The evaluation is (mostly) based on the figures you submit and your answer sentences.
# We will only do random tests of your code and not re-run the full notebook.
#
# ### Your names
#
# Before you start, please enter your full name(s) in the field below; they are used to load the data. The variable student2 may remain empty, if you work alone.

# %%
student1 = "Nicolas Lesimple"
student2 = "Nakka Krishna"

# %% [markdown]
# ## Some helper functions
#
# For your convenience we provide here some functions to preprocess the data and plot the results later. Simply run the following cells with `Shift-Enter`.
#
# ### Dependencies and constants

# %%
import numpy as np
import time
import matplotlib.pyplot as plt
import scipy.io

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Activation, Input
from keras.optimizers import SGD, Adam
from keras.layers.normalization import BatchNormalization
from keras.models import Model
from keras import regularizers



# you may experiment with different subsets, 
# but make sure in the submission 
# it is generated with the correct random seed for all exercises.
#np.random.seed(hash(student1 + student2) % 2**32)
np.random.seed(237699 + 279617)
subset_of_classes = np.random.choice(range(10), 5, replace = False)
print("Subset of classes selected: {}".format(', '.join([str(subset_of_classes[i]) for i in range(5)])))
# Out:
# /home/nakka/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Subset of classes selected: 1, 0, 5, 6, 3

# %% [markdown]
# ### Plotting

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
def plot_some_samples(x, y = [], yhat = [], select_from = [], 
                      ncols = 6, nrows = 4, xdim = 16, ydim = 16,
                      label_mapping = range(10)):
    """plot some input vectors as grayscale images (optionally together with their assigned or predicted labels).
    
    x is an NxD - dimensional array, where D is the length of an input vector and N is the number of samples.
    Out of the N samples, ncols x nrows indices are randomly selected from the list select_from (if it is empty, select_from becomes range(N)).
    
    Keyword arguments:
    y             -- corresponding labels to plot in green below each image.
    yhat          -- corresponding predicted labels to plot in red below each image.
    select_from   -- list of indices from which to select the images.
    ncols, nrows  -- number of columns and rows to plot.
    xdim, ydim    -- number of pixels of the images in x- and y-direction.
    label_mapping -- map labels to digits.
    
    """
    fig, ax = plt.subplots(nrows, ncols)
    if len(select_from) == 0:
        select_from = range(x.shape[0])
    indices = np.random.choice(select_from, size = min(ncols * nrows, len(select_from)), replace = False)
    for i, ind in enumerate(indices):
        thisax = ax[i//ncols,i%ncols]
        thisax.matshow(x[ind].reshape(xdim, ydim), cmap='gray')
        thisax.set_axis_off()
        if len(y) != 0:
            j = y[ind] if type(y[ind]) != np.ndarray else y[ind].argmax()
            thisax.text(0, 0, (label_mapping[j]+1)%10, color='green', 
                                                       verticalalignment='top',
                                                       transform=thisax.transAxes)
        if len(yhat) != 0:
            k = yhat[ind] if type(yhat[ind]) != np.ndarray else yhat[ind].argmax()
            thisax.text(1, 0, (label_mapping[k]+1)%10, color='red',
                                             verticalalignment='top',
                                             horizontalalignment='right',
                                             transform=thisax.transAxes)
    return fig

def prepare_standardplot(title, xlabel):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.suptitle(title)
    ax1.set_ylabel('categorical cross entropy')
    ax1.set_xlabel(xlabel)
    ax1.set_yscale('log')
    ax2.set_ylabel('accuracy [% correct]')
    ax2.set_xlabel(xlabel)
    return fig, ax1, ax2

def finalize_standardplot(fig, ax1, ax2):
    ax1handles, ax1labels = ax1.get_legend_handles_labels()
    if len(ax1labels) > 0:
        ax1.legend(ax1handles, ax1labels)
    ax2handles, ax2labels = ax2.get_legend_handles_labels()
    if len(ax2labels) > 0:
        ax2.legend(ax2handles, ax2labels)
    fig.tight_layout()
    plt.subplots_adjust(top=0.9)

def plot_history(history, title):
    fig, ax1, ax2 = prepare_standardplot(title, 'epoch')
    ax1.plot(history.history['loss'], label = "training")
    ax1.plot(history.history['val_loss'], label = "validation")
    ax2.plot(history.history['acc'], label = "training")
    ax2.plot(history.history['val_acc'], label = "validation")
    finalize_standardplot(fig, ax1, ax2)
    return fig

# %% [markdown]
# ### Loading and preprocessing the data
#
# The data consists of RGB color images with 32x32 pixels, loaded into an array of dimension 32x32x3x(number of images). We convert them to grayscale (using [this method](https://en.wikipedia.org/wiki/SRGB#The_reverse_transformation)) and we downsample them to images of 16x16 pixels by averaging over patches of 2x2 pixels.
#
# With these preprocessing steps we obviously remove some information that could be helpful in classifying the images. But, since the processed data is much lower dimensional, the fitting procedures converge faster. This is an advantage in situations like here (or generally when prototyping), were we want to try many different things without having to wait too long for computations to finish. After having gained some experience, one may want to go back to work on the 32x32 RGB images.

# %%
# convert RGB images x to grayscale using the formula for Y_linear in https://en.wikipedia.org/wiki/Grayscale#Colorimetric_(perceptual_luminance-preserving)_conversion_to_grayscale
def grayscale(x):
    x = x.astype('float32')/255
    x = np.piecewise(x, [x <= 0.04045, x > 0.04045], 
                        [lambda x: x/12.92, lambda x: ((x + .055)/1.055)**2.4])
    return .2126 * x[:,:,0,:] + .7152 * x[:,:,1,:]  + .07152 * x[:,:,2,:]

def downsample(x):
    return sum([x[i::2,j::2,:] for i in range(2) for j in range(2)])/4

def preprocess(data):
    gray = grayscale(data['X'])
    downsampled = downsample(gray)
    return (downsampled.reshape(16*16, gray.shape[2]).transpose(),
            data['y'].flatten() - 1)


data_train = scipy.io.loadmat('housenumbers/train_32x32.mat')
data_test = scipy.io.loadmat('housenumbers/test_32x32.mat')

x_train_all, y_train_all = preprocess(data_train)
x_test_all, y_test_all = preprocess(data_test)
print("FullTrain data size: {}\n Full Test data size: {}".format(x_train_all.shape,x_test_all.shape))
# Out:
# FullTrain data size: (73257, 256)
#  Full Test data size: (26032, 256)

# %% [markdown]
# ### Selecting a subset of classes
#
# We furter reduce the size of the dataset (and thus reduce computation time) by selecting only the 5 (out of 10 digits) in subset_of_classes.

# %%
def extract_classes(x, y, classes):
    indices = []
    labels = []
    count = 0
    for c in classes:
        tmp = np.where(y == c)[0]
        indices.extend(tmp)
        labels.extend(np.ones(len(tmp), dtype='uint8') * count)
        count += 1
    return x[indices], labels

x_train, y_train = extract_classes(x_train_all, y_train_all, subset_of_classes)
x_test, y_test = extract_classes(x_test_all, y_test_all, subset_of_classes)

print("Sampled Train data size: {}\nSampled Test data size: {}".format(x_train.shape,x_test.shape))
# Out:
# Sampled Train data size: (43226, 256)
# Sampled Test data size: (15767, 256)

# %% [markdown]
# Let us plot some examples now. The green digit at the bottom left of each image indicates the corresponding label in y_test.
# For further usage of the function plot_some_samples, please have a look at its definition in the plotting section.

# %%
plot_some_samples(x_test, y_test, label_mapping = subset_of_classes);

# %% [markdown]
# To prepare for fitting we transform the labels to one hot coding, i.e. for 5 classes, label 2 becomes the vector [0, 0, 1, 0, 0] (python uses 0-indexing).

# %%
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

# %% [markdown]
# ## Exercise 1: No hidden layer
#
# ### Description
#
# Define and fit a model without a hidden layer.
#
# 1. Use the softmax activation for the output layer.
# 2. Use the categorical_crossentropy loss.
# 3. Add the accuracy metric to the metrics.
# 4. Choose stochastic gradient descent for the optimizer.
# 5. Choose a minibatch size of 128.
# 6. Fit for as many epochs as needed to see no further decrease in the validation loss.
# 7. Plot the output of the fitting procedure (a history object) using the function plot_history defined above.
# 8. Determine the indices of all test images that are misclassified by the fitted model and plot some of them using the function
#    `plot_some_samples(x_test, y_test, yhat_test, error_indices, label_mapping = subset_of_classes)`
#
#
# Hints:
# * Read the keras docs, in particular [Getting started with the Keras Sequential model](https://keras.io/getting-started/sequential-model-guide/).
# * Have a look at the keras [examples](https://github.com/keras-team/keras/tree/master/examples), e.g. [mnist_mlp](https://github.com/keras-team/keras/blob/master/examples/mnist_mlp.py).

# %% [markdown]
# ### Solution

# %%
### Model ###
model = Sequential()
model.add(Dense(5, activation='softmax', input_shape=x_train.shape[1:]))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=128,
                    epochs=450,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
plot_history(history, 'Learning Curve and Accuracy')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_429 (Dense)            (None, 5)                 1285
# =================================================================
# Total params: 1,285
# Trainable params: 1,285
# Non-trainable params: 0
# _________________________________________________________________
# Train on 35179 samples, validate on 12670 samples
# Epoch 1/450
# 35179/35179 [==============================] - 0s - loss: 1.5941 - acc: 0.2833 - val_loss: 1.5712 - val_acc: 0.3203
# Epoch 2/450
# 35179/35179 [==============================] - 0s - loss: 1.5764 - acc: 0.3014 - val_loss: 1.5647 - val_acc: 0.3242
# Epoch 3/450
# 35179/35179 [==============================] - 0s - loss: 1.5710 - acc: 0.3031 - val_loss: 1.5605 - val_acc: 0.3300
# Epoch 4/450
# 35179/35179 [==============================] - 0s - loss: 1.5668 - acc: 0.3052 - val_loss: 1.5554 - val_acc: 0.3308
# Epoch 5/450
# 35179/35179 [==============================] - 0s - loss: 1.5632 - acc: 0.3068 - val_loss: 1.5522 - val_acc: 0.3335
# Epoch 6/450
# 35179/35179 [==============================] - 0s - loss: 1.5599 - acc: 0.3089 - val_loss: 1.5495 - val_acc: 0.3386
# Epoch 7/450
# 35179/35179 [==============================] - 0s - loss: 1.5572 - acc: 0.3104 - val_loss: 1.5485 - val_acc: 0.3470
# Epoch 8/450
# 35179/35179 [==============================] - 0s - loss: 1.5548 - acc: 0.3139 - val_loss: 1.5453 - val_acc: 0.3444
# Epoch 9/450
# 35179/35179 [==============================] - 0s - loss: 1.5525 - acc: 0.3166 - val_loss: 1.5437 - val_acc: 0.3460
# Epoch 10/450
# 35179/35179 [==============================] - 0s - loss: 1.5506 - acc: 0.3188 - val_loss: 1.5427 - val_acc: 0.3519
# Epoch 11/450
# 35179/35179 [==============================] - 0s - loss: 1.5488 - acc: 0.3200 - val_loss: 1.5417 - val_acc: 0.3555
# Epoch 12/450
# 35179/35179 [==============================] - 0s - loss: 1.5470 - acc: 0.3225 - val_loss: 1.5408 - val_acc: 0.3571
# Epoch 13/450
# 35179/35179 [==============================] - 0s - loss: 1.5454 - acc: 0.3244 - val_loss: 1.5411 - val_acc: 0.3645
# Epoch 14/450
# 35179/35179 [==============================] - 0s - loss: 1.5440 - acc: 0.3267 - val_loss: 1.5386 - val_acc: 0.3565
# Epoch 15/450
# 35179/35179 [==============================] - 0s - loss: 1.5427 - acc: 0.3272 - val_loss: 1.5386 - val_acc: 0.3658
# Epoch 16/450
# 35179/35179 [==============================] - 0s - loss: 1.5413 - acc: 0.3291 - val_loss: 1.5389 - val_acc: 0.3699
# Epoch 17/450
# 35179/35179 [==============================] - 0s - loss: 1.5402 - acc: 0.3322 - val_loss: 1.5369 - val_acc: 0.3616
# Epoch 18/450
# 35179/35179 [==============================] - 0s - loss: 1.5389 - acc: 0.3323 - val_loss: 1.5365 - val_acc: 0.3625
# Epoch 19/450
# 35179/35179 [==============================] - 0s - loss: 1.5379 - acc: 0.3339 - val_loss: 1.5355 - val_acc: 0.3568
# Epoch 20/450
# 35179/35179 [==============================] - 0s - loss: 1.5368 - acc: 0.3349 - val_loss: 1.5353 - val_acc: 0.3581
# Epoch 21/450
# 35179/35179 [==============================] - 0s - loss: 1.5358 - acc: 0.3359 - val_loss: 1.5368 - val_acc: 0.3736
# Epoch 22/450
# 35179/35179 [==============================] - 0s - loss: 1.5348 - acc: 0.3370 - val_loss: 1.5355 - val_acc: 0.3701
# Epoch 23/450
# 35179/35179 [==============================] - 0s - loss: 1.5338 - acc: 0.3385 - val_loss: 1.5356 - val_acc: 0.3719
# Epoch 24/450
# 35179/35179 [==============================] - 0s - loss: 1.5331 - acc: 0.3399 - val_loss: 1.5346 - val_acc: 0.3679
# Epoch 25/450
# 35179/35179 [==============================] - 0s - loss: 1.5321 - acc: 0.3407 - val_loss: 1.5345 - val_acc: 0.3631
# Epoch 26/450
# 35179/35179 [==============================] - 0s - loss: 1.5314 - acc: 0.3423 - val_loss: 1.5345 - val_acc: 0.3708
# Epoch 27/450
# 35179/35179 [==============================] - 0s - loss: 1.5305 - acc: 0.3426 - val_loss: 1.5348 - val_acc: 0.3697
# Epoch 28/450
# 35179/35179 [==============================] - 0s - loss: 1.5298 - acc: 0.3434 - val_loss: 1.5339 - val_acc: 0.3675
# Epoch 29/450
# 35179/35179 [==============================] - 0s - loss: 1.5291 - acc: 0.3440 - val_loss: 1.5340 - val_acc: 0.3691
# Epoch 30/450
# 35179/35179 [==============================] - 0s - loss: 1.5284 - acc: 0.3443 - val_loss: 1.5340 - val_acc: 0.3698
# Epoch 31/450
# 35179/35179 [==============================] - 0s - loss: 1.5277 - acc: 0.3451 - val_loss: 1.5343 - val_acc: 0.3717
# Epoch 32/450
# 35179/35179 [==============================] - 0s - loss: 1.5271 - acc: 0.3456 - val_loss: 1.5337 - val_acc: 0.3708
# Epoch 33/450
# 35179/35179 [==============================] - 0s - loss: 1.5265 - acc: 0.3458 - val_loss: 1.5340 - val_acc: 0.3728
# Epoch 34/450
# 35179/35179 [==============================] - 0s - loss: 1.5258 - acc: 0.3466 - val_loss: 1.5341 - val_acc: 0.3747
# Epoch 35/450
# 35179/35179 [==============================] - 0s - loss: 1.5252 - acc: 0.3481 - val_loss: 1.5340 - val_acc: 0.3714
# Epoch 36/450
# 35179/35179 [==============================] - 0s - loss: 1.5247 - acc: 0.3472 - val_loss: 1.5335 - val_acc: 0.3710
# Epoch 37/450
# 35179/35179 [==============================] - 0s - loss: 1.5241 - acc: 0.3478 - val_loss: 1.5353 - val_acc: 0.37410.34
# Epoch 38/450
# 35179/35179 [==============================] - 0s - loss: 1.5236 - acc: 0.3495 - val_loss: 1.5341 - val_acc: 0.3749
# Epoch 39/450
# 35179/35179 [==============================] - 0s - loss: 1.5229 - acc: 0.3510 - val_loss: 1.5335 - val_acc: 0.3689
# Epoch 40/450
# 35179/35179 [==============================] - 0s - loss: 1.5226 - acc: 0.3490 - val_loss: 1.5350 - val_acc: 0.3746
# Epoch 41/450
# 35179/35179 [==============================] - 0s - loss: 1.5220 - acc: 0.3517 - val_loss: 1.5344 - val_acc: 0.3754
# Epoch 42/450
# 35179/35179 [==============================] - 0s - loss: 1.5216 - acc: 0.3501 - val_loss: 1.5349 - val_acc: 0.3752
# Epoch 43/450
# 35179/35179 [==============================] - 0s - loss: 1.5212 - acc: 0.3521 - val_loss: 1.5340 - val_acc: 0.3731
# Epoch 44/450
# 35179/35179 [==============================] - 0s - loss: 1.5206 - acc: 0.3524 - val_loss: 1.5344 - val_acc: 0.3753
# Epoch 45/450
# 35179/35179 [==============================] - 0s - loss: 1.5202 - acc: 0.3520 - val_loss: 1.5350 - val_acc: 0.3758
# Epoch 46/450
# 35179/35179 [==============================] - 0s - loss: 1.5198 - acc: 0.3537 - val_loss: 1.5343 - val_acc: 0.3733
# Epoch 47/450
# 35179/35179 [==============================] - 0s - loss: 1.5193 - acc: 0.3529 - val_loss: 1.5340 - val_acc: 0.3732
# Epoch 48/450
# 35179/35179 [==============================] - 0s - loss: 1.5190 - acc: 0.3534 - val_loss: 1.5346 - val_acc: 0.3726
# Epoch 49/450
# 35179/35179 [==============================] - 0s - loss: 1.5186 - acc: 0.3538 - val_loss: 1.5350 - val_acc: 0.3758
# Epoch 50/450
# 35179/35179 [==============================] - 0s - loss: 1.5182 - acc: 0.3538 - val_loss: 1.5353 - val_acc: 0.3769
# Epoch 51/450
# 35179/35179 [==============================] - 0s - loss: 1.5178 - acc: 0.3552 - val_loss: 1.5347 - val_acc: 0.3736
# Epoch 52/450
# 35179/35179 [==============================] - 0s - loss: 1.5174 - acc: 0.3547 - val_loss: 1.5342 - val_acc: 0.3727
# Epoch 53/450
# 35179/35179 [==============================] - 0s - loss: 1.5171 - acc: 0.3550 - val_loss: 1.5347 - val_acc: 0.3741
# Epoch 54/450
# 35179/35179 [==============================] - 0s - loss: 1.5167 - acc: 0.3556 - val_loss: 1.5351 - val_acc: 0.3763
# Epoch 55/450
# 35179/35179 [==============================] - 0s - loss: 1.5164 - acc: 0.3561 - val_loss: 1.5346 - val_acc: 0.3726
# Epoch 56/450
# 35179/35179 [==============================] - 0s - loss: 1.5160 - acc: 0.3549 - val_loss: 1.5352 - val_acc: 0.3762
# Epoch 57/450
# 35179/35179 [==============================] - 0s - loss: 1.5157 - acc: 0.3560 - val_loss: 1.5351 - val_acc: 0.3754
# Epoch 58/450
# 35179/35179 [==============================] - 0s - loss: 1.5154 - acc: 0.3563 - val_loss: 1.5347 - val_acc: 0.3736
# Epoch 59/450
# 35179/35179 [==============================] - 0s - loss: 1.5151 - acc: 0.3570 - val_loss: 1.5346 - val_acc: 0.3720
# Epoch 60/450
# 35179/35179 [==============================] - 0s - loss: 1.5148 - acc: 0.3566 - val_loss: 1.5361 - val_acc: 0.3763
# Epoch 61/450
# 35179/35179 [==============================] - 0s - loss: 1.5144 - acc: 0.3588 - val_loss: 1.5352 - val_acc: 0.3752
# Epoch 62/450
# 35179/35179 [==============================] - 0s - loss: 1.5142 - acc: 0.3569 - val_loss: 1.5361 - val_acc: 0.3774
# Epoch 63/450
# 35179/35179 [==============================] - 0s - loss: 1.5138 - acc: 0.3586 - val_loss: 1.5353 - val_acc: 0.3728
# Epoch 64/450
# 35179/35179 [==============================] - 0s - loss: 1.5136 - acc: 0.3583 - val_loss: 1.5361 - val_acc: 0.3755
# Epoch 65/450
# 35179/35179 [==============================] - 0s - loss: 1.5133 - acc: 0.3581 - val_loss: 1.5366 - val_acc: 0.3776
# Epoch 66/450
# 35179/35179 [==============================] - 0s - loss: 1.5130 - acc: 0.3590 - val_loss: 1.5355 - val_acc: 0.3750
# Epoch 67/450
# 35179/35179 [==============================] - 0s - loss: 1.5128 - acc: 0.3576 - val_loss: 1.5367 - val_acc: 0.3779
# Epoch 68/450
# 35179/35179 [==============================] - 0s - loss: 1.5125 - acc: 0.3596 - val_loss: 1.5363 - val_acc: 0.3766
# Epoch 69/450
# 35179/35179 [==============================] - 0s - loss: 1.5123 - acc: 0.3587 - val_loss: 1.5373 - val_acc: 0.3773
# Epoch 70/450
# 35179/35179 [==============================] - 0s - loss: 1.5121 - acc: 0.3594 - val_loss: 1.5365 - val_acc: 0.3775
# Epoch 71/450
# 35179/35179 [==============================] - 0s - loss: 1.5117 - acc: 0.3602 - val_loss: 1.5358 - val_acc: 0.3736
# Epoch 72/450
# 35179/35179 [==============================] - 0s - loss: 1.5116 - acc: 0.3591 - val_loss: 1.5371 - val_acc: 0.3770
# Epoch 73/450
# 35179/35179 [==============================] - 0s - loss: 1.5113 - acc: 0.3597 - val_loss: 1.5372 - val_acc: 0.3773
# Epoch 74/450
# 35179/35179 [==============================] - 0s - loss: 1.5110 - acc: 0.3603 - val_loss: 1.5368 - val_acc: 0.3760
# Epoch 75/450
# 35179/35179 [==============================] - 0s - loss: 1.5109 - acc: 0.3599 - val_loss: 1.5373 - val_acc: 0.3768
# Epoch 76/450
# 35179/35179 [==============================] - 0s - loss: 1.5106 - acc: 0.3605 - val_loss: 1.5364 - val_acc: 0.3745
# Epoch 77/450
# 35179/35179 [==============================] - 0s - loss: 1.5104 - acc: 0.3595 - val_loss: 1.5371 - val_acc: 0.3762
# Epoch 78/450
# 35179/35179 [==============================] - 0s - loss: 1.5102 - acc: 0.3604 - val_loss: 1.5371 - val_acc: 0.3765
# Epoch 79/450
# 35179/35179 [==============================] - 0s - loss: 1.5099 - acc: 0.3613 - val_loss: 1.5365 - val_acc: 0.3734
# Epoch 80/450
# 35179/35179 [==============================] - 0s - loss: 1.5098 - acc: 0.3597 - val_loss: 1.5374 - val_acc: 0.3768
# Epoch 81/450
# 35179/35179 [==============================] - 0s - loss: 1.5095 - acc: 0.3610 - val_loss: 1.5393 - val_acc: 0.3766
# Epoch 82/450
# 35179/35179 [==============================] - 0s - loss: 1.5093 - acc: 0.3615 - val_loss: 1.5378 - val_acc: 0.3759
# Epoch 83/450
# 35179/35179 [==============================] - 0s - loss: 1.5092 - acc: 0.3613 - val_loss: 1.5382 - val_acc: 0.3748
# Epoch 84/450
# 35179/35179 [==============================] - 0s - loss: 1.5090 - acc: 0.3610 - val_loss: 1.5396 - val_acc: 0.3777
# Epoch 85/450
# 35179/35179 [==============================] - 0s - loss: 1.5088 - acc: 0.3617 - val_loss: 1.5389 - val_acc: 0.3765
# Epoch 86/450
# 35179/35179 [==============================] - 0s - loss: 1.5085 - acc: 0.3615 - val_loss: 1.5381 - val_acc: 0.3763
# Epoch 87/450
# 35179/35179 [==============================] - 0s - loss: 1.5084 - acc: 0.3614 - val_loss: 1.5376 - val_acc: 0.3755
# Epoch 88/450
# 35179/35179 [==============================] - 0s - loss: 1.5083 - acc: 0.3612 - val_loss: 1.5380 - val_acc: 0.3765
# Epoch 89/450
# 35179/35179 [==============================] - 0s - loss: 1.5080 - acc: 0.3625 - val_loss: 1.5381 - val_acc: 0.3764
# Epoch 90/450
# 35179/35179 [==============================] - 0s - loss: 1.5079 - acc: 0.3622 - val_loss: 1.5383 - val_acc: 0.3768
# Epoch 91/450
# 35179/35179 [==============================] - 0s - loss: 1.5078 - acc: 0.3627 - val_loss: 1.5390 - val_acc: 0.3763
# Epoch 92/450
# 35179/35179 [==============================] - 0s - loss: 1.5075 - acc: 0.3625 - val_loss: 1.5381 - val_acc: 0.3767
# Epoch 93/450
# 35179/35179 [==============================] - 0s - loss: 1.5074 - acc: 0.3628 - val_loss: 1.5386 - val_acc: 0.3763
# Epoch 94/450
# 35179/35179 [==============================] - 0s - loss: 1.5072 - acc: 0.3642 - val_loss: 1.5383 - val_acc: 0.3772
# Epoch 95/450
# 35179/35179 [==============================] - 0s - loss: 1.5070 - acc: 0.3619 - val_loss: 1.5398 - val_acc: 0.3762
# Epoch 96/450
# 35179/35179 [==============================] - 0s - loss: 1.5068 - acc: 0.3625 - val_loss: 1.5399 - val_acc: 0.3775
# Epoch 97/450
# 35179/35179 [==============================] - 0s - loss: 1.5067 - acc: 0.3638 - val_loss: 1.5399 - val_acc: 0.3770
# Epoch 98/450
# 35179/35179 [==============================] - 0s - loss: 1.5065 - acc: 0.3633 - val_loss: 1.5398 - val_acc: 0.3777
# Epoch 99/450
# 35179/35179 [==============================] - 0s - loss: 1.5064 - acc: 0.3629 - val_loss: 1.5407 - val_acc: 0.3765
# Epoch 100/450
# 35179/35179 [==============================] - 0s - loss: 1.5063 - acc: 0.3636 - val_loss: 1.5399 - val_acc: 0.3763
# Epoch 101/450
# 35179/35179 [==============================] - 0s - loss: 1.5061 - acc: 0.3639 - val_loss: 1.5401 - val_acc: 0.3773
# Epoch 102/450
# 35179/35179 [==============================] - 0s - loss: 1.5060 - acc: 0.3644 - val_loss: 1.5403 - val_acc: 0.3766
# Epoch 103/450
# 35179/35179 [==============================] - 0s - loss: 1.5058 - acc: 0.3642 - val_loss: 1.5400 - val_acc: 0.3762
# Epoch 104/450
# 35179/35179 [==============================] - 0s - loss: 1.5057 - acc: 0.3643 - val_loss: 1.5409 - val_acc: 0.3772
# Epoch 105/450
# 35179/35179 [==============================] - 0s - loss: 1.5055 - acc: 0.3633 - val_loss: 1.5404 - val_acc: 0.3769
# Epoch 106/450
# 35179/35179 [==============================] - 0s - loss: 1.5054 - acc: 0.3649 - val_loss: 1.5398 - val_acc: 0.3774
# Epoch 107/450
# 35179/35179 [==============================] - 0s - loss: 1.5052 - acc: 0.3641 - val_loss: 1.5399 - val_acc: 0.3761
# Epoch 108/450
# 35179/35179 [==============================] - 0s - loss: 1.5052 - acc: 0.3649 - val_loss: 1.5406 - val_acc: 0.3757
# Epoch 109/450
# 35179/35179 [==============================] - 0s - loss: 1.5049 - acc: 0.3648 - val_loss: 1.5412 - val_acc: 0.3766
# Epoch 110/450
# 35179/35179 [==============================] - 0s - loss: 1.5049 - acc: 0.3648 - val_loss: 1.5402 - val_acc: 0.3763
# Epoch 111/450
# 35179/35179 [==============================] - 0s - loss: 1.5048 - acc: 0.3650 - val_loss: 1.5407 - val_acc: 0.3774
# Epoch 112/450
# 35179/35179 [==============================] - 0s - loss: 1.5046 - acc: 0.3662 - val_loss: 1.5400 - val_acc: 0.3775
# Epoch 113/450
# 35179/35179 [==============================] - 0s - loss: 1.5045 - acc: 0.3659 - val_loss: 1.5401 - val_acc: 0.3760
# Epoch 114/450
# 35179/35179 [==============================] - 0s - loss: 1.5044 - acc: 0.3662 - val_loss: 1.5401 - val_acc: 0.3755
# Epoch 115/450
# 35179/35179 [==============================] - 0s - loss: 1.5042 - acc: 0.3651 - val_loss: 1.5413 - val_acc: 0.3769
# Epoch 116/450
# 35179/35179 [==============================] - 0s - loss: 1.5041 - acc: 0.3654 - val_loss: 1.5417 - val_acc: 0.3760
# Epoch 117/450
# 35179/35179 [==============================] - 0s - loss: 1.5040 - acc: 0.3657 - val_loss: 1.5411 - val_acc: 0.3759
# Epoch 118/450
# 35179/35179 [==============================] - 0s - loss: 1.5039 - acc: 0.3668 - val_loss: 1.5418 - val_acc: 0.3761
# Epoch 119/450
# 35179/35179 [==============================] - 0s - loss: 1.5038 - acc: 0.3660 - val_loss: 1.5418 - val_acc: 0.3770
# Epoch 120/450
# 35179/35179 [==============================] - 0s - loss: 1.5036 - acc: 0.3670 - val_loss: 1.5416 - val_acc: 0.3755
# Epoch 121/450
# 35179/35179 [==============================] - 0s - loss: 1.5036 - acc: 0.3661 - val_loss: 1.5411 - val_acc: 0.3762
# Epoch 122/450
# 35179/35179 [==============================] - 0s - loss: 1.5034 - acc: 0.3650 - val_loss: 1.5422 - val_acc: 0.3764
# Epoch 123/450
# 35179/35179 [==============================] - 0s - loss: 1.5033 - acc: 0.3663 - val_loss: 1.5426 - val_acc: 0.3766
# Epoch 124/450
# 35179/35179 [==============================] - 0s - loss: 1.5032 - acc: 0.3671 - val_loss: 1.5414 - val_acc: 0.3737
# Epoch 125/450
# 35179/35179 [==============================] - 0s - loss: 1.5031 - acc: 0.3671 - val_loss: 1.5410 - val_acc: 0.3765
# Epoch 126/450
# 35179/35179 [==============================] - 0s - loss: 1.5029 - acc: 0.3670 - val_loss: 1.5415 - val_acc: 0.3761
# Epoch 127/450
# 35179/35179 [==============================] - 0s - loss: 1.5029 - acc: 0.3662 - val_loss: 1.5427 - val_acc: 0.3772
# Epoch 128/450
# 35179/35179 [==============================] - 0s - loss: 1.5027 - acc: 0.3672 - val_loss: 1.5411 - val_acc: 0.3756
# Epoch 129/450
# 35179/35179 [==============================] - 0s - loss: 1.5026 - acc: 0.3669 - val_loss: 1.5422 - val_acc: 0.3766
# Epoch 130/450
# 35179/35179 [==============================] - 0s - loss: 1.5026 - acc: 0.3680 - val_loss: 1.5415 - val_acc: 0.3769
# Epoch 131/450
# 35179/35179 [==============================] - 0s - loss: 1.5024 - acc: 0.3672 - val_loss: 1.5432 - val_acc: 0.3770
# Epoch 132/450
# 35179/35179 [==============================] - 0s - loss: 1.5024 - acc: 0.3676 - val_loss: 1.5421 - val_acc: 0.3766
# Epoch 133/450
# 35179/35179 [==============================] - 0s - loss: 1.5023 - acc: 0.3672 - val_loss: 1.5424 - val_acc: 0.3770
# Epoch 134/450
# 35179/35179 [==============================] - 0s - loss: 1.5022 - acc: 0.3678 - val_loss: 1.5423 - val_acc: 0.3763
# Epoch 135/450
# 35179/35179 [==============================] - 0s - loss: 1.5020 - acc: 0.3681 - val_loss: 1.5425 - val_acc: 0.3758
# Epoch 136/450
# 35179/35179 [==============================] - 0s - loss: 1.5020 - acc: 0.3686 - val_loss: 1.5427 - val_acc: 0.3755
# Epoch 137/450
# 35179/35179 [==============================] - 0s - loss: 1.5018 - acc: 0.3679 - val_loss: 1.5431 - val_acc: 0.3761
# Epoch 138/450
# 35179/35179 [==============================] - 0s - loss: 1.5019 - acc: 0.3687 - val_loss: 1.5430 - val_acc: 0.3767
# Epoch 139/450
# 35179/35179 [==============================] - 0s - loss: 1.5017 - acc: 0.3681 - val_loss: 1.5434 - val_acc: 0.3762
# Epoch 140/450
# 35179/35179 [==============================] - 0s - loss: 1.5016 - acc: 0.3681 - val_loss: 1.5433 - val_acc: 0.3761
# Epoch 141/450
# 35179/35179 [==============================] - 0s - loss: 1.5015 - acc: 0.3686 - val_loss: 1.5430 - val_acc: 0.3777
# Epoch 142/450
# 35179/35179 [==============================] - 0s - loss: 1.5015 - acc: 0.3687 - val_loss: 1.5424 - val_acc: 0.3761
# Epoch 143/450
# 35179/35179 [==============================] - 0s - loss: 1.5014 - acc: 0.3694 - val_loss: 1.5425 - val_acc: 0.3760
# Epoch 144/450
# 35179/35179 [==============================] - 0s - loss: 1.5012 - acc: 0.3674 - val_loss: 1.5445 - val_acc: 0.3768
# Epoch 145/450
# 35179/35179 [==============================] - 0s - loss: 1.5011 - acc: 0.3692 - val_loss: 1.5425 - val_acc: 0.3764
# Epoch 146/450
# 35179/35179 [==============================] - 0s - loss: 1.5010 - acc: 0.3691 - val_loss: 1.5433 - val_acc: 0.3751
# Epoch 147/450
# 35179/35179 [==============================] - 0s - loss: 1.5009 - acc: 0.3687 - val_loss: 1.5429 - val_acc: 0.3771
# Epoch 148/450
# 35179/35179 [==============================] - 0s - loss: 1.5008 - acc: 0.3683 - val_loss: 1.5439 - val_acc: 0.3755
# Epoch 149/450
# 35179/35179 [==============================] - 0s - loss: 1.5008 - acc: 0.3698 - val_loss: 1.5431 - val_acc: 0.3775
# Epoch 150/450
# 35179/35179 [==============================] - 0s - loss: 1.5008 - acc: 0.3691 - val_loss: 1.5435 - val_acc: 0.3771
# Epoch 151/450
# 35179/35179 [==============================] - 0s - loss: 1.5005 - acc: 0.3689 - val_loss: 1.5454 - val_acc: 0.3773
# Epoch 152/450
# 35179/35179 [==============================] - 0s - loss: 1.5006 - acc: 0.3695 - val_loss: 1.5438 - val_acc: 0.3757
# Epoch 153/450
# 35179/35179 [==============================] - 0s - loss: 1.5004 - acc: 0.3696 - val_loss: 1.5444 - val_acc: 0.3774
# Epoch 154/450
# 35179/35179 [==============================] - 0s - loss: 1.5004 - acc: 0.3708 - val_loss: 1.5438 - val_acc: 0.3759
# Epoch 155/450
# 35179/35179 [==============================] - 0s - loss: 1.5004 - acc: 0.3701 - val_loss: 1.5433 - val_acc: 0.3768
# Epoch 156/450
# 35179/35179 [==============================] - 0s - loss: 1.5003 - acc: 0.3697 - val_loss: 1.5434 - val_acc: 0.3762
# Epoch 157/450
# 35179/35179 [==============================] - 0s - loss: 1.5002 - acc: 0.3698 - val_loss: 1.5448 - val_acc: 0.3756
# Epoch 158/450
# 35179/35179 [==============================] - 0s - loss: 1.5001 - acc: 0.3699 - val_loss: 1.5448 - val_acc: 0.3762
# Epoch 159/450
# 35179/35179 [==============================] - 0s - loss: 1.5000 - acc: 0.3706 - val_loss: 1.5455 - val_acc: 0.3785
# Epoch 160/450
# 35179/35179 [==============================] - 0s - loss: 1.4999 - acc: 0.3706 - val_loss: 1.5436 - val_acc: 0.3767
# Epoch 161/450
# 35179/35179 [==============================] - 0s - loss: 1.4997 - acc: 0.3701 - val_loss: 1.5441 - val_acc: 0.3773
# Epoch 162/450
# 35179/35179 [==============================] - 0s - loss: 1.4998 - acc: 0.3700 - val_loss: 1.5439 - val_acc: 0.3773
# Epoch 163/450
# 35179/35179 [==============================] - 0s - loss: 1.4998 - acc: 0.3696 - val_loss: 1.5444 - val_acc: 0.3770
# Epoch 164/450
# 35179/35179 [==============================] - 0s - loss: 1.4995 - acc: 0.3708 - val_loss: 1.5442 - val_acc: 0.3769
# Epoch 165/450
# 35179/35179 [==============================] - 0s - loss: 1.4995 - acc: 0.3694 - val_loss: 1.5451 - val_acc: 0.3764
# Epoch 166/450
# 35179/35179 [==============================] - 0s - loss: 1.4993 - acc: 0.3714 - val_loss: 1.5437 - val_acc: 0.3752
# Epoch 167/450
# 35179/35179 [==============================] - 0s - loss: 1.4993 - acc: 0.3697 - val_loss: 1.5457 - val_acc: 0.3776
# Epoch 168/450
# 35179/35179 [==============================] - 0s - loss: 1.4992 - acc: 0.3714 - val_loss: 1.5439 - val_acc: 0.3751
# Epoch 169/450
# 35179/35179 [==============================] - 0s - loss: 1.4993 - acc: 0.3698 - val_loss: 1.5452 - val_acc: 0.3768
# Epoch 170/450
# 35179/35179 [==============================] - 0s - loss: 1.4992 - acc: 0.3709 - val_loss: 1.5452 - val_acc: 0.3771
# Epoch 171/450
# 35179/35179 [==============================] - 0s - loss: 1.4991 - acc: 0.3707 - val_loss: 1.5450 - val_acc: 0.3771
# Epoch 172/450
# 35179/35179 [==============================] - 0s - loss: 1.4990 - acc: 0.3720 - val_loss: 1.5451 - val_acc: 0.3777
# Epoch 173/450
# 35179/35179 [==============================] - 0s - loss: 1.4991 - acc: 0.3708 - val_loss: 1.5444 - val_acc: 0.3769
# Epoch 174/450
# 35179/35179 [==============================] - 0s - loss: 1.4990 - acc: 0.3717 - val_loss: 1.5446 - val_acc: 0.3775
# Epoch 175/450
# 35179/35179 [==============================] - 0s - loss: 1.4989 - acc: 0.3714 - val_loss: 1.5447 - val_acc: 0.3762
# Epoch 176/450
# 35179/35179 [==============================] - 0s - loss: 1.4989 - acc: 0.3713 - val_loss: 1.5447 - val_acc: 0.3782
# Epoch 177/450
# 35179/35179 [==============================] - 0s - loss: 1.4987 - acc: 0.3703 - val_loss: 1.5458 - val_acc: 0.3774
# Epoch 178/450
# 35179/35179 [==============================] - 0s - loss: 1.4986 - acc: 0.3706 - val_loss: 1.5461 - val_acc: 0.3777
# Epoch 179/450
# 35179/35179 [==============================] - 0s - loss: 1.4985 - acc: 0.3713 - val_loss: 1.5450 - val_acc: 0.3762
# Epoch 180/450
# 35179/35179 [==============================] - 0s - loss: 1.4985 - acc: 0.3718 - val_loss: 1.5453 - val_acc: 0.3756
# Epoch 181/450
# 35179/35179 [==============================] - 0s - loss: 1.4985 - acc: 0.3714 - val_loss: 1.5450 - val_acc: 0.3788
# Epoch 182/450
# 35179/35179 [==============================] - 0s - loss: 1.4984 - acc: 0.3714 - val_loss: 1.5451 - val_acc: 0.3777
# Epoch 183/450
# 35179/35179 [==============================] - 0s - loss: 1.4984 - acc: 0.3715 - val_loss: 1.5454 - val_acc: 0.3782
# Epoch 184/450
# 35179/35179 [==============================] - 0s - loss: 1.4983 - acc: 0.3707 - val_loss: 1.5449 - val_acc: 0.3768
# Epoch 185/450
# 35179/35179 [==============================] - 0s - loss: 1.4982 - acc: 0.3719 - val_loss: 1.5474 - val_acc: 0.3762
# Epoch 186/450
# 35179/35179 [==============================] - 0s - loss: 1.4982 - acc: 0.3717 - val_loss: 1.5457 - val_acc: 0.3776
# Epoch 187/450
# 35179/35179 [==============================] - 0s - loss: 1.4981 - acc: 0.3724 - val_loss: 1.5461 - val_acc: 0.3777
# Epoch 188/450
# 35179/35179 [==============================] - 0s - loss: 1.4980 - acc: 0.3725 - val_loss: 1.5453 - val_acc: 0.3772
# Epoch 189/450
# 35179/35179 [==============================] - 0s - loss: 1.4980 - acc: 0.3726 - val_loss: 1.5454 - val_acc: 0.3780
# Epoch 190/450
# 35179/35179 [==============================] - 0s - loss: 1.4980 - acc: 0.3713 - val_loss: 1.5451 - val_acc: 0.3773
# Epoch 191/450
# 35179/35179 [==============================] - 0s - loss: 1.4980 - acc: 0.3714 - val_loss: 1.5458 - val_acc: 0.3787
# Epoch 192/450
# 35179/35179 [==============================] - 0s - loss: 1.4978 - acc: 0.3726 - val_loss: 1.5452 - val_acc: 0.3759
# Epoch 193/450
# 35179/35179 [==============================] - 0s - loss: 1.4977 - acc: 0.3721 - val_loss: 1.5472 - val_acc: 0.3779
# Epoch 194/450
# 35179/35179 [==============================] - 0s - loss: 1.4978 - acc: 0.3722 - val_loss: 1.5459 - val_acc: 0.3773
# Epoch 195/450
# 35179/35179 [==============================] - 0s - loss: 1.4977 - acc: 0.3726 - val_loss: 1.5460 - val_acc: 0.3785
# Epoch 196/450
# 35179/35179 [==============================] - 0s - loss: 1.4976 - acc: 0.3722 - val_loss: 1.5457 - val_acc: 0.3772
# Epoch 197/450
# 35179/35179 [==============================] - 0s - loss: 1.4975 - acc: 0.3723 - val_loss: 1.5469 - val_acc: 0.3782
# Epoch 198/450
# 35179/35179 [==============================] - 0s - loss: 1.4974 - acc: 0.3731 - val_loss: 1.5455 - val_acc: 0.3771
# Epoch 199/450
# 35179/35179 [==============================] - 0s - loss: 1.4973 - acc: 0.3714 - val_loss: 1.5467 - val_acc: 0.3768
# Epoch 200/450
# 35179/35179 [==============================] - 0s - loss: 1.4974 - acc: 0.3718 - val_loss: 1.5463 - val_acc: 0.3773
# Epoch 201/450
# 35179/35179 [==============================] - 0s - loss: 1.4973 - acc: 0.3726 - val_loss: 1.5466 - val_acc: 0.3777
# Epoch 202/450
# 35179/35179 [==============================] - 0s - loss: 1.4973 - acc: 0.3723 - val_loss: 1.5466 - val_acc: 0.3758
# Epoch 203/450
# 35179/35179 [==============================] - 0s - loss: 1.4972 - acc: 0.3734 - val_loss: 1.5463 - val_acc: 0.3787
# Epoch 204/450
# 35179/35179 [==============================] - 0s - loss: 1.4971 - acc: 0.3728 - val_loss: 1.5471 - val_acc: 0.3772
# Epoch 205/450
# 35179/35179 [==============================] - 0s - loss: 1.4971 - acc: 0.3730 - val_loss: 1.5471 - val_acc: 0.3790
# Epoch 206/450
# 35179/35179 [==============================] - 0s - loss: 1.4971 - acc: 0.3722 - val_loss: 1.5463 - val_acc: 0.3774
# Epoch 207/450
# 35179/35179 [==============================] - 0s - loss: 1.4970 - acc: 0.3727 - val_loss: 1.5477 - val_acc: 0.3779
# Epoch 208/450
# 35179/35179 [==============================] - 0s - loss: 1.4969 - acc: 0.3741 - val_loss: 1.5465 - val_acc: 0.3750
# Epoch 209/450
# 35179/35179 [==============================] - 0s - loss: 1.4970 - acc: 0.3731 - val_loss: 1.5464 - val_acc: 0.3775
# Epoch 210/450
# 35179/35179 [==============================] - 0s - loss: 1.4969 - acc: 0.3734 - val_loss: 1.5473 - val_acc: 0.3790
# Epoch 211/450
# 35179/35179 [==============================] - 0s - loss: 1.4968 - acc: 0.3741 - val_loss: 1.5462 - val_acc: 0.3785
# Epoch 212/450
# 35179/35179 [==============================] - 0s - loss: 1.4968 - acc: 0.3726 - val_loss: 1.5477 - val_acc: 0.3789
# Epoch 213/450
# 35179/35179 [==============================] - 0s - loss: 1.4966 - acc: 0.3741 - val_loss: 1.5470 - val_acc: 0.3781
# Epoch 214/450
# 35179/35179 [==============================] - 0s - loss: 1.4966 - acc: 0.3743 - val_loss: 1.5470 - val_acc: 0.3792
# Epoch 215/450
# 35179/35179 [==============================] - 0s - loss: 1.4966 - acc: 0.3736 - val_loss: 1.5472 - val_acc: 0.3790
# Epoch 216/450
# 35179/35179 [==============================] - 0s - loss: 1.4966 - acc: 0.3743 - val_loss: 1.5463 - val_acc: 0.3755
# Epoch 217/450
# 35179/35179 [==============================] - 0s - loss: 1.4966 - acc: 0.3734 - val_loss: 1.5464 - val_acc: 0.3777
# Epoch 218/450
# 35179/35179 [==============================] - 0s - loss: 1.4964 - acc: 0.3733 - val_loss: 1.5478 - val_acc: 0.3778
# Epoch 219/450
# 35179/35179 [==============================] - 0s - loss: 1.4963 - acc: 0.3745 - val_loss: 1.5468 - val_acc: 0.3783
# Epoch 220/450
# 35179/35179 [==============================] - 0s - loss: 1.4964 - acc: 0.3740 - val_loss: 1.5478 - val_acc: 0.3785
# Epoch 221/450
# 35179/35179 [==============================] - 0s - loss: 1.4963 - acc: 0.3742 - val_loss: 1.5480 - val_acc: 0.3779
# Epoch 222/450
# 35179/35179 [==============================] - 0s - loss: 1.4961 - acc: 0.3744 - val_loss: 1.5475 - val_acc: 0.3786
# Epoch 223/450
# 35179/35179 [==============================] - 0s - loss: 1.4961 - acc: 0.3747 - val_loss: 1.5470 - val_acc: 0.3786
# Epoch 224/450
# 35179/35179 [==============================] - 0s - loss: 1.4961 - acc: 0.3740 - val_loss: 1.5478 - val_acc: 0.3789
# Epoch 225/450
# 35179/35179 [==============================] - 0s - loss: 1.4961 - acc: 0.3744 - val_loss: 1.5470 - val_acc: 0.3785
# Epoch 226/450
# 35179/35179 [==============================] - 0s - loss: 1.4961 - acc: 0.3744 - val_loss: 1.5486 - val_acc: 0.3792
# Epoch 227/450
# 35179/35179 [==============================] - 0s - loss: 1.4961 - acc: 0.3748 - val_loss: 1.5475 - val_acc: 0.3787
# Epoch 228/450
# 35179/35179 [==============================] - 0s - loss: 1.4960 - acc: 0.3746 - val_loss: 1.5481 - val_acc: 0.3794
# Epoch 229/450
# 35179/35179 [==============================] - 0s - loss: 1.4959 - acc: 0.3754 - val_loss: 1.5474 - val_acc: 0.3777
# Epoch 230/450
# 35179/35179 [==============================] - 0s - loss: 1.4959 - acc: 0.3751 - val_loss: 1.5475 - val_acc: 0.3785
# Epoch 231/450
# 35179/35179 [==============================] - 0s - loss: 1.4958 - acc: 0.3749 - val_loss: 1.5479 - val_acc: 0.3781
# Epoch 232/450
# 35179/35179 [==============================] - 0s - loss: 1.4958 - acc: 0.3754 - val_loss: 1.5471 - val_acc: 0.3775
# Epoch 233/450
# 35179/35179 [==============================] - 0s - loss: 1.4958 - acc: 0.3746 - val_loss: 1.5471 - val_acc: 0.3782
# Epoch 234/450
# 35179/35179 [==============================] - 0s - loss: 1.4957 - acc: 0.3753 - val_loss: 1.5489 - val_acc: 0.3780
# Epoch 235/450
# 35179/35179 [==============================] - 0s - loss: 1.4957 - acc: 0.3747 - val_loss: 1.5486 - val_acc: 0.3794
# Epoch 236/450
# 35179/35179 [==============================] - 0s - loss: 1.4956 - acc: 0.3755 - val_loss: 1.5488 - val_acc: 0.3791
# Epoch 237/450
# 35179/35179 [==============================] - 0s - loss: 1.4956 - acc: 0.3751 - val_loss: 1.5482 - val_acc: 0.3778
# Epoch 238/450
# 35179/35179 [==============================] - 0s - loss: 1.4956 - acc: 0.3753 - val_loss: 1.5479 - val_acc: 0.3779
# Epoch 239/450
# 35179/35179 [==============================] - 0s - loss: 1.4955 - acc: 0.3750 - val_loss: 1.5494 - val_acc: 0.3785
# Epoch 240/450
# 35179/35179 [==============================] - 0s - loss: 1.4955 - acc: 0.3755 - val_loss: 1.5486 - val_acc: 0.3796
# Epoch 241/450
# 35179/35179 [==============================] - 0s - loss: 1.4955 - acc: 0.3752 - val_loss: 1.5493 - val_acc: 0.3793
# Epoch 242/450
# 35179/35179 [==============================] - 0s - loss: 1.4953 - acc: 0.3759 - val_loss: 1.5474 - val_acc: 0.3785
# Epoch 243/450
# 35179/35179 [==============================] - 0s - loss: 1.4954 - acc: 0.3754 - val_loss: 1.5494 - val_acc: 0.3792
# Epoch 244/450
# 35179/35179 [==============================] - 0s - loss: 1.4953 - acc: 0.3762 - val_loss: 1.5484 - val_acc: 0.3792
# Epoch 245/450
# 35179/35179 [==============================] - 0s - loss: 1.4952 - acc: 0.3750 - val_loss: 1.5483 - val_acc: 0.3787
# Epoch 246/450
# 35179/35179 [==============================] - 0s - loss: 1.4953 - acc: 0.3757 - val_loss: 1.5489 - val_acc: 0.3792
# Epoch 247/450
# 35179/35179 [==============================] - 0s - loss: 1.4951 - acc: 0.3752 - val_loss: 1.5487 - val_acc: 0.3780
# Epoch 248/450
# 35179/35179 [==============================] - 0s - loss: 1.4951 - acc: 0.3755 - val_loss: 1.5492 - val_acc: 0.3784
# Epoch 249/450
# 35179/35179 [==============================] - 0s - loss: 1.4951 - acc: 0.3756 - val_loss: 1.5482 - val_acc: 0.3792
# Epoch 250/450
# 35179/35179 [==============================] - 0s - loss: 1.4951 - acc: 0.3757 - val_loss: 1.5491 - val_acc: 0.3792
# Epoch 251/450
# 35179/35179 [==============================] - 0s - loss: 1.4950 - acc: 0.3761 - val_loss: 1.5488 - val_acc: 0.3788
# Epoch 252/450
# 35179/35179 [==============================] - 0s - loss: 1.4948 - acc: 0.3773 - val_loss: 1.5486 - val_acc: 0.3770
# Epoch 253/450
# 35179/35179 [==============================] - 0s - loss: 1.4950 - acc: 0.3760 - val_loss: 1.5489 - val_acc: 0.3792
# Epoch 254/450
# 35179/35179 [==============================] - 0s - loss: 1.4948 - acc: 0.3763 - val_loss: 1.5484 - val_acc: 0.3772
# Epoch 255/450
# 35179/35179 [==============================] - 0s - loss: 1.4949 - acc: 0.3758 - val_loss: 1.5492 - val_acc: 0.3776
# Epoch 256/450
# 35179/35179 [==============================] - 0s - loss: 1.4949 - acc: 0.3761 - val_loss: 1.5485 - val_acc: 0.3782
# Epoch 257/450
# 35179/35179 [==============================] - 0s - loss: 1.4948 - acc: 0.3756 - val_loss: 1.5485 - val_acc: 0.3787
# Epoch 258/450
# 35179/35179 [==============================] - 0s - loss: 1.4948 - acc: 0.3760 - val_loss: 1.5492 - val_acc: 0.3792
# Epoch 259/450
# 35179/35179 [==============================] - 0s - loss: 1.4947 - acc: 0.3761 - val_loss: 1.5488 - val_acc: 0.3790
# Epoch 260/450
# 35179/35179 [==============================] - 0s - loss: 1.4945 - acc: 0.3762 - val_loss: 1.5487 - val_acc: 0.3777
# Epoch 261/450
# 35179/35179 [==============================] - 0s - loss: 1.4946 - acc: 0.3765 - val_loss: 1.5484 - val_acc: 0.3782
# Epoch 262/450
# 35179/35179 [==============================] - 0s - loss: 1.4946 - acc: 0.3764 - val_loss: 1.5489 - val_acc: 0.3793
# Epoch 263/450
# 35179/35179 [==============================] - 0s - loss: 1.4945 - acc: 0.3772 - val_loss: 1.5497 - val_acc: 0.3793
# Epoch 264/450
# 35179/35179 [==============================] - 0s - loss: 1.4945 - acc: 0.3770 - val_loss: 1.5482 - val_acc: 0.3764
# Epoch 265/450
# 35179/35179 [==============================] - 0s - loss: 1.4944 - acc: 0.3749 - val_loss: 1.5505 - val_acc: 0.3793
# Epoch 266/450
# 35179/35179 [==============================] - 0s - loss: 1.4945 - acc: 0.3766 - val_loss: 1.5492 - val_acc: 0.3785
# Epoch 267/450
# 35179/35179 [==============================] - 0s - loss: 1.4945 - acc: 0.3773 - val_loss: 1.5494 - val_acc: 0.3800
# Epoch 268/450
# 35179/35179 [==============================] - 0s - loss: 1.4943 - acc: 0.3772 - val_loss: 1.5495 - val_acc: 0.3781
# Epoch 269/450
# 35179/35179 [==============================] - 0s - loss: 1.4943 - acc: 0.3762 - val_loss: 1.5500 - val_acc: 0.3787
# Epoch 270/450
# 35179/35179 [==============================] - 0s - loss: 1.4942 - acc: 0.3770 - val_loss: 1.5483 - val_acc: 0.3776
# Epoch 271/450
# 35179/35179 [==============================] - 0s - loss: 1.4944 - acc: 0.3756 - val_loss: 1.5493 - val_acc: 0.3788
# Epoch 272/450
# 35179/35179 [==============================] - 0s - loss: 1.4942 - acc: 0.3771 - val_loss: 1.5497 - val_acc: 0.3787
# Epoch 273/450
# 35179/35179 [==============================] - 0s - loss: 1.4942 - acc: 0.3772 - val_loss: 1.5497 - val_acc: 0.3785
# Epoch 274/450
# 35179/35179 [==============================] - 0s - loss: 1.4942 - acc: 0.3765 - val_loss: 1.5493 - val_acc: 0.3788
# Epoch 275/450
# 35179/35179 [==============================] - 0s - loss: 1.4939 - acc: 0.3770 - val_loss: 1.5496 - val_acc: 0.3788
# Epoch 276/450
# 35179/35179 [==============================] - 0s - loss: 1.4941 - acc: 0.3776 - val_loss: 1.5496 - val_acc: 0.3788
# Epoch 277/450
# 35179/35179 [==============================] - 0s - loss: 1.4940 - acc: 0.3780 - val_loss: 1.5491 - val_acc: 0.3750
# Epoch 278/450
# 35179/35179 [==============================] - 0s - loss: 1.4940 - acc: 0.3766 - val_loss: 1.5509 - val_acc: 0.3792
# Epoch 279/450
# 35179/35179 [==============================] - 0s - loss: 1.4939 - acc: 0.3774 - val_loss: 1.5497 - val_acc: 0.3791
# Epoch 280/450
# 35179/35179 [==============================] - 0s - loss: 1.4940 - acc: 0.3774 - val_loss: 1.5503 - val_acc: 0.3790
# Epoch 281/450
# 35179/35179 [==============================] - 0s - loss: 1.4940 - acc: 0.3771 - val_loss: 1.5500 - val_acc: 0.3788
# Epoch 282/450
# 35179/35179 [==============================] - 0s - loss: 1.4939 - acc: 0.3767 - val_loss: 1.5500 - val_acc: 0.3792
# Epoch 283/450
# 35179/35179 [==============================] - 0s - loss: 1.4939 - acc: 0.3776 - val_loss: 1.5498 - val_acc: 0.3794
# Epoch 284/450
# 35179/35179 [==============================] - 0s - loss: 1.4937 - acc: 0.3777 - val_loss: 1.5501 - val_acc: 0.3796
# Epoch 285/450
# 35179/35179 [==============================] - 0s - loss: 1.4938 - acc: 0.3779 - val_loss: 1.5490 - val_acc: 0.3785
# Epoch 286/450
# 35179/35179 [==============================] - 0s - loss: 1.4938 - acc: 0.3775 - val_loss: 1.5493 - val_acc: 0.3787
# Epoch 287/450
# 35179/35179 [==============================] - 0s - loss: 1.4938 - acc: 0.3775 - val_loss: 1.5495 - val_acc: 0.3796
# Epoch 288/450
# 35179/35179 [==============================] - 0s - loss: 1.4937 - acc: 0.3769 - val_loss: 1.5504 - val_acc: 0.3791
# Epoch 289/450
# 35179/35179 [==============================] - 0s - loss: 1.4937 - acc: 0.3774 - val_loss: 1.5505 - val_acc: 0.3793
# Epoch 290/450
# 35179/35179 [==============================] - 0s - loss: 1.4937 - acc: 0.3775 - val_loss: 1.5493 - val_acc: 0.3784
# Epoch 291/450
# 35179/35179 [==============================] - 0s - loss: 1.4936 - acc: 0.3784 - val_loss: 1.5492 - val_acc: 0.3792
# Epoch 292/450
# 35179/35179 [==============================] - 0s - loss: 1.4936 - acc: 0.3775 - val_loss: 1.5513 - val_acc: 0.3794
# Epoch 293/450
# 35179/35179 [==============================] - 0s - loss: 1.4935 - acc: 0.3782 - val_loss: 1.5504 - val_acc: 0.3791
# Epoch 294/450
# 35179/35179 [==============================] - 0s - loss: 1.4935 - acc: 0.3778 - val_loss: 1.5498 - val_acc: 0.3787
# Epoch 295/450
# 35179/35179 [==============================] - 0s - loss: 1.4935 - acc: 0.3777 - val_loss: 1.5498 - val_acc: 0.3794
# Epoch 296/450
# 35179/35179 [==============================] - 0s - loss: 1.4935 - acc: 0.3773 - val_loss: 1.5503 - val_acc: 0.3790
# Epoch 297/450
# 35179/35179 [==============================] - 0s - loss: 1.4934 - acc: 0.3789 - val_loss: 1.5494 - val_acc: 0.3786
# Epoch 298/450
# 35179/35179 [==============================] - 0s - loss: 1.4933 - acc: 0.3778 - val_loss: 1.5491 - val_acc: 0.3792
# Epoch 299/450
# 35179/35179 [==============================] - 0s - loss: 1.4933 - acc: 0.3772 - val_loss: 1.5520 - val_acc: 0.3781
# Epoch 300/450
# 35179/35179 [==============================] - 0s - loss: 1.4934 - acc: 0.3789 - val_loss: 1.5507 - val_acc: 0.3792
# Epoch 301/450
# 35179/35179 [==============================] - 0s - loss: 1.4933 - acc: 0.3778 - val_loss: 1.5498 - val_acc: 0.3781
# Epoch 302/450
# 35179/35179 [==============================] - 0s - loss: 1.4931 - acc: 0.3774 - val_loss: 1.5507 - val_acc: 0.3793
# Epoch 303/450
# 35179/35179 [==============================] - 0s - loss: 1.4932 - acc: 0.3776 - val_loss: 1.5509 - val_acc: 0.3786
# Epoch 304/450
# 35179/35179 [==============================] - 0s - loss: 1.4932 - acc: 0.3773 - val_loss: 1.5505 - val_acc: 0.3789
# Epoch 305/450
# 35179/35179 [==============================] - 0s - loss: 1.4932 - acc: 0.3788 - val_loss: 1.5508 - val_acc: 0.3789
# Epoch 306/450
# 35179/35179 [==============================] - 0s - loss: 1.4931 - acc: 0.3778 - val_loss: 1.5505 - val_acc: 0.3785
# Epoch 307/450
# 35179/35179 [==============================] - 0s - loss: 1.4931 - acc: 0.3772 - val_loss: 1.5502 - val_acc: 0.3796
# Epoch 308/450
# 35179/35179 [==============================] - 0s - loss: 1.4931 - acc: 0.3779 - val_loss: 1.5497 - val_acc: 0.3786
# Epoch 309/450
# 35179/35179 [==============================] - 0s - loss: 1.4931 - acc: 0.3775 - val_loss: 1.5512 - val_acc: 0.3790
# Epoch 310/450
# 35179/35179 [==============================] - 0s - loss: 1.4929 - acc: 0.3780 - val_loss: 1.5529 - val_acc: 0.3791
# Epoch 311/450
# 35179/35179 [==============================] - 0s - loss: 1.4929 - acc: 0.3791 - val_loss: 1.5508 - val_acc: 0.3775
# Epoch 312/450
# 35179/35179 [==============================] - 0s - loss: 1.4930 - acc: 0.3784 - val_loss: 1.5507 - val_acc: 0.3793
# Epoch 313/450
# 35179/35179 [==============================] - 0s - loss: 1.4929 - acc: 0.3782 - val_loss: 1.5515 - val_acc: 0.3795
# Epoch 314/450
# 35179/35179 [==============================] - 0s - loss: 1.4929 - acc: 0.3782 - val_loss: 1.5519 - val_acc: 0.3792
# Epoch 315/450
# 35179/35179 [==============================] - 0s - loss: 1.4930 - acc: 0.3787 - val_loss: 1.5510 - val_acc: 0.3796
# Epoch 316/450
# 35179/35179 [==============================] - 0s - loss: 1.4928 - acc: 0.3790 - val_loss: 1.5503 - val_acc: 0.3774
# Epoch 317/450
# 35179/35179 [==============================] - 0s - loss: 1.4928 - acc: 0.3783 - val_loss: 1.5513 - val_acc: 0.3790
# Epoch 318/450
# 35179/35179 [==============================] - 0s - loss: 1.4927 - acc: 0.3784 - val_loss: 1.5511 - val_acc: 0.3794
# Epoch 319/450
# 35179/35179 [==============================] - 0s - loss: 1.4928 - acc: 0.3787 - val_loss: 1.5509 - val_acc: 0.3792
# Epoch 320/450
# 35179/35179 [==============================] - 0s - loss: 1.4927 - acc: 0.3788 - val_loss: 1.5502 - val_acc: 0.3787
# Epoch 321/450
# 35179/35179 [==============================] - 0s - loss: 1.4927 - acc: 0.3789 - val_loss: 1.5521 - val_acc: 0.3796
# Epoch 322/450
# 35179/35179 [==============================] - 0s - loss: 1.4926 - acc: 0.3791 - val_loss: 1.5513 - val_acc: 0.3783
# Epoch 323/450
# 35179/35179 [==============================] - 0s - loss: 1.4926 - acc: 0.3785 - val_loss: 1.5519 - val_acc: 0.3799
# Epoch 324/450
# 35179/35179 [==============================] - 0s - loss: 1.4925 - acc: 0.3787 - val_loss: 1.5536 - val_acc: 0.3791
# Epoch 325/450
# 35179/35179 [==============================] - 0s - loss: 1.4926 - acc: 0.3789 - val_loss: 1.5501 - val_acc: 0.3791
# Epoch 326/450
# 35179/35179 [==============================] - 0s - loss: 1.4926 - acc: 0.3779 - val_loss: 1.5513 - val_acc: 0.3787
# Epoch 327/450
# 35179/35179 [==============================] - 0s - loss: 1.4925 - acc: 0.3788 - val_loss: 1.5518 - val_acc: 0.3787
# Epoch 328/450
# 35179/35179 [==============================] - 0s - loss: 1.4925 - acc: 0.3793 - val_loss: 1.5506 - val_acc: 0.3792
# Epoch 329/450
# 35179/35179 [==============================] - 0s - loss: 1.4925 - acc: 0.3786 - val_loss: 1.5517 - val_acc: 0.3796
# Epoch 330/450
# 35179/35179 [==============================] - 0s - loss: 1.4925 - acc: 0.3790 - val_loss: 1.5515 - val_acc: 0.3797
# Epoch 331/450
# 35179/35179 [==============================] - 0s - loss: 1.4924 - acc: 0.3787 - val_loss: 1.5506 - val_acc: 0.3775
# Epoch 332/450
# 35179/35179 [==============================] - 0s - loss: 1.4925 - acc: 0.3784 - val_loss: 1.5505 - val_acc: 0.3774
# Epoch 333/450
# 35179/35179 [==============================] - 0s - loss: 1.4923 - acc: 0.3787 - val_loss: 1.5509 - val_acc: 0.3778
# Epoch 334/450
# 35179/35179 [==============================] - 0s - loss: 1.4924 - acc: 0.3793 - val_loss: 1.5507 - val_acc: 0.3789
# Epoch 335/450
# 35179/35179 [==============================] - 0s - loss: 1.4924 - acc: 0.3789 - val_loss: 1.5511 - val_acc: 0.3784
# Epoch 336/450
# 35179/35179 [==============================] - 0s - loss: 1.4923 - acc: 0.3790 - val_loss: 1.5510 - val_acc: 0.3781
# Epoch 337/450
# 35179/35179 [==============================] - 0s - loss: 1.4923 - acc: 0.3791 - val_loss: 1.5507 - val_acc: 0.3777
# Epoch 338/450
# 35179/35179 [==============================] - 0s - loss: 1.4922 - acc: 0.3788 - val_loss: 1.5511 - val_acc: 0.3781
# Epoch 339/450
# 35179/35179 [==============================] - 0s - loss: 1.4923 - acc: 0.3786 - val_loss: 1.5505 - val_acc: 0.3797
# Epoch 340/450
# 35179/35179 [==============================] - 0s - loss: 1.4922 - acc: 0.3784 - val_loss: 1.5512 - val_acc: 0.3788
# Epoch 341/450
# 35179/35179 [==============================] - 0s - loss: 1.4922 - acc: 0.3784 - val_loss: 1.5508 - val_acc: 0.3791
# Epoch 342/450
# 35179/35179 [==============================] - 0s - loss: 1.4920 - acc: 0.3778 - val_loss: 1.5534 - val_acc: 0.3781
# Epoch 343/450
# 35179/35179 [==============================] - 0s - loss: 1.4921 - acc: 0.3797 - val_loss: 1.5516 - val_acc: 0.3785
# Epoch 344/450
# 35179/35179 [==============================] - 0s - loss: 1.4921 - acc: 0.3786 - val_loss: 1.5526 - val_acc: 0.3798
# Epoch 345/450
# 35179/35179 [==============================] - 0s - loss: 1.4920 - acc: 0.3791 - val_loss: 1.5518 - val_acc: 0.3792
# Epoch 346/450
# 35179/35179 [==============================] - 0s - loss: 1.4921 - acc: 0.3792 - val_loss: 1.5518 - val_acc: 0.3790
# Epoch 347/450
# 35179/35179 [==============================] - 0s - loss: 1.4919 - acc: 0.3801 - val_loss: 1.5521 - val_acc: 0.3800
# Epoch 348/450
# 35179/35179 [==============================] - 0s - loss: 1.4919 - acc: 0.3799 - val_loss: 1.5522 - val_acc: 0.3797
# Epoch 349/450
# 35179/35179 [==============================] - 0s - loss: 1.4920 - acc: 0.3799 - val_loss: 1.5508 - val_acc: 0.3788
# Epoch 350/450
# 35179/35179 [==============================] - 0s - loss: 1.4919 - acc: 0.3797 - val_loss: 1.5511 - val_acc: 0.3792
# Epoch 351/450
# 35179/35179 [==============================] - 0s - loss: 1.4919 - acc: 0.3798 - val_loss: 1.5517 - val_acc: 0.3792
# Epoch 352/450
# 35179/35179 [==============================] - 0s - loss: 1.4919 - acc: 0.3802 - val_loss: 1.5518 - val_acc: 0.3787
# Epoch 353/450
# 35179/35179 [==============================] - 0s - loss: 1.4918 - acc: 0.3802 - val_loss: 1.5515 - val_acc: 0.3784
# Epoch 354/450
# 35179/35179 [==============================] - 0s - loss: 1.4918 - acc: 0.3789 - val_loss: 1.5527 - val_acc: 0.3796
# Epoch 355/450
# 35179/35179 [==============================] - 0s - loss: 1.4917 - acc: 0.3796 - val_loss: 1.5511 - val_acc: 0.3782
# Epoch 356/450
# 35179/35179 [==============================] - 0s - loss: 1.4918 - acc: 0.3803 - val_loss: 1.5507 - val_acc: 0.3777
# Epoch 357/450
# 35179/35179 [==============================] - 0s - loss: 1.4917 - acc: 0.3797 - val_loss: 1.5513 - val_acc: 0.3762
# Epoch 358/450
# 35179/35179 [==============================] - 0s - loss: 1.4918 - acc: 0.3792 - val_loss: 1.5520 - val_acc: 0.3788
# Epoch 359/450
# 35179/35179 [==============================] - 0s - loss: 1.4915 - acc: 0.3799 - val_loss: 1.5514 - val_acc: 0.3795
# Epoch 360/450
# 35179/35179 [==============================] - 0s - loss: 1.4918 - acc: 0.3795 - val_loss: 1.5517 - val_acc: 0.3785
# Epoch 361/450
# 35179/35179 [==============================] - 0s - loss: 1.4917 - acc: 0.3797 - val_loss: 1.5517 - val_acc: 0.3794
# Epoch 362/450
# 35179/35179 [==============================] - 0s - loss: 1.4917 - acc: 0.3794 - val_loss: 1.5520 - val_acc: 0.3787
# Epoch 363/450
# 35179/35179 [==============================] - 0s - loss: 1.4916 - acc: 0.3797 - val_loss: 1.5523 - val_acc: 0.3794
# Epoch 364/450
# 35179/35179 [==============================] - 0s - loss: 1.4916 - acc: 0.3803 - val_loss: 1.5527 - val_acc: 0.3793
# Epoch 365/450
# 35179/35179 [==============================] - 0s - loss: 1.4916 - acc: 0.3800 - val_loss: 1.5520 - val_acc: 0.3792
# Epoch 366/450
# 35179/35179 [==============================] - 0s - loss: 1.4916 - acc: 0.3799 - val_loss: 1.5518 - val_acc: 0.3795
# Epoch 367/450
# 35179/35179 [==============================] - 0s - loss: 1.4915 - acc: 0.3793 - val_loss: 1.5527 - val_acc: 0.3793
# Epoch 368/450
# 35179/35179 [==============================] - 0s - loss: 1.4915 - acc: 0.3798 - val_loss: 1.5524 - val_acc: 0.3794
# Epoch 369/450
# 35179/35179 [==============================] - 0s - loss: 1.4915 - acc: 0.3798 - val_loss: 1.5517 - val_acc: 0.3785
# Epoch 370/450
# 35179/35179 [==============================] - 0s - loss: 1.4915 - acc: 0.3800 - val_loss: 1.5520 - val_acc: 0.3789
# Epoch 371/450
# 35179/35179 [==============================] - 0s - loss: 1.4914 - acc: 0.3796 - val_loss: 1.5515 - val_acc: 0.3786
# Epoch 372/450
# 35179/35179 [==============================] - 0s - loss: 1.4915 - acc: 0.3799 - val_loss: 1.5519 - val_acc: 0.3797
# Epoch 373/450
# 35179/35179 [==============================] - 0s - loss: 1.4913 - acc: 0.3796 - val_loss: 1.5533 - val_acc: 0.3800
# Epoch 374/450
# 35179/35179 [==============================] - 0s - loss: 1.4914 - acc: 0.3802 - val_loss: 1.5518 - val_acc: 0.3788
# Epoch 375/450
# 35179/35179 [==============================] - 0s - loss: 1.4914 - acc: 0.3803 - val_loss: 1.5519 - val_acc: 0.3780
# Epoch 376/450
# 35179/35179 [==============================] - 0s - loss: 1.4914 - acc: 0.3797 - val_loss: 1.5514 - val_acc: 0.3787
# Epoch 377/450
# 35179/35179 [==============================] - 0s - loss: 1.4913 - acc: 0.3794 - val_loss: 1.5523 - val_acc: 0.3796
# Epoch 378/450
# 35179/35179 [==============================] - 0s - loss: 1.4912 - acc: 0.3805 - val_loss: 1.5517 - val_acc: 0.3781
# Epoch 379/450
# 35179/35179 [==============================] - 0s - loss: 1.4912 - acc: 0.3805 - val_loss: 1.5522 - val_acc: 0.3796
# Epoch 380/450
# 35179/35179 [==============================] - 0s - loss: 1.4913 - acc: 0.3799 - val_loss: 1.5527 - val_acc: 0.3800
# Epoch 381/450
# 35179/35179 [==============================] - 0s - loss: 1.4912 - acc: 0.3814 - val_loss: 1.5514 - val_acc: 0.3793
# Epoch 382/450
# 35179/35179 [==============================] - 0s - loss: 1.4911 - acc: 0.3810 - val_loss: 1.5519 - val_acc: 0.3779
# Epoch 383/450
# 35179/35179 [==============================] - 0s - loss: 1.4912 - acc: 0.3802 - val_loss: 1.5530 - val_acc: 0.3803
# Epoch 384/450
# 35179/35179 [==============================] - 0s - loss: 1.4911 - acc: 0.3793 - val_loss: 1.5531 - val_acc: 0.3793
# Epoch 385/450
# 35179/35179 [==============================] - 0s - loss: 1.4911 - acc: 0.3809 - val_loss: 1.5521 - val_acc: 0.3787
# Epoch 386/450
# 35179/35179 [==============================] - 0s - loss: 1.4911 - acc: 0.3808 - val_loss: 1.5530 - val_acc: 0.3801
# Epoch 387/450
# 35179/35179 [==============================] - 0s - loss: 1.4911 - acc: 0.3809 - val_loss: 1.5523 - val_acc: 0.3784
# Epoch 388/450
# 35179/35179 [==============================] - 0s - loss: 1.4911 - acc: 0.3798 - val_loss: 1.5522 - val_acc: 0.3784
# Epoch 389/450
# 35179/35179 [==============================] - 0s - loss: 1.4911 - acc: 0.3805 - val_loss: 1.5519 - val_acc: 0.3799
# Epoch 390/450
# 35179/35179 [==============================] - 0s - loss: 1.4911 - acc: 0.3800 - val_loss: 1.5522 - val_acc: 0.3784
# Epoch 391/450
# 35179/35179 [==============================] - 0s - loss: 1.4910 - acc: 0.3798 - val_loss: 1.5531 - val_acc: 0.3796
# Epoch 392/450
# 35179/35179 [==============================] - 0s - loss: 1.4909 - acc: 0.3798 - val_loss: 1.5536 - val_acc: 0.3792
# Epoch 393/450
# 35179/35179 [==============================] - 0s - loss: 1.4909 - acc: 0.3797 - val_loss: 1.5527 - val_acc: 0.3795
# Epoch 394/450
# 35179/35179 [==============================] - 0s - loss: 1.4909 - acc: 0.3800 - val_loss: 1.5527 - val_acc: 0.3798
# Epoch 395/450
# 35179/35179 [==============================] - 0s - loss: 1.4909 - acc: 0.3804 - val_loss: 1.5516 - val_acc: 0.3781
# Epoch 396/450
# 35179/35179 [==============================] - 0s - loss: 1.4909 - acc: 0.3794 - val_loss: 1.5532 - val_acc: 0.3792
# Epoch 397/450
# 35179/35179 [==============================] - 0s - loss: 1.4909 - acc: 0.3813 - val_loss: 1.5528 - val_acc: 0.3777
# Epoch 398/450
# 35179/35179 [==============================] - 0s - loss: 1.4909 - acc: 0.3806 - val_loss: 1.5537 - val_acc: 0.3793
# Epoch 399/450
# 35179/35179 [==============================] - 0s - loss: 1.4909 - acc: 0.3810 - val_loss: 1.5519 - val_acc: 0.3785
# Epoch 400/450
# 35179/35179 [==============================] - 0s - loss: 1.4907 - acc: 0.3801 - val_loss: 1.5540 - val_acc: 0.3799
# Epoch 401/450
# 35179/35179 [==============================] - 0s - loss: 1.4908 - acc: 0.3810 - val_loss: 1.5531 - val_acc: 0.3796
# Epoch 402/450
# 35179/35179 [==============================] - 0s - loss: 1.4906 - acc: 0.3809 - val_loss: 1.5516 - val_acc: 0.3784
# Epoch 403/450
# 35179/35179 [==============================] - 0s - loss: 1.4908 - acc: 0.3800 - val_loss: 1.5527 - val_acc: 0.3799
# Epoch 404/450
# 35179/35179 [==============================] - 0s - loss: 1.4907 - acc: 0.3812 - val_loss: 1.5521 - val_acc: 0.3784
# Epoch 405/450
# 35179/35179 [==============================] - 0s - loss: 1.4907 - acc: 0.3802 - val_loss: 1.5528 - val_acc: 0.3789
# Epoch 406/450
# 35179/35179 [==============================] - 0s - loss: 1.4907 - acc: 0.3807 - val_loss: 1.5534 - val_acc: 0.3788
# Epoch 407/450
# 35179/35179 [==============================] - 0s - loss: 1.4907 - acc: 0.3814 - val_loss: 1.5524 - val_acc: 0.3795
# Epoch 408/450
# 35179/35179 [==============================] - 0s - loss: 1.4906 - acc: 0.3815 - val_loss: 1.5525 - val_acc: 0.3799
# Epoch 409/450
# 35179/35179 [==============================] - 0s - loss: 1.4907 - acc: 0.3805 - val_loss: 1.5532 - val_acc: 0.3796
# Epoch 410/450
# 35179/35179 [==============================] - 0s - loss: 1.4906 - acc: 0.3806 - val_loss: 1.5538 - val_acc: 0.3797
# Epoch 411/450
# 35179/35179 [==============================] - 0s - loss: 1.4906 - acc: 0.3812 - val_loss: 1.5518 - val_acc: 0.3791
# Epoch 412/450
# 35179/35179 [==============================] - 0s - loss: 1.4906 - acc: 0.3804 - val_loss: 1.5549 - val_acc: 0.3780
# Epoch 413/450
# 35179/35179 [==============================] - 0s - loss: 1.4906 - acc: 0.3812 - val_loss: 1.5530 - val_acc: 0.3786
# Epoch 414/450
# 35179/35179 [==============================] - 0s - loss: 1.4905 - acc: 0.3809 - val_loss: 1.5536 - val_acc: 0.3800
# Epoch 415/450
# 35179/35179 [==============================] - 0s - loss: 1.4905 - acc: 0.3809 - val_loss: 1.5541 - val_acc: 0.3798
# Epoch 416/450
# 35179/35179 [==============================] - 0s - loss: 1.4905 - acc: 0.3810 - val_loss: 1.5546 - val_acc: 0.3785
# Epoch 417/450
# 35179/35179 [==============================] - 0s - loss: 1.4905 - acc: 0.3814 - val_loss: 1.5544 - val_acc: 0.3792
# Epoch 418/450
# 35179/35179 [==============================] - 0s - loss: 1.4904 - acc: 0.3832 - val_loss: 1.5525 - val_acc: 0.3792
# Epoch 419/450
# 35179/35179 [==============================] - 0s - loss: 1.4904 - acc: 0.3805 - val_loss: 1.5530 - val_acc: 0.3792
# Epoch 420/450
# 35179/35179 [==============================] - 0s - loss: 1.4903 - acc: 0.3809 - val_loss: 1.5530 - val_acc: 0.3800
# Epoch 421/450
# 35179/35179 [==============================] - 0s - loss: 1.4903 - acc: 0.3823 - val_loss: 1.5522 - val_acc: 0.3785
# Epoch 422/450
# 35179/35179 [==============================] - 0s - loss: 1.4903 - acc: 0.3801 - val_loss: 1.5527 - val_acc: 0.3792
# Epoch 423/450
# 35179/35179 [==============================] - 0s - loss: 1.4903 - acc: 0.3819 - val_loss: 1.5524 - val_acc: 0.3792
# Epoch 424/450
# 35179/35179 [==============================] - 0s - loss: 1.4903 - acc: 0.3811 - val_loss: 1.5524 - val_acc: 0.3777
# Epoch 425/450
# 35179/35179 [==============================] - 0s - loss: 1.4903 - acc: 0.3809 - val_loss: 1.5526 - val_acc: 0.3787
# Epoch 426/450
# 35179/35179 [==============================] - 0s - loss: 1.4902 - acc: 0.3806 - val_loss: 1.5549 - val_acc: 0.3791
# Epoch 427/450
# 35179/35179 [==============================] - 0s - loss: 1.4903 - acc: 0.3811 - val_loss: 1.5545 - val_acc: 0.3788
# Epoch 428/450
# 35179/35179 [==============================] - 0s - loss: 1.4903 - acc: 0.3817 - val_loss: 1.5521 - val_acc: 0.3791
# Epoch 429/450
# 35179/35179 [==============================] - 0s - loss: 1.4901 - acc: 0.3802 - val_loss: 1.5537 - val_acc: 0.3785
# Epoch 430/450
# 35179/35179 [==============================] - 0s - loss: 1.4902 - acc: 0.3810 - val_loss: 1.5538 - val_acc: 0.3785
# Epoch 431/450
# 35179/35179 [==============================] - 0s - loss: 1.4902 - acc: 0.3817 - val_loss: 1.5523 - val_acc: 0.3800
# Epoch 432/450
# 35179/35179 [==============================] - 0s - loss: 1.4901 - acc: 0.3813 - val_loss: 1.5538 - val_acc: 0.3796
# Epoch 433/450
# 35179/35179 [==============================] - 0s - loss: 1.4902 - acc: 0.3816 - val_loss: 1.5532 - val_acc: 0.3785
# Epoch 434/450
# 35179/35179 [==============================] - 0s - loss: 1.4901 - acc: 0.3824 - val_loss: 1.5533 - val_acc: 0.3796
# Epoch 435/450
# 35179/35179 [==============================] - 0s - loss: 1.4901 - acc: 0.3817 - val_loss: 1.5525 - val_acc: 0.3800
# Epoch 436/450
# 35179/35179 [==============================] - 0s - loss: 1.4901 - acc: 0.3811 - val_loss: 1.5529 - val_acc: 0.3785
# Epoch 437/450
# 35179/35179 [==============================] - 0s - loss: 1.4901 - acc: 0.3812 - val_loss: 1.5527 - val_acc: 0.3798
# Epoch 438/450
# 35179/35179 [==============================] - 0s - loss: 1.4901 - acc: 0.3809 - val_loss: 1.5540 - val_acc: 0.3793
# Epoch 439/450
# 35179/35179 [==============================] - 0s - loss: 1.4900 - acc: 0.3818 - val_loss: 1.5533 - val_acc: 0.3803
# Epoch 440/450
# 35179/35179 [==============================] - 0s - loss: 1.4901 - acc: 0.3817 - val_loss: 1.5534 - val_acc: 0.3799
# Epoch 441/450
# 35179/35179 [==============================] - 0s - loss: 1.4900 - acc: 0.3820 - val_loss: 1.5535 - val_acc: 0.3784
# Epoch 442/450
# 35179/35179 [==============================] - 0s - loss: 1.4901 - acc: 0.3809 - val_loss: 1.5531 - val_acc: 0.3800
# Epoch 443/450
# 35179/35179 [==============================] - 0s - loss: 1.4899 - acc: 0.3817 - val_loss: 1.5528 - val_acc: 0.3807
# Epoch 444/450
# 35179/35179 [==============================] - 0s - loss: 1.4900 - acc: 0.3815 - val_loss: 1.5532 - val_acc: 0.3799
# Epoch 445/450
# 35179/35179 [==============================] - 0s - loss: 1.4899 - acc: 0.3812 - val_loss: 1.5531 - val_acc: 0.3794
# Epoch 446/450
# 35179/35179 [==============================] - 0s - loss: 1.4898 - acc: 0.3813 - val_loss: 1.5534 - val_acc: 0.3787
# Epoch 447/450
# 35179/35179 [==============================] - 0s - loss: 1.4899 - acc: 0.3815 - val_loss: 1.5544 - val_acc: 0.3783
# Epoch 448/450
# 35179/35179 [==============================] - 0s - loss: 1.4898 - acc: 0.3815 - val_loss: 1.5540 - val_acc: 0.3782
# Epoch 449/450
# 35179/35179 [==============================] - 0s - loss: 1.4899 - acc: 0.3818 - val_loss: 1.5535 - val_acc: 0.3788
# Epoch 450/450
# 35179/35179 [==============================] - 0s - loss: 1.4899 - acc: 0.3815 - val_loss: 1.5535 - val_acc: 0.3803
# Test loss: 1.55354662075
# Test accuracy: 0.380347277049

# %%
### Question 8 : Determine the indices of all test images that are misclassified by the fitted model ### 

prediction=model.predict(x_test, batch_size=None, verbose=0)
idx=[]
error=0
for i in range (y_test[:,0].size):
    for j in range (y_test[0,:].size):
        
        if ((y_test[i][j]==1) & (max(prediction[i])!=prediction[i][j])):
            idx.append(i)
            error=error+1
            break
print ('Nombre erreurs: ')
print (error)

### plot some of them using the function ###
plot_some_samples(x_test, y_test, prediction, idx[0:30]  ,label_mapping = subset_of_classes)
# Out:
# Nombre erreurs:
# 7851

# %% [markdown]
# ## Exercise 2: One hidden layer, different optizimizers
# ### Description
#
# Train a network with one hidden layer and compare different optimizers.
#
# 1. Use one hidden layer with 64 units and the 'relu' activation. Use the [summary method](https://keras.io/models/about-keras-models/) to inspect your model.
# 2. Fit the model for 50 epochs with different learning rates of stochastic gradient descent and answer the question below.
# 3. Replace the stochastic gradient descent optimizer with the [Adam optimizer](https://keras.io/optimizers/#adam).
# 4. Plot the learning curves of SGD with a reasonable learning rate together with the learning curves of Adam in the same figure. Take care of a reasonable labeling of the curves in the plot.

# %% [markdown]
# ### Solution

# %%
### Question 2 : Fit model with different Learning Rate ###

### Learning Rate ###
l_r=[0.001,0.01,0.05,0.1,0.5,1]

### Simulation for the different learning rate ###
for i in range (len(l_r)):
    model_1 = Sequential()
    model_1.add(Dense(64, activation='relu', input_shape=x_train.shape[1:]))
    model_1.add(Dense(5, activation='softmax'))

    model_1.summary()

    model_1.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.SGD(lr=l_r[i]),
              metrics=['accuracy'])

    history_1 = model_1.fit(x_train, y_train,
                        batch_size=128,
                        epochs=50,
                        verbose=0,
                        validation_data=(x_test, y_test))

    score = model_1.evaluate(x_test, y_test, verbose=0)

    # plot #
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])
    plot_history(history_1, 'SGD (lr={0}) : Learning Curve and Accuracy'.format(l_r[i]))
    plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_430 (Dense)            (None, 64)                16448
# _________________________________________________________________
# dense_431 (Dense)            (None, 5)                 325
# =================================================================
# Total params: 16,773
# Trainable params: 16,773
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 1.50170211241
# Test accuracy: 0.392423046567
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_432 (Dense)            (None, 64)                16448
# _________________________________________________________________
# dense_433 (Dense)            (None, 5)                 325
# =================================================================
# Total params: 16,773
# Trainable params: 16,773
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.913583164311
# Test accuracy: 0.693922651924
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_434 (Dense)            (None, 64)                16448
# _________________________________________________________________
# dense_435 (Dense)            (None, 5)                 325
# =================================================================
# Total params: 16,773
# Trainable params: 16,773
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.609368521798
# Test accuracy: 0.817758484553
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_436 (Dense)            (None, 64)                16448
# _________________________________________________________________
# dense_437 (Dense)            (None, 5)                 325
# =================================================================
# Total params: 16,773
# Trainable params: 16,773
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.518755670966
# Test accuracy: 0.85698500389
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_438 (Dense)            (None, 64)                16448
# _________________________________________________________________
# dense_439 (Dense)            (None, 5)                 325
# =================================================================
# Total params: 16,773
# Trainable params: 16,773
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.535975884606
# Test accuracy: 0.867719021263
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_440 (Dense)            (None, 64)                16448
# _________________________________________________________________
# dense_441 (Dense)            (None, 5)                 325
# =================================================================
# Total params: 16,773
# Trainable params: 16,773
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.654688015677
# Test accuracy: 0.822573007047

# %% [markdown]
# **Question**: What happens if the learning rate of SGD is A) very large B) very small? Please answer A) and B) with one full sentence (double click this markdown cell to edit).
#
# **Answer**:
#
# A) Very Large : The validation curve is sensitive to a noise. In fact with a huge learning rate, the set of validation data is not enough big to allow the validation curve to escape the noise. Moreover, we can see a difference in validation and training which is normal (we want to see that)
#
# B) Very small : We can see that there are no difference between training and validation curve. In fact, with 50 epochs and a little learning rate, the model has not the time to learn well.

# %%
#SGD for the graph with lr=0.05#
model_1 = Sequential()
model_1.add(Dense(64, activation='relu', input_shape=x_train.shape[1:]))
model_1.add(Dense(5, activation='softmax'))

model_1.summary()

model_1.compile(loss='categorical_crossentropy',
          optimizer=keras.optimizers.SGD(lr=0.05),
          metrics=['accuracy'])

history_sgd = model_1.fit(x_train, y_train,
                    batch_size=128,
                    epochs=50,
                    verbose=0,
                    validation_data=(x_test, y_test))

score = model_1.evaluate(x_test, y_test, verbose=0)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_442 (Dense)            (None, 64)                16448
# _________________________________________________________________
# dense_443 (Dense)            (None, 5)                 325
# =================================================================
# Total params: 16,773
# Trainable params: 16,773
# Non-trainable params: 0
# _________________________________________________________________

# %%
### ADAM OPTIMIZER Question 3 ###
model_adam = Sequential()
model_adam.add(Dense(64, activation='relu', input_shape=x_train.shape[1:]))
model_adam.add(Dense(5, activation='softmax'))

model_adam.summary()

model_adam.compile(loss='categorical_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])

history_adam = model_adam.fit(x_train, y_train,
                    batch_size=128,
                    epochs=50,
                    verbose=1,
                    validation_data=(x_test, y_test))

score = model_adam.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
plot_history(history_adam, 'Adam : Learning Curve and Accuracy')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_444 (Dense)            (None, 64)                16448
# _________________________________________________________________
# dense_445 (Dense)            (None, 5)                 325
# =================================================================
# Total params: 16,773
# Trainable params: 16,773
# Non-trainable params: 0
# _________________________________________________________________
# Train on 35179 samples, validate on 12670 samples
# Epoch 1/50
# 35179/35179 [==============================] - 0s - loss: 1.4411 - acc: 0.4140 - val_loss: 1.2087 - val_acc: 0.5617
# Epoch 2/50
# 35179/35179 [==============================] - 0s - loss: 1.0374 - acc: 0.6612 - val_loss: 0.9353 - val_acc: 0.6916
# Epoch 3/50
# 35179/35179 [==============================] - 0s - loss: 0.8345 - acc: 0.7429 - val_loss: 0.8410 - val_acc: 0.7269
# Epoch 4/50
# 35179/35179 [==============================] - 0s - loss: 0.7453 - acc: 0.7736 - val_loss: 0.7928 - val_acc: 0.7470
# Epoch 5/50
# 35179/35179 [==============================] - 0s - loss: 0.6964 - acc: 0.7880 - val_loss: 0.7777 - val_acc: 0.7554
# Epoch 6/50
# 35179/35179 [==============================] - 0s - loss: 0.6640 - acc: 0.7976 - val_loss: 0.7698 - val_acc: 0.7593
# Epoch 7/50
# 35179/35179 [==============================] - 0s - loss: 0.6390 - acc: 0.8041 - val_loss: 0.7463 - val_acc: 0.7667
# Epoch 8/50
# 35179/35179 [==============================] - 0s - loss: 0.6189 - acc: 0.8108 - val_loss: 0.7291 - val_acc: 0.7757
# Epoch 9/50
# 35179/35179 [==============================] - 0s - loss: 0.5996 - acc: 0.8149 - val_loss: 0.7162 - val_acc: 0.7763
# Epoch 10/50
# 35179/35179 [==============================] - 0s - loss: 0.5856 - acc: 0.8217 - val_loss: 0.6986 - val_acc: 0.7851
# Epoch 11/50
# 35179/35179 [==============================] - 0s - loss: 0.5700 - acc: 0.8266 - val_loss: 0.6778 - val_acc: 0.7949
# Epoch 12/50
# 35179/35179 [==============================] - 0s - loss: 0.5570 - acc: 0.8287 - val_loss: 0.6585 - val_acc: 0.7995
# Epoch 13/50
# 35179/35179 [==============================] - 0s - loss: 0.5459 - acc: 0.8358 - val_loss: 0.6527 - val_acc: 0.8017
# Epoch 14/50
# 35179/35179 [==============================] - 0s - loss: 0.5326 - acc: 0.8393 - val_loss: 0.6339 - val_acc: 0.8090
# Epoch 15/50
# 35179/35179 [==============================] - 0s - loss: 0.5185 - acc: 0.8429 - val_loss: 0.6284 - val_acc: 0.8129
# Epoch 16/50
# 35179/35179 [==============================] - 0s - loss: 0.5075 - acc: 0.8476 - val_loss: 0.6219 - val_acc: 0.8189
# Epoch 17/50
# 35179/35179 [==============================] - 0s - loss: 0.4958 - acc: 0.8503 - val_loss: 0.6087 - val_acc: 0.8200
# Epoch 18/50
# 35179/35179 [==============================] - 0s - loss: 0.4866 - acc: 0.8531 - val_loss: 0.5906 - val_acc: 0.8296
# Epoch 19/50
# 35179/35179 [==============================] - 0s - loss: 0.4798 - acc: 0.8551 - val_loss: 0.5896 - val_acc: 0.8257
# Epoch 20/50
# 35179/35179 [==============================] - 0s - loss: 0.4694 - acc: 0.8593 - val_loss: 0.5817 - val_acc: 0.8353
# Epoch 21/50
# 35179/35179 [==============================] - 0s - loss: 0.4599 - acc: 0.8624 - val_loss: 0.5662 - val_acc: 0.8381
# Epoch 22/50
# 35179/35179 [==============================] - 0s - loss: 0.4506 - acc: 0.8666 - val_loss: 0.5598 - val_acc: 0.8426
# Epoch 23/50
# 35179/35179 [==============================] - 0s - loss: 0.4440 - acc: 0.8659 - val_loss: 0.5743 - val_acc: 0.8386
# Epoch 24/50
# 35179/35179 [==============================] - 0s - loss: 0.4386 - acc: 0.8707 - val_loss: 0.5627 - val_acc: 0.8429
# Epoch 25/50
# 35179/35179 [==============================] - 0s - loss: 0.4318 - acc: 0.8737 - val_loss: 0.5504 - val_acc: 0.8475
# Epoch 26/50
# 35179/35179 [==============================] - 0s - loss: 0.4238 - acc: 0.8751 - val_loss: 0.5388 - val_acc: 0.8497
# Epoch 27/50
# 35179/35179 [==============================] - 0s - loss: 0.4189 - acc: 0.8757 - val_loss: 0.5600 - val_acc: 0.8443
# Epoch 28/50
# 35179/35179 [==============================] - 0s - loss: 0.4126 - acc: 0.8775 - val_loss: 0.5421 - val_acc: 0.8504
# Epoch 29/50
# 35179/35179 [==============================] - 0s - loss: 0.4049 - acc: 0.8800 - val_loss: 0.5282 - val_acc: 0.8548
# Epoch 30/50
# 35179/35179 [==============================] - 0s - loss: 0.3985 - acc: 0.8831 - val_loss: 0.5250 - val_acc: 0.8557
# Epoch 31/50
# 35179/35179 [==============================] - 0s - loss: 0.3980 - acc: 0.8828 - val_loss: 0.5172 - val_acc: 0.8568
# Epoch 32/50
# 35179/35179 [==============================] - 0s - loss: 0.3892 - acc: 0.8850 - val_loss: 0.5145 - val_acc: 0.8603
# Epoch 33/50
# 35179/35179 [==============================] - 0s - loss: 0.3853 - acc: 0.8857 - val_loss: 0.5299 - val_acc: 0.8556
# Epoch 34/50
# 35179/35179 [==============================] - 0s - loss: 0.3806 - acc: 0.8873 - val_loss: 0.5200 - val_acc: 0.8597
# Epoch 35/50
# 35179/35179 [==============================] - 0s - loss: 0.3761 - acc: 0.8886 - val_loss: 0.5102 - val_acc: 0.8627
# Epoch 36/50
# 35179/35179 [==============================] - 0s - loss: 0.3706 - acc: 0.8901 - val_loss: 0.5187 - val_acc: 0.8598
# Epoch 37/50
# 35179/35179 [==============================] - 0s - loss: 0.3699 - acc: 0.8910 - val_loss: 0.5117 - val_acc: 0.8630
# Epoch 38/50
# 35179/35179 [==============================] - 0s - loss: 0.3623 - acc: 0.8940 - val_loss: 0.5093 - val_acc: 0.8647
# Epoch 39/50
# 35179/35179 [==============================] - 0s - loss: 0.3620 - acc: 0.8924 - val_loss: 0.5371 - val_acc: 0.8569
# Epoch 40/50
# 35179/35179 [==============================] - 0s - loss: 0.3583 - acc: 0.8945 - val_loss: 0.5144 - val_acc: 0.8634
# Epoch 41/50
# 35179/35179 [==============================] - 0s - loss: 0.3538 - acc: 0.8953 - val_loss: 0.5026 - val_acc: 0.8669
# Epoch 42/50
# 35179/35179 [==============================] - 0s - loss: 0.3521 - acc: 0.8961 - val_loss: 0.4961 - val_acc: 0.8691
# Epoch 43/50
# 35179/35179 [==============================] - 0s - loss: 0.3458 - acc: 0.8985 - val_loss: 0.4964 - val_acc: 0.8693
# Epoch 44/50
# 35179/35179 [==============================] - 0s - loss: 0.3429 - acc: 0.8997 - val_loss: 0.5288 - val_acc: 0.8605
# Epoch 45/50
# 35179/35179 [==============================] - 0s - loss: 0.3421 - acc: 0.8990 - val_loss: 0.5183 - val_acc: 0.8630
# Epoch 46/50
# 35179/35179 [==============================] - 0s - loss: 0.3389 - acc: 0.8997 - val_loss: 0.4941 - val_acc: 0.8723
# Epoch 47/50
# 35179/35179 [==============================] - 0s - loss: 0.3321 - acc: 0.9028 - val_loss: 0.4975 - val_acc: 0.8737
# Epoch 48/50
# 35179/35179 [==============================] - 0s - loss: 0.3303 - acc: 0.9032 - val_loss: 0.4914 - val_acc: 0.8740
# Epoch 49/50
# 35179/35179 [==============================] - 0s - loss: 0.3288 - acc: 0.9035 - val_loss: 0.5197 - val_acc: 0.8639
# Epoch 50/50
# 35179/35179 [==============================] - 0s - loss: 0.3285 - acc: 0.9022 - val_loss: 0.4913 - val_acc: 0.8744
# Test loss: 0.491300743211
# Test accuracy: 0.874427782172

# %%
### Question 4: Graph of SGD and ADAM ###

### Plot with the 2 model###
def plot_history_2(history_adam,history_sgd, title):
    fig, ax1, ax2 = prepare_standardplot(title, 'epoch')
    ax1.plot(history_adam.history['loss'], label = "Training_loss_adam")
    ax1.plot(history_adam.history['val_loss'], label = "Validation_loss_adam")
    ax2.plot(history_adam.history['acc'], label = "Training_accuracy_adam")
    ax2.plot(history_adam.history['val_acc'], label = "Validation_accuracy_adam")
    ax1.plot(history_sgd.history['loss'], label = "Training_loss_sgd_lr=0.05")
    ax1.plot(history_sgd.history['val_loss'], label = "Validation_loss_sgd_lr=0.05")
    ax2.plot(history_sgd.history['acc'], label = "Training_accuracy_sgd_lr=0.05")
    ax2.plot(history_sgd.history['val_acc'], label = "Validation_accuracy_sgd_lr=0.05")
    finalize_standardplot(fig, ax1, ax2)
    return fig

plot_history_2(history_adam,history_sgd,'Learning Curve and Accuracy for SGD and Adam optimizer')

# %% [markdown]
# ## Exercise 3: Overfitting and early stopping with Adam
#
# ### Description
#
# Run the above simulation with Adam for sufficiently many epochs (be patient!) until you see clear overfitting.
#
# 1. Plot the learning curves of a fit with Adam and sufficiently many epochs and answer the questions below.
#
# A simple, but effective mean to avoid overfitting is early stopping, i.e. a fit is not run until convergence but stopped as soon as the validation error starts to increase. We will use early stopping in all subsequent exercises.
#
# ### Solution

# %%
### ADAM OPTIMIZER ###
model_adam = Sequential()
model_adam.add(Dense(64, activation='relu', input_shape=x_train.shape[1:]))
model_adam.add(Dense(5, activation='softmax'))

model_adam.summary()

model_adam.compile(loss='categorical_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])

history_adam = model_adam.fit(x_train, y_train,
                    batch_size=128,
                    epochs=200,
                    verbose=1,
                    validation_data=(x_test, y_test))

score = model_adam.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
plot_history(history_adam, 'Adam optimizer : Loss and Accuracy')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_446 (Dense)            (None, 64)                16448
# _________________________________________________________________
# dense_447 (Dense)            (None, 5)                 325
# =================================================================
# Total params: 16,773
# Trainable params: 16,773
# Non-trainable params: 0
# _________________________________________________________________
# Train on 35179 samples, validate on 12670 samples
# Epoch 1/200
# 35179/35179 [==============================] - 0s - loss: 1.4103 - acc: 0.4364 - val_loss: 1.1687 - val_acc: 0.5586
# Epoch 2/200
# 35179/35179 [==============================] - 0s - loss: 1.0008 - acc: 0.6657 - val_loss: 0.9235 - val_acc: 0.6999
# Epoch 3/200
# 35179/35179 [==============================] - 0s - loss: 0.8232 - acc: 0.7417 - val_loss: 0.8394 - val_acc: 0.7331
# Epoch 4/200
# 35179/35179 [==============================] - 0s - loss: 0.7425 - acc: 0.7694 - val_loss: 0.8310 - val_acc: 0.7384
# Epoch 5/200
# 35179/35179 [==============================] - 0s - loss: 0.6986 - acc: 0.7834 - val_loss: 0.7868 - val_acc: 0.7519
# Epoch 6/200
# 35179/35179 [==============================] - 0s - loss: 0.6651 - acc: 0.7937 - val_loss: 0.7587 - val_acc: 0.7590
# Epoch 7/200
# 35179/35179 [==============================] - 0s - loss: 0.6370 - acc: 0.8032 - val_loss: 0.7465 - val_acc: 0.7680
# Epoch 8/200
# 35179/35179 [==============================] - 0s - loss: 0.6152 - acc: 0.8100 - val_loss: 0.7071 - val_acc: 0.7775
# Epoch 9/200
# 35179/35179 [==============================] - 0s - loss: 0.5989 - acc: 0.8156 - val_loss: 0.7072 - val_acc: 0.7824
# Epoch 10/200
# 35179/35179 [==============================] - 0s - loss: 0.5791 - acc: 0.8224 - val_loss: 0.6974 - val_acc: 0.7790
# Epoch 11/200
# 35179/35179 [==============================] - 0s - loss: 0.5650 - acc: 0.8255 - val_loss: 0.6676 - val_acc: 0.7947
# Epoch 12/200
# 35179/35179 [==============================] - 0s - loss: 0.5524 - acc: 0.8312 - val_loss: 0.6514 - val_acc: 0.8013
# Epoch 13/200
# 35179/35179 [==============================] - 0s - loss: 0.5378 - acc: 0.8371 - val_loss: 0.6386 - val_acc: 0.8079
# Epoch 14/200
# 35179/35179 [==============================] - 0s - loss: 0.5226 - acc: 0.8410 - val_loss: 0.6386 - val_acc: 0.8075
# Epoch 15/200
# 35179/35179 [==============================] - 0s - loss: 0.5140 - acc: 0.8433 - val_loss: 0.6030 - val_acc: 0.8187
# Epoch 16/200
# 35179/35179 [==============================] - 0s - loss: 0.4991 - acc: 0.8503 - val_loss: 0.6053 - val_acc: 0.8183
# Epoch 17/200
# 35179/35179 [==============================] - 1s - loss: 0.4867 - acc: 0.8543 - val_loss: 0.5941 - val_acc: 0.8227
# Epoch 18/200
# 35179/35179 [==============================] - 1s - loss: 0.4788 - acc: 0.8566 - val_loss: 0.5868 - val_acc: 0.8292
# Epoch 19/200
# 35179/35179 [==============================] - 1s - loss: 0.4682 - acc: 0.8595 - val_loss: 0.5770 - val_acc: 0.8305
# Epoch 20/200
# 35179/35179 [==============================] - 1s - loss: 0.4593 - acc: 0.8632 - val_loss: 0.5746 - val_acc: 0.8329
# Epoch 21/200
# 35179/35179 [==============================] - 1s - loss: 0.4547 - acc: 0.8624 - val_loss: 0.5627 - val_acc: 0.8358
# Epoch 22/200
# 35179/35179 [==============================] - 1s - loss: 0.4426 - acc: 0.8696 - val_loss: 0.5471 - val_acc: 0.8430
# Epoch 23/200
# 35179/35179 [==============================] - 1s - loss: 0.4372 - acc: 0.8706 - val_loss: 0.5529 - val_acc: 0.8403
# Epoch 24/200
# 35179/35179 [==============================] - 1s - loss: 0.4273 - acc: 0.8735 - val_loss: 0.5425 - val_acc: 0.8474
# Epoch 25/200
# 35179/35179 [==============================] - 0s - loss: 0.4227 - acc: 0.8744 - val_loss: 0.5340 - val_acc: 0.8474
# Epoch 26/200
# 35179/35179 [==============================] - 1s - loss: 0.4141 - acc: 0.8770 - val_loss: 0.5383 - val_acc: 0.8504
# Epoch 27/200
# 35179/35179 [==============================] - 1s - loss: 0.4090 - acc: 0.8794 - val_loss: 0.5348 - val_acc: 0.8500
# Epoch 28/200
# 35179/35179 [==============================] - 1s - loss: 0.4038 - acc: 0.8812 - val_loss: 0.5233 - val_acc: 0.8544
# Epoch 29/200
# 35179/35179 [==============================] - 1s - loss: 0.3977 - acc: 0.8826 - val_loss: 0.5332 - val_acc: 0.8540
# Epoch 30/200
# 35179/35179 [==============================] - 1s - loss: 0.3953 - acc: 0.8840 - val_loss: 0.5113 - val_acc: 0.8585
# Epoch 31/200
# 35179/35179 [==============================] - 1s - loss: 0.3887 - acc: 0.8845 - val_loss: 0.5093 - val_acc: 0.8591
# Epoch 32/200
# 35179/35179 [==============================] - 1s - loss: 0.3789 - acc: 0.8890 - val_loss: 0.4989 - val_acc: 0.8637
# Epoch 33/200
# 35179/35179 [==============================] - 1s - loss: 0.3749 - acc: 0.8898 - val_loss: 0.5034 - val_acc: 0.8632
# Epoch 34/200
# 35179/35179 [==============================] - 0s - loss: 0.3736 - acc: 0.8904 - val_loss: 0.5027 - val_acc: 0.8620
# Epoch 35/200
# 35179/35179 [==============================] - 1s - loss: 0.3696 - acc: 0.8917 - val_loss: 0.4987 - val_acc: 0.8672
# Epoch 36/200
# 35179/35179 [==============================] - 1s - loss: 0.3636 - acc: 0.8930 - val_loss: 0.4962 - val_acc: 0.8684
# Epoch 37/200
# 35179/35179 [==============================] - 0s - loss: 0.3596 - acc: 0.8947 - val_loss: 0.4951 - val_acc: 0.8674
# Epoch 38/200
# 35179/35179 [==============================] - 0s - loss: 0.3548 - acc: 0.8950 - val_loss: 0.4945 - val_acc: 0.8660
# Epoch 39/200
# 35179/35179 [==============================] - 1s - loss: 0.3499 - acc: 0.8978 - val_loss: 0.4897 - val_acc: 0.8702
# Epoch 40/200
# 35179/35179 [==============================] - 1s - loss: 0.3500 - acc: 0.8961 - val_loss: 0.4958 - val_acc: 0.8695
# Epoch 41/200
# 35179/35179 [==============================] - 0s - loss: 0.3460 - acc: 0.8992 - val_loss: 0.5023 - val_acc: 0.8675
# Epoch 42/200
# 35179/35179 [==============================] - 1s - loss: 0.3409 - acc: 0.9000 - val_loss: 0.5011 - val_acc: 0.8704
# Epoch 43/200
# 35179/35179 [==============================] - 1s - loss: 0.3368 - acc: 0.9004 - val_loss: 0.5012 - val_acc: 0.8670
# Epoch 44/200
# 35179/35179 [==============================] - 1s - loss: 0.3341 - acc: 0.9002 - val_loss: 0.4837 - val_acc: 0.8743
# Epoch 45/200
# 35179/35179 [==============================] - 1s - loss: 0.3318 - acc: 0.9016 - val_loss: 0.4862 - val_acc: 0.8740
# Epoch 46/200
# 35179/35179 [==============================] - 1s - loss: 0.3272 - acc: 0.9042 - val_loss: 0.4900 - val_acc: 0.8707
# Epoch 47/200
# 35179/35179 [==============================] - 1s - loss: 0.3262 - acc: 0.9031 - val_loss: 0.4775 - val_acc: 0.8737
# Epoch 48/200
# 35179/35179 [==============================] - 1s - loss: 0.3221 - acc: 0.9051 - val_loss: 0.4792 - val_acc: 0.8764
# Epoch 49/200
# 35179/35179 [==============================] - 1s - loss: 0.3220 - acc: 0.9050 - val_loss: 0.4757 - val_acc: 0.8788
# Epoch 50/200
# 35179/35179 [==============================] - 1s - loss: 0.3194 - acc: 0.9053 - val_loss: 0.4887 - val_acc: 0.8746
# Epoch 51/200
# 35179/35179 [==============================] - 1s - loss: 0.3142 - acc: 0.9068 - val_loss: 0.4828 - val_acc: 0.8773
# Epoch 52/200
# 35179/35179 [==============================] - 0s - loss: 0.3128 - acc: 0.9074 - val_loss: 0.4740 - val_acc: 0.8788
# Epoch 53/200
# 35179/35179 [==============================] - 0s - loss: 0.3112 - acc: 0.9083 - val_loss: 0.4918 - val_acc: 0.8757
# Epoch 54/200
# 35179/35179 [==============================] - 1s - loss: 0.3059 - acc: 0.9090 - val_loss: 0.4839 - val_acc: 0.8758
# Epoch 55/200
# 35179/35179 [==============================] - 1s - loss: 0.3051 - acc: 0.9096 - val_loss: 0.4801 - val_acc: 0.8779
# Epoch 56/200
# 35179/35179 [==============================] - 1s - loss: 0.3024 - acc: 0.9107 - val_loss: 0.4787 - val_acc: 0.8781
# Epoch 57/200
# 35179/35179 [==============================] - 1s - loss: 0.2988 - acc: 0.9118 - val_loss: 0.4868 - val_acc: 0.8743
# Epoch 58/200
# 35179/35179 [==============================] - 1s - loss: 0.2988 - acc: 0.9117 - val_loss: 0.5068 - val_acc: 0.8706
# Epoch 59/200
# 35179/35179 [==============================] - 1s - loss: 0.2968 - acc: 0.9120 - val_loss: 0.4908 - val_acc: 0.8761
# Epoch 60/200
# 35179/35179 [==============================] - 1s - loss: 0.2973 - acc: 0.9125 - val_loss: 0.5159 - val_acc: 0.8687
# Epoch 61/200
# 35179/35179 [==============================] - 0s - loss: 0.2903 - acc: 0.9123 - val_loss: 0.4824 - val_acc: 0.8785
# Epoch 62/200
# 35179/35179 [==============================] - 0s - loss: 0.2885 - acc: 0.9144 - val_loss: 0.4797 - val_acc: 0.8815
# Epoch 63/200
# 35179/35179 [==============================] - 0s - loss: 0.2903 - acc: 0.9136 - val_loss: 0.4794 - val_acc: 0.8788
# Epoch 64/200
# 35179/35179 [==============================] - 1s - loss: 0.2854 - acc: 0.9148 - val_loss: 0.5258 - val_acc: 0.8667
# Epoch 65/200
# 35179/35179 [==============================] - 1s - loss: 0.2845 - acc: 0.9157 - val_loss: 0.4782 - val_acc: 0.8817
# Epoch 66/200
# 35179/35179 [==============================] - 1s - loss: 0.2821 - acc: 0.9168 - val_loss: 0.4811 - val_acc: 0.8777
# Epoch 67/200
# 35179/35179 [==============================] - 1s - loss: 0.2816 - acc: 0.9165 - val_loss: 0.4798 - val_acc: 0.8815
# Epoch 68/200
# 35179/35179 [==============================] - 1s - loss: 0.2827 - acc: 0.9148 - val_loss: 0.4718 - val_acc: 0.8845
# Epoch 69/200
# 35179/35179 [==============================] - 1s - loss: 0.2778 - acc: 0.9182 - val_loss: 0.4872 - val_acc: 0.8797
# Epoch 70/200
# 35179/35179 [==============================] - 0s - loss: 0.2745 - acc: 0.9175 - val_loss: 0.4819 - val_acc: 0.8823
# Epoch 71/200
# 35179/35179 [==============================] - 1s - loss: 0.2725 - acc: 0.9192 - val_loss: 0.4784 - val_acc: 0.8818
# Epoch 72/200
# 35179/35179 [==============================] - 1s - loss: 0.2731 - acc: 0.9198 - val_loss: 0.4721 - val_acc: 0.8854
# Epoch 73/200
# 35179/35179 [==============================] - 1s - loss: 0.2709 - acc: 0.9175 - val_loss: 0.4796 - val_acc: 0.8826
# Epoch 74/200
# 35179/35179 [==============================] - 1s - loss: 0.2655 - acc: 0.9206 - val_loss: 0.4805 - val_acc: 0.8845
# Epoch 75/200
# 35179/35179 [==============================] - 1s - loss: 0.2663 - acc: 0.9195 - val_loss: 0.4806 - val_acc: 0.8829
# Epoch 76/200
# 35179/35179 [==============================] - 1s - loss: 0.2650 - acc: 0.9205 - val_loss: 0.4991 - val_acc: 0.8804
# Epoch 77/200
# 35179/35179 [==============================] - 1s - loss: 0.2650 - acc: 0.9217 - val_loss: 0.4932 - val_acc: 0.8782
# Epoch 78/200
# 35179/35179 [==============================] - 1s - loss: 0.2637 - acc: 0.9208 - val_loss: 0.4814 - val_acc: 0.8848
# Epoch 79/200
# 35179/35179 [==============================] - 1s - loss: 0.2623 - acc: 0.9205 - val_loss: 0.4986 - val_acc: 0.8806
# Epoch 80/200
# 35179/35179 [==============================] - 1s - loss: 0.2598 - acc: 0.9226 - val_loss: 0.4973 - val_acc: 0.8798
# Epoch 81/200
# 35179/35179 [==============================] - 1s - loss: 0.2601 - acc: 0.9215 - val_loss: 0.4766 - val_acc: 0.8859
# Epoch 82/200
# 35179/35179 [==============================] - 0s - loss: 0.2562 - acc: 0.9225 - val_loss: 0.4950 - val_acc: 0.8827
# Epoch 83/200
# 35179/35179 [==============================] - 1s - loss: 0.2569 - acc: 0.9222 - val_loss: 0.4901 - val_acc: 0.8829
# Epoch 84/200
# 35179/35179 [==============================] - 1s - loss: 0.2551 - acc: 0.9230 - val_loss: 0.4763 - val_acc: 0.8863
# Epoch 85/200
# 35179/35179 [==============================] - 1s - loss: 0.2541 - acc: 0.9229 - val_loss: 0.4861 - val_acc: 0.8852
# Epoch 86/200
# 35179/35179 [==============================] - 1s - loss: 0.2475 - acc: 0.9261 - val_loss: 0.4777 - val_acc: 0.8872
# Epoch 87/200
# 35179/35179 [==============================] - 1s - loss: 0.2499 - acc: 0.9255 - val_loss: 0.4827 - val_acc: 0.8848
# Epoch 88/200
# 35179/35179 [==============================] - 1s - loss: 0.2472 - acc: 0.9260 - val_loss: 0.5018 - val_acc: 0.8819
# Epoch 89/200
# 35179/35179 [==============================] - 1s - loss: 0.2479 - acc: 0.9249 - val_loss: 0.4797 - val_acc: 0.8871
# Epoch 90/200
# 35179/35179 [==============================] - 1s - loss: 0.2464 - acc: 0.9255 - val_loss: 0.4816 - val_acc: 0.8869
# Epoch 91/200
# 35179/35179 [==============================] - 1s - loss: 0.2444 - acc: 0.9271 - val_loss: 0.4739 - val_acc: 0.8885
# Epoch 92/200
# 35179/35179 [==============================] - 1s - loss: 0.2410 - acc: 0.9273 - val_loss: 0.4884 - val_acc: 0.8860
# Epoch 93/200
# 35179/35179 [==============================] - 1s - loss: 0.2387 - acc: 0.9278 - val_loss: 0.4869 - val_acc: 0.8862
# Epoch 94/200
# 35179/35179 [==============================] - 1s - loss: 0.2440 - acc: 0.9269 - val_loss: 0.4773 - val_acc: 0.8897
# Epoch 95/200
# 35179/35179 [==============================] - 1s - loss: 0.2383 - acc: 0.9273 - val_loss: 0.4785 - val_acc: 0.8871
# Epoch 96/200
# 35179/35179 [==============================] - 1s - loss: 0.2393 - acc: 0.9277 - val_loss: 0.5087 - val_acc: 0.8833
# Epoch 97/200
# 35179/35179 [==============================] - 0s - loss: 0.2442 - acc: 0.9259 - val_loss: 0.5059 - val_acc: 0.8824
# Epoch 98/200
# 35179/35179 [==============================] - 1s - loss: 0.2381 - acc: 0.9275 - val_loss: 0.4857 - val_acc: 0.8867
# Epoch 99/200
# 35179/35179 [==============================] - 1s - loss: 0.2359 - acc: 0.9280 - val_loss: 0.4821 - val_acc: 0.8900
# Epoch 100/200
# 35179/35179 [==============================] - 1s - loss: 0.2358 - acc: 0.9283 - val_loss: 0.5010 - val_acc: 0.8841
# Epoch 101/200
# 35179/35179 [==============================] - 1s - loss: 0.2362 - acc: 0.9284 - val_loss: 0.4920 - val_acc: 0.8862
# Epoch 102/200
# 35179/35179 [==============================] - 1s - loss: 0.2372 - acc: 0.9283 - val_loss: 0.4855 - val_acc: 0.8882
# Epoch 103/200
# 35179/35179 [==============================] - 1s - loss: 0.2324 - acc: 0.9290 - val_loss: 0.4897 - val_acc: 0.8854
# Epoch 104/200
# 35179/35179 [==============================] - 1s - loss: 0.2302 - acc: 0.9304 - val_loss: 0.4915 - val_acc: 0.8863
# Epoch 105/200
# 35179/35179 [==============================] - 1s - loss: 0.2308 - acc: 0.9287 - val_loss: 0.4867 - val_acc: 0.8897
# Epoch 106/200
# 35179/35179 [==============================] - 1s - loss: 0.2265 - acc: 0.9316 - val_loss: 0.4975 - val_acc: 0.8872
# Epoch 107/200
# 35179/35179 [==============================] - 1s - loss: 0.2258 - acc: 0.9312 - val_loss: 0.4911 - val_acc: 0.8855
# Epoch 108/200
# 35179/35179 [==============================] - 1s - loss: 0.2244 - acc: 0.9327 - val_loss: 0.4905 - val_acc: 0.8860
# Epoch 109/200
# 35179/35179 [==============================] - 1s - loss: 0.2247 - acc: 0.9322 - val_loss: 0.4877 - val_acc: 0.8911
# Epoch 110/200
# 35179/35179 [==============================] - 0s - loss: 0.2241 - acc: 0.9324 - val_loss: 0.4969 - val_acc: 0.8889
# Epoch 111/200
# 35179/35179 [==============================] - 1s - loss: 0.2220 - acc: 0.9319 - val_loss: 0.4926 - val_acc: 0.8898
# Epoch 112/200
# 35179/35179 [==============================] - 1s - loss: 0.2242 - acc: 0.9318 - val_loss: 0.4938 - val_acc: 0.8877
# Epoch 113/200
# 35179/35179 [==============================] - 1s - loss: 0.2251 - acc: 0.9318 - val_loss: 0.4907 - val_acc: 0.8886
# Epoch 114/200
# 35179/35179 [==============================] - 1s - loss: 0.2268 - acc: 0.9309 - val_loss: 0.5044 - val_acc: 0.8848
# Epoch 115/200
# 35179/35179 [==============================] - 1s - loss: 0.2226 - acc: 0.9321 - val_loss: 0.4930 - val_acc: 0.8878
# Epoch 116/200
# 35179/35179 [==============================] - 1s - loss: 0.2180 - acc: 0.9339 - val_loss: 0.5081 - val_acc: 0.8886
# Epoch 117/200
# 35179/35179 [==============================] - 1s - loss: 0.2193 - acc: 0.9331 - val_loss: 0.5444 - val_acc: 0.8774
# Epoch 118/200
# 35179/35179 [==============================] - 1s - loss: 0.2177 - acc: 0.9345 - val_loss: 0.4976 - val_acc: 0.8904
# Epoch 119/200
# 35179/35179 [==============================] - 1s - loss: 0.2181 - acc: 0.9324 - val_loss: 0.4901 - val_acc: 0.8923
# Epoch 120/200
# 35179/35179 [==============================] - 1s - loss: 0.2165 - acc: 0.9337 - val_loss: 0.4981 - val_acc: 0.8892
# Epoch 121/200
# 35179/35179 [==============================] - 1s - loss: 0.2155 - acc: 0.9337 - val_loss: 0.5105 - val_acc: 0.8860
# Epoch 122/200
# 35179/35179 [==============================] - 0s - loss: 0.2151 - acc: 0.9344 - val_loss: 0.5080 - val_acc: 0.8873
# Epoch 123/200
# 35179/35179 [==============================] - 0s - loss: 0.2127 - acc: 0.9353 - val_loss: 0.5077 - val_acc: 0.8876
# Epoch 124/200
# 35179/35179 [==============================] - 0s - loss: 0.2125 - acc: 0.9342 - val_loss: 0.5073 - val_acc: 0.8873
# Epoch 125/200
# 35179/35179 [==============================] - 0s - loss: 0.2129 - acc: 0.9347 - val_loss: 0.5002 - val_acc: 0.8905
# Epoch 126/200
# 35179/35179 [==============================] - 1s - loss: 0.2123 - acc: 0.9350 - val_loss: 0.4996 - val_acc: 0.8897
# Epoch 127/200
# 35179/35179 [==============================] - 1s - loss: 0.2120 - acc: 0.9348 - val_loss: 0.5005 - val_acc: 0.8886
# Epoch 128/200
# 35179/35179 [==============================] - 1s - loss: 0.2127 - acc: 0.9341 - val_loss: 0.5084 - val_acc: 0.8888
# Epoch 129/200
# 35179/35179 [==============================] - 0s - loss: 0.2110 - acc: 0.9366 - val_loss: 0.4997 - val_acc: 0.8898
# Epoch 130/200
# 35179/35179 [==============================] - 0s - loss: 0.2106 - acc: 0.9346 - val_loss: 0.5061 - val_acc: 0.8904
# Epoch 131/200
# 35179/35179 [==============================] - 0s - loss: 0.2101 - acc: 0.9354 - val_loss: 0.5252 - val_acc: 0.8855
# Epoch 132/200
# 35179/35179 [==============================] - 0s - loss: 0.2083 - acc: 0.9359 - val_loss: 0.5284 - val_acc: 0.8870
# Epoch 133/200
# 35179/35179 [==============================] - ETA: 0s - loss: 0.2040 - acc: 0.937 - 0s - loss: 0.2050 - acc: 0.9373 - val_loss: 0.5068 - val_acc: 0.8893
# Epoch 134/200
# 35179/35179 [==============================] - 0s - loss: 0.2060 - acc: 0.9377 - val_loss: 0.5050 - val_acc: 0.8895
# Epoch 135/200
# 35179/35179 [==============================] - 0s - loss: 0.2058 - acc: 0.9378 - val_loss: 0.5168 - val_acc: 0.8885
# Epoch 136/200
# 35179/35179 [==============================] - 0s - loss: 0.2078 - acc: 0.9354 - val_loss: 0.5029 - val_acc: 0.8906
# Epoch 137/200
# 35179/35179 [==============================] - 0s - loss: 0.2038 - acc: 0.9368 - val_loss: 0.5116 - val_acc: 0.8882
# Epoch 138/200
# 35179/35179 [==============================] - 0s - loss: 0.2031 - acc: 0.9378 - val_loss: 0.5099 - val_acc: 0.8901
# Epoch 139/200
# 35179/35179 [==============================] - 0s - loss: 0.2073 - acc: 0.9368 - val_loss: 0.5067 - val_acc: 0.8912
# Epoch 140/200
# 35179/35179 [==============================] - 0s - loss: 0.2038 - acc: 0.9383 - val_loss: 0.5060 - val_acc: 0.8911
# Epoch 141/200
# 35179/35179 [==============================] - 0s - loss: 0.2013 - acc: 0.9395 - val_loss: 0.5104 - val_acc: 0.8904
# Epoch 142/200
# 35179/35179 [==============================] - 0s - loss: 0.2012 - acc: 0.9380 - val_loss: 0.5292 - val_acc: 0.8875
# Epoch 143/200
# 35179/35179 [==============================] - 1s - loss: 0.2066 - acc: 0.9355 - val_loss: 0.5142 - val_acc: 0.8900
# Epoch 144/200
# 35179/35179 [==============================] - 1s - loss: 0.1988 - acc: 0.9394 - val_loss: 0.5083 - val_acc: 0.8906
# Epoch 145/200
# 35179/35179 [==============================] - 1s - loss: 0.1994 - acc: 0.9392 - val_loss: 0.5205 - val_acc: 0.8874
# Epoch 146/200
# 35179/35179 [==============================] - 0s - loss: 0.2026 - acc: 0.9385 - val_loss: 0.5201 - val_acc: 0.8879
# Epoch 147/200
# 35179/35179 [==============================] - 0s - loss: 0.1977 - acc: 0.9384 - val_loss: 0.5197 - val_acc: 0.8896
# Epoch 148/200
# 35179/35179 [==============================] - 0s - loss: 0.1972 - acc: 0.9392 - val_loss: 0.5225 - val_acc: 0.8896
# Epoch 149/200
# 35179/35179 [==============================] - 0s - loss: 0.2003 - acc: 0.9371 - val_loss: 0.5095 - val_acc: 0.8919
# Epoch 150/200
# 35179/35179 [==============================] - 0s - loss: 0.2032 - acc: 0.9367 - val_loss: 0.5173 - val_acc: 0.8907
# Epoch 151/200
# 35179/35179 [==============================] - 1s - loss: 0.1986 - acc: 0.9401 - val_loss: 0.5228 - val_acc: 0.8875
# Epoch 152/200
# 35179/35179 [==============================] - 0s - loss: 0.1932 - acc: 0.9411 - val_loss: 0.5259 - val_acc: 0.8864
# Epoch 153/200
# 35179/35179 [==============================] - 1s - loss: 0.1953 - acc: 0.9402 - val_loss: 0.5249 - val_acc: 0.8880
# Epoch 154/200
# 35179/35179 [==============================] - 0s - loss: 0.1949 - acc: 0.9394 - val_loss: 0.5396 - val_acc: 0.8856
# Epoch 155/200
# 35179/35179 [==============================] - 0s - loss: 0.1948 - acc: 0.9403 - val_loss: 0.5221 - val_acc: 0.8890
# Epoch 156/200
# 35179/35179 [==============================] - 0s - loss: 0.1957 - acc: 0.9406 - val_loss: 0.5302 - val_acc: 0.8878
# Epoch 157/200
# 35179/35179 [==============================] - 1s - loss: 0.1917 - acc: 0.9413 - val_loss: 0.5121 - val_acc: 0.8909
# Epoch 158/200
# 35179/35179 [==============================] - 0s - loss: 0.1942 - acc: 0.9408 - val_loss: 0.5172 - val_acc: 0.8898
# Epoch 159/200
# 35179/35179 [==============================] - 0s - loss: 0.1907 - acc: 0.9424 - val_loss: 0.5250 - val_acc: 0.8902
# Epoch 160/200
# 35179/35179 [==============================] - 1s - loss: 0.1899 - acc: 0.9419 - val_loss: 0.5186 - val_acc: 0.8913
# Epoch 161/200
# 35179/35179 [==============================] - 1s - loss: 0.1886 - acc: 0.9427 - val_loss: 0.5313 - val_acc: 0.8872
# Epoch 162/200
# 35179/35179 [==============================] - 1s - loss: 0.1906 - acc: 0.9410 - val_loss: 0.5417 - val_acc: 0.8853
# Epoch 163/200
# 35179/35179 [==============================] - 0s - loss: 0.1936 - acc: 0.9412 - val_loss: 0.5318 - val_acc: 0.8897
# Epoch 164/200
# 35179/35179 [==============================] - 1s - loss: 0.1880 - acc: 0.9423 - val_loss: 0.5446 - val_acc: 0.8843
# Epoch 165/200
# 35179/35179 [==============================] - 1s - loss: 0.1897 - acc: 0.9422 - val_loss: 0.5414 - val_acc: 0.8860
# Epoch 166/200
# 35179/35179 [==============================] - 1s - loss: 0.1863 - acc: 0.9433 - val_loss: 0.5212 - val_acc: 0.8924
# Epoch 167/200
# 35179/35179 [==============================] - 0s - loss: 0.1870 - acc: 0.9431 - val_loss: 0.5284 - val_acc: 0.8884
# Epoch 168/200
# 35179/35179 [==============================] - 0s - loss: 0.1890 - acc: 0.9420 - val_loss: 0.5586 - val_acc: 0.8831
# Epoch 169/200
# 35179/35179 [==============================] - 0s - loss: 0.1897 - acc: 0.9412 - val_loss: 0.5237 - val_acc: 0.8929
# Epoch 170/200
# 35179/35179 [==============================] - 1s - loss: 0.1887 - acc: 0.9419 - val_loss: 0.5321 - val_acc: 0.8878
# Epoch 171/200
# 35179/35179 [==============================] - 1s - loss: 0.1880 - acc: 0.9420 - val_loss: 0.5265 - val_acc: 0.8904
# Epoch 172/200
# 35179/35179 [==============================] - 1s - loss: 0.1857 - acc: 0.9438 - val_loss: 0.5286 - val_acc: 0.8916
# Epoch 173/200
# 35179/35179 [==============================] - 1s - loss: 0.1858 - acc: 0.9426 - val_loss: 0.5264 - val_acc: 0.8922
# Epoch 174/200
# 35179/35179 [==============================] - 1s - loss: 0.1846 - acc: 0.9422 - val_loss: 0.5277 - val_acc: 0.8910
# Epoch 175/200
# 35179/35179 [==============================] - 1s - loss: 0.1836 - acc: 0.9434 - val_loss: 0.5537 - val_acc: 0.8856
# Epoch 176/200
# 35179/35179 [==============================] - 1s - loss: 0.1845 - acc: 0.9428 - val_loss: 0.5364 - val_acc: 0.8903
# Epoch 177/200
# 35179/35179 [==============================] - 1s - loss: 0.1838 - acc: 0.9434 - val_loss: 0.5262 - val_acc: 0.8917
# Epoch 178/200
# 35179/35179 [==============================] - 1s - loss: 0.1899 - acc: 0.9412 - val_loss: 0.5301 - val_acc: 0.8898
# Epoch 179/200
# 35179/35179 [==============================] - 0s - loss: 0.1836 - acc: 0.9430 - val_loss: 0.5312 - val_acc: 0.8901
# Epoch 180/200
# 35179/35179 [==============================] - 1s - loss: 0.1838 - acc: 0.9433 - val_loss: 0.5320 - val_acc: 0.8894
# Epoch 181/200
# 35179/35179 [==============================] - 1s - loss: 0.1791 - acc: 0.9458 - val_loss: 0.5431 - val_acc: 0.8883
# Epoch 182/200
# 35179/35179 [==============================] - 0s - loss: 0.1801 - acc: 0.9445 - val_loss: 0.5642 - val_acc: 0.8869
# Epoch 183/200
# 35179/35179 [==============================] - 1s - loss: 0.1786 - acc: 0.9447 - val_loss: 0.5463 - val_acc: 0.8900
# Epoch 184/200
# 35179/35179 [==============================] - 1s - loss: 0.1786 - acc: 0.9459 - val_loss: 0.5378 - val_acc: 0.8886
# Epoch 185/200
# 35179/35179 [==============================] - 0s - loss: 0.1769 - acc: 0.9464 - val_loss: 0.5343 - val_acc: 0.8922
# Epoch 186/200
# 35179/35179 [==============================] - 0s - loss: 0.1778 - acc: 0.9447 - val_loss: 0.5726 - val_acc: 0.8846
# Epoch 187/200
# 35179/35179 [==============================] - 0s - loss: 0.1810 - acc: 0.9441 - val_loss: 0.5606 - val_acc: 0.8873
# Epoch 188/200
# 35179/35179 [==============================] - 0s - loss: 0.1799 - acc: 0.9447 - val_loss: 0.5491 - val_acc: 0.8877
# Epoch 189/200
# 35179/35179 [==============================] - 0s - loss: 0.1812 - acc: 0.9431 - val_loss: 0.5370 - val_acc: 0.8908
# Epoch 190/200
# 35179/35179 [==============================] - 0s - loss: 0.1772 - acc: 0.9456 - val_loss: 0.5459 - val_acc: 0.8898
# Epoch 191/200
# 35179/35179 [==============================] - 0s - loss: 0.1772 - acc: 0.9448 - val_loss: 0.5457 - val_acc: 0.8897
# Epoch 192/200
# 35179/35179 [==============================] - 0s - loss: 0.1752 - acc: 0.9470 - val_loss: 0.5446 - val_acc: 0.8912
# Epoch 193/200
# 35179/35179 [==============================] - 1s - loss: 0.1751 - acc: 0.9460 - val_loss: 0.5443 - val_acc: 0.8898
# Epoch 194/200
# 35179/35179 [==============================] - 1s - loss: 0.1758 - acc: 0.9466 - val_loss: 0.5520 - val_acc: 0.8896
# Epoch 195/200
# 35179/35179 [==============================] - 0s - loss: 0.1750 - acc: 0.9455 - val_loss: 0.5544 - val_acc: 0.8864
# Epoch 196/200
# 35179/35179 [==============================] - 0s - loss: 0.1749 - acc: 0.9456 - val_loss: 0.5470 - val_acc: 0.8881
# Epoch 197/200
# 35179/35179 [==============================] - 0s - loss: 0.1746 - acc: 0.9455 - val_loss: 0.5519 - val_acc: 0.8878
# Epoch 198/200
# 35179/35179 [==============================] - 0s - loss: 0.1754 - acc: 0.9458 - val_loss: 0.5543 - val_acc: 0.8861
# Epoch 199/200
# 35179/35179 [==============================] - 0s - loss: 0.1784 - acc: 0.9449 - val_loss: 0.5531 - val_acc: 0.8881
# Epoch 200/200
# 35179/35179 [==============================] - 0s - loss: 0.1730 - acc: 0.9464 - val_loss: 0.5557 - val_acc: 0.8890
# Test loss: 0.555737862527
# Test accuracy: 0.888950276187

# %%
### EARLY STOPPING : ADAM OPTIMIZER ###
model_early = Sequential()
model_early.add(Dense(64, activation='relu', input_shape=x_train.shape[1:]))
model_early.add(Dense(5, activation='softmax'))

model_early.summary()

call= keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.001, patience=5, verbose=0, mode='auto')

model_early.compile(loss='categorical_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])

history_early = model_early.fit(x_train, y_train,  callbacks=[call],
                    batch_size=128,
                    epochs=300,
                    verbose=1,
                    validation_data=(x_test, y_test))

score = model_early.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
plot_history(history_early, 'Adam Optimizer with Early Stopping : Loss and Accuracy ')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_448 (Dense)            (None, 64)                16448
# _________________________________________________________________
# dense_449 (Dense)            (None, 5)                 325
# =================================================================
# Total params: 16,773
# Trainable params: 16,773
# Non-trainable params: 0
# _________________________________________________________________
# Train on 35179 samples, validate on 12670 samples
# Epoch 1/300
# 35179/35179 [==============================] - 0s - loss: 1.4483 - acc: 0.4083 - val_loss: 1.2310 - val_acc: 0.5669
# Epoch 2/300
# 35179/35179 [==============================] - 0s - loss: 1.0748 - acc: 0.6475 - val_loss: 0.9606 - val_acc: 0.6717
# Epoch 3/300
# 35179/35179 [==============================] - 0s - loss: 0.8693 - acc: 0.7302 - val_loss: 0.8558 - val_acc: 0.7211
# Epoch 4/300
# 35179/35179 [==============================] - 0s - loss: 0.7743 - acc: 0.7609 - val_loss: 0.8368 - val_acc: 0.7376
# Epoch 5/300
# 35179/35179 [==============================] - 1s - loss: 0.7233 - acc: 0.7753 - val_loss: 0.8040 - val_acc: 0.7522
# Epoch 6/300
# 35179/35179 [==============================] - 1s - loss: 0.6865 - acc: 0.7867 - val_loss: 0.7715 - val_acc: 0.7575
# Epoch 7/300
# 35179/35179 [==============================] - 1s - loss: 0.6605 - acc: 0.7963 - val_loss: 0.7702 - val_acc: 0.7637
# Epoch 8/300
# 35179/35179 [==============================] - 1s - loss: 0.6365 - acc: 0.8043 - val_loss: 0.7476 - val_acc: 0.7702
# Epoch 9/300
# 35179/35179 [==============================] - 1s - loss: 0.6184 - acc: 0.8088 - val_loss: 0.7355 - val_acc: 0.7728
# Epoch 10/300
# 35179/35179 [==============================] - 1s - loss: 0.5995 - acc: 0.8156 - val_loss: 0.7034 - val_acc: 0.7837
# Epoch 11/300
# 35179/35179 [==============================] - 1s - loss: 0.5854 - acc: 0.8210 - val_loss: 0.6971 - val_acc: 0.7844
# Epoch 12/300
# 35179/35179 [==============================] - 1s - loss: 0.5692 - acc: 0.8247 - val_loss: 0.6815 - val_acc: 0.7923
# Epoch 13/300
# 35179/35179 [==============================] - 1s - loss: 0.5547 - acc: 0.8303 - val_loss: 0.6690 - val_acc: 0.7982
# Epoch 14/300
# 35179/35179 [==============================] - 1s - loss: 0.5429 - acc: 0.8342 - val_loss: 0.6634 - val_acc: 0.7998
# Epoch 15/300
# 35179/35179 [==============================] - 1s - loss: 0.5288 - acc: 0.8388 - val_loss: 0.6548 - val_acc: 0.8047
# Epoch 16/300
# 35179/35179 [==============================] - 1s - loss: 0.5184 - acc: 0.8416 - val_loss: 0.6431 - val_acc: 0.8070
# Epoch 17/300
# 35179/35179 [==============================] - 1s - loss: 0.5045 - acc: 0.8486 - val_loss: 0.6296 - val_acc: 0.8131
# Epoch 18/300
# 35179/35179 [==============================] - 1s - loss: 0.4933 - acc: 0.8505 - val_loss: 0.6246 - val_acc: 0.8195
# Epoch 19/300
# 35179/35179 [==============================] - 1s - loss: 0.4837 - acc: 0.8546 - val_loss: 0.6072 - val_acc: 0.8260
# Epoch 20/300
# 35179/35179 [==============================] - 1s - loss: 0.4736 - acc: 0.8561 - val_loss: 0.6200 - val_acc: 0.8232
# Epoch 21/300
# 35179/35179 [==============================] - 1s - loss: 0.4627 - acc: 0.8607 - val_loss: 0.6211 - val_acc: 0.8221
# Epoch 22/300
# 35179/35179 [==============================] - 1s - loss: 0.4584 - acc: 0.8621 - val_loss: 0.5822 - val_acc: 0.8332
# Epoch 23/300
# 35179/35179 [==============================] - 1s - loss: 0.4487 - acc: 0.8647 - val_loss: 0.5866 - val_acc: 0.8354
# Epoch 24/300
# 35179/35179 [==============================] - 1s - loss: 0.4409 - acc: 0.8669 - val_loss: 0.5780 - val_acc: 0.8380
# Epoch 25/300
# 35179/35179 [==============================] - 1s - loss: 0.4320 - acc: 0.8698 - val_loss: 0.5718 - val_acc: 0.8379
# Epoch 26/300
# 35179/35179 [==============================] - 1s - loss: 0.4273 - acc: 0.8714 - val_loss: 0.5614 - val_acc: 0.8444
# Epoch 27/300
# 35179/35179 [==============================] - 1s - loss: 0.4198 - acc: 0.8739 - val_loss: 0.5647 - val_acc: 0.8439
# Epoch 28/300
# 35179/35179 [==============================] - 1s - loss: 0.4115 - acc: 0.8779 - val_loss: 0.5726 - val_acc: 0.8433
# Epoch 29/300
# 35179/35179 [==============================] - 1s - loss: 0.4081 - acc: 0.8765 - val_loss: 0.5530 - val_acc: 0.8470
# Epoch 30/300
# 35179/35179 [==============================] - 1s - loss: 0.3997 - acc: 0.8804 - val_loss: 0.5490 - val_acc: 0.8522
# Epoch 31/300
# 35179/35179 [==============================] - 1s - loss: 0.3977 - acc: 0.8797 - val_loss: 0.5442 - val_acc: 0.8522
# Epoch 32/300
# 35179/35179 [==============================] - 1s - loss: 0.3925 - acc: 0.8833 - val_loss: 0.5347 - val_acc: 0.8584
# Epoch 33/300
# 35179/35179 [==============================] - 1s - loss: 0.3851 - acc: 0.8845 - val_loss: 0.5316 - val_acc: 0.8568
# Epoch 34/300
# 35179/35179 [==============================] - 1s - loss: 0.3810 - acc: 0.8854 - val_loss: 0.5499 - val_acc: 0.8481
# Epoch 35/300
# 35179/35179 [==============================] - 0s - loss: 0.3784 - acc: 0.8850 - val_loss: 0.5243 - val_acc: 0.8588
# Epoch 36/300
# 35179/35179 [==============================] - 1s - loss: 0.3716 - acc: 0.8876 - val_loss: 0.5243 - val_acc: 0.8571
# Epoch 37/300
# 35179/35179 [==============================] - 1s - loss: 0.3705 - acc: 0.8898 - val_loss: 0.5333 - val_acc: 0.8584
# Epoch 38/300
# 35179/35179 [==============================] - 1s - loss: 0.3657 - acc: 0.8906 - val_loss: 0.5448 - val_acc: 0.8561
# Epoch 39/300
# 35179/35179 [==============================] - 1s - loss: 0.3623 - acc: 0.8911 - val_loss: 0.5243 - val_acc: 0.8605
# Epoch 40/300
# 35179/35179 [==============================] - 1s - loss: 0.3574 - acc: 0.8920 - val_loss: 0.5208 - val_acc: 0.8635
# Epoch 41/300
# 35179/35179 [==============================] - 1s - loss: 0.3553 - acc: 0.8934 - val_loss: 0.5259 - val_acc: 0.8630
# Epoch 42/300
# 35179/35179 [==============================] - 1s - loss: 0.3516 - acc: 0.8939 - val_loss: 0.5131 - val_acc: 0.8669
# Epoch 43/300
# 35179/35179 [==============================] - 1s - loss: 0.3507 - acc: 0.8940 - val_loss: 0.5192 - val_acc: 0.8646
# Epoch 44/300
# 35179/35179 [==============================] - 1s - loss: 0.3451 - acc: 0.8955 - val_loss: 0.5146 - val_acc: 0.8627
# Epoch 45/300
# 35179/35179 [==============================] - 1s - loss: 0.3418 - acc: 0.8958 - val_loss: 0.5197 - val_acc: 0.8629
# Epoch 46/300
# 35179/35179 [==============================] - 1s - loss: 0.3385 - acc: 0.8985 - val_loss: 0.5112 - val_acc: 0.8659
# Epoch 47/300
# 35179/35179 [==============================] - 1s - loss: 0.3359 - acc: 0.8982 - val_loss: 0.5144 - val_acc: 0.8649
# Epoch 48/300
# 35179/35179 [==============================] - 1s - loss: 0.3330 - acc: 0.8991 - val_loss: 0.5156 - val_acc: 0.8643
# Epoch 49/300
# 35179/35179 [==============================] - 1s - loss: 0.3308 - acc: 0.8995 - val_loss: 0.5220 - val_acc: 0.8626
# Epoch 50/300
# 35179/35179 [==============================] - 1s - loss: 0.3299 - acc: 0.8998 - val_loss: 0.5181 - val_acc: 0.8654
# Epoch 51/300
# 35179/35179 [==============================] - 1s - loss: 0.3253 - acc: 0.9020 - val_loss: 0.5138 - val_acc: 0.8661
# Epoch 52/300
# 35179/35179 [==============================] - 1s - loss: 0.3251 - acc: 0.9019 - val_loss: 0.5235 - val_acc: 0.8646
# Test loss: 0.523481554141
# Test accuracy: 0.864561957389

# %% [markdown]
# **Question 1**: At which epoch (approximately) does the model start to overfit? Please answer with one full sentence.
#
# **Answer**: The model start to overfit around the 50 epoch
#
# **Question 2**: Explain the qualitative difference between the loss curves and the accuracy curves with respect to signs of overfitting. Please answer with at most 3 full sentences.
#
# **Answer**:  In statistics, overfitting is "the production of an analysis that corresponds too closely or exactly to a particular set of data, and may therefore fail to fit additional data or predict future observations reliably". An overfitted model is a statistical model that contains more parameters than can be justified by the data.The essence of overfitting is to have unknowingly extracted some of the residual variation (i.e. the noise) as if that variation represented underlying model structure.
# Thus we can see overfitting when the training accuracy inscrease since the validation accuracy stays the same. Moreover, we can see that overfitting begin when validation categorical cross entropy starts to increase after a rapid decrease since the training categorical cross entropy decrease. In fact theses two signs means that the training becomes more and more precise for the training set but it has no effect or bad effect on the validation set. It means that the model corresponds too closely or exactly to a particular set of data, the training data. This is overfitting.

# %% [markdown]
# ## Exercise 4: Model performance as a function of number of hidden neurons
#
# ### Description
#
# Investigate how the best validation loss and accuracy depends on the number of hidden neurons in a single layer.
#
# 1. Fit a reasonable number of models with different hidden layer size (between 10 and 1000 hidden neurons) for a fixed number of epochs well beyond the point of overfitting.
# 2. Collect some statistics by fitting the same models as in 1. for multiple initial conditions. Hints: 1. If you don't reset the random seed, you get different initial conditions each time you create a new model. 2. Let your computer work while you are asleep.
# 3. Plot summary statistics of the final validation loss and accuracy versus the number of hidden neurons. Hint: [boxplots](https://matplotlib.org/examples/pylab_examples/boxplot_demo.html) (also [here](https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.boxplot.html?highlight=boxplot#matplotlib.axes.Axes.boxplot)) are useful. You may also want to use the matplotlib method set_xticklabels.
# 4. Plot summary statistics of the loss and accuracy for early stopping versus the number of hidden neurons.
#
# ### Solution

# %%
#########Question 1################

#10#
model_10 = Sequential()
model_10.add(Dense(10, activation='relu', input_shape=x_train.shape[1:]))
model_10.add(Dense(5, activation='softmax'))
model_10.summary()
model_10.compile(loss='categorical_crossentropy',
          optimizer=keras.optimizers.SGD(lr=0.1),
          metrics=['accuracy'])
history_10 = model_10.fit(x_train, y_train,
                    batch_size=128,
                    epochs=200,
                    verbose=0,
                    validation_data=(x_test, y_test))

score = model_10.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#50#
model_50 = Sequential()
model_50.add(Dense(50, activation='relu', input_shape=x_train.shape[1:]))
model_50.add(Dense(5, activation='softmax'))
model_50.summary()
model_50.compile(loss='categorical_crossentropy',
          optimizer=keras.optimizers.SGD(lr=0.1),
          metrics=['accuracy'])
history_50 = model_50.fit(x_train, y_train,
                    batch_size=128,
                    epochs=200,
                    verbose=0,
                    validation_data=(x_test, y_test))
score = model_50.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#100#
model_100 = Sequential()
model_100.add(Dense(100, activation='relu', input_shape=x_train.shape[1:]))
model_100.add(Dense(5, activation='softmax'))
model_100.summary()
model_100.compile(loss='categorical_crossentropy',
          optimizer=keras.optimizers.SGD(lr=0.1),
          metrics=['accuracy'])
history_100 = model_100.fit(x_train, y_train,
                    batch_size=128,
                    epochs=200,
                    verbose=0,
                    validation_data=(x_test, y_test))
score = model_100.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#300#
model_300 = Sequential()
model_300.add(Dense(300, activation='relu', input_shape=x_train.shape[1:]))
model_300.add(Dense(5, activation='softmax'))
model_300.summary()
model_300.compile(loss='categorical_crossentropy',
          optimizer=keras.optimizers.SGD(lr=0.1),
          metrics=['accuracy'])
history_300 = model_300.fit(x_train, y_train,
                    batch_size=128,
                    epochs=200,
                    verbose=0,
                    validation_data=(x_test, y_test))
score = model_300.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#600#
model_600 = Sequential()
model_600.add(Dense(600, activation='relu', input_shape=x_train.shape[1:]))
model_600.add(Dense(5, activation='softmax'))
model_600.summary()
model_600.compile(loss='categorical_crossentropy',
          optimizer=keras.optimizers.SGD(lr=0.5),
          metrics=['accuracy'])
history_600 = model_600.fit(x_train, y_train,
                    batch_size=128,
                    epochs=200,
                    verbose=0,
                    validation_data=(x_test, y_test))
score = model_600.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#1000#
model_1000 = Sequential()
model_1000.add(Dense(1000, activation='relu', input_shape=x_train.shape[1:]))
model_1000.add(Dense(5, activation='softmax'))
model_1000.summary()
model_1000.compile(loss='categorical_crossentropy',
          optimizer=keras.optimizers.SGD(lr=0.1),
          metrics=['accuracy'])
history_1000 = model_1000.fit(x_train, y_train,
                    batch_size=128,
                    epochs=200,
                    verbose=0,
                    validation_data=(x_test, y_test))
score = model_1000.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])


### Plot with all the curve of the different number of neuron in the hidden layer ###
def plot_history_3(history_10,history_50,history_100,history_300,history_600,history_1000, title):
    fig, ax1, ax2 = prepare_standardplot(title, 'epoch')
    ax1.plot(history_10.history['loss'], ':', color="blue", label = "Training Loss with 10 hidden neurons")
    ax1.plot(history_10.history['val_loss'], '--', color="blue", label = "Validation Loss with 10 hidden neurons")
    ax2.plot(history_10.history['acc'], ':', color="blue",label = "Training Accuracy with 10 hidden neurons")
    ax2.plot(history_10.history['val_acc'],'--', color="blue", label = "Validation Accuracy with 10 hidden neurons")
    ax1.plot(history_50.history['loss'], ':', color="red",label = "Training Loss with 50 hidden neurons")
    ax1.plot(history_50.history['val_loss'], '--', color="red",label = "Validation Loss with 50 hidden neurons")
    ax2.plot(history_50.history['acc'], ':', color="red",label = "Training Accuracy with 50 hidden neurons")
    ax2.plot(history_50.history['val_acc'], '--', color="red",label = "Validation Accuracy with 50 hidden neurons")
    ax1.plot(history_100.history['loss'], ':', color="green",label = "Training Loss with 100 hidden neurons")
    ax1.plot(history_100.history['val_loss'], '--', color="green",label = "Validation Loss with 100 hidden neurons")
    ax2.plot(history_100.history['acc'], ':', color="green",label = "Training Accuracy with 100 hidden neurons")
    ax2.plot(history_100.history['val_acc'], '--', color="green",label = "Validation Accuracy with 100 hidden neurons")
    ax1.plot(history_300.history['loss'], ':', color="orange",label = "Training Loss with 300 hidden neurons")
    ax1.plot(history_300.history['val_loss'], '--', color="orange",label = "Validation Loss with 300 hidden neurons")
    ax2.plot(history_300.history['acc'], ':', color="orange",label = "Training Accuracy with 300 hidden neurons")
    ax2.plot(history_300.history['val_acc'], '--', color="orange",label = "Validation Accuracy with 300 hidden neurons")
    ax1.plot(history_600.history['loss'], ':', color="yellow",label = "Training Loss with 600 hidden neurons")
    ax1.plot(history_600.history['val_loss'], '--', color="yellow",label = "Validation Loss with 600 hidden neurons")
    ax2.plot(history_600.history['acc'], ':', color="yellow",label = "Training Accuracy with 600 hidden neurons")
    ax2.plot(history_600.history['val_acc'], '--', color="yellow",label = "Validation Accuracy with 600 hidden neurons")
    ax1.plot(history_1000.history['loss'], ':', color="black",label = "Training Loss with 1000 hidden neurons")
    ax1.plot(history_1000.history['val_loss'], '--', color="black",label = "Validation Loss with 1000 hidden neurons")
    ax2.plot(history_1000.history['acc'], ':', color="black",label = "Training Accuracy with 1000 hidden neurons")
    ax2.plot(history_1000.history['val_acc'], '--', color="black",label = "Validation Accuracy with 1000 hidden neurons")
    finalize_standardplot(fig, ax1, ax2)
    return fig
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_450 (Dense)            (None, 10)                2570
# _________________________________________________________________
# dense_451 (Dense)            (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.788465463447
# Test accuracy: 0.762904498835
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_452 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_453 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.509786577754
# Test accuracy: 0.88405682716
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_454 (Dense)            (None, 100)               25700
# _________________________________________________________________
# dense_455 (Dense)            (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.513367569282
# Test accuracy: 0.886266771921
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_456 (Dense)            (None, 300)               77100
# _________________________________________________________________
# dense_457 (Dense)            (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.464188268541
# Test accuracy: 0.898263614772
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_458 (Dense)            (None, 600)               154200
# _________________________________________________________________
# dense_459 (Dense)            (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.678014164523
# Test accuracy: 0.896764009415
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_460 (Dense)            (None, 1000)              257000
# _________________________________________________________________
# dense_461 (Dense)            (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.446219731369
# Test accuracy: 0.904262036316

# %%
plot_history_3(history_10,history_50,history_100,history_300,history_600,history_1000,'Learning Curve and Accuracy')

# %%
###### Question 3 ######
## You can see all the graph of the different network with the different numbers of hidden neuron ##

### Hiden Layer ###
hidden=[10,50,100,300,600,1000]

### Simulation of the network for different number of hidden neuron ###
for i in range (len(hidden)):
    model= Sequential()
    model.add(Dense(hidden[i], activation='relu', input_shape=x_train.shape[1:]))
    model.add(Dense(5, activation='softmax'))
    model.summary()
    model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.SGD(lr=0.05),
              metrics=['accuracy'])
    history= model.fit(x_train, y_train,
                        batch_size=128,
                        epochs=100,
                        verbose=0,
                        validation_data=(x_test, y_test))
    plot_history(history, 'title')
    plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_462 (Dense)            (None, 10)                2570
# _________________________________________________________________
# dense_463 (Dense)            (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_464 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_465 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_466 (Dense)            (None, 100)               25700
# _________________________________________________________________
# dense_467 (Dense)            (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_468 (Dense)            (None, 300)               77100
# _________________________________________________________________
# dense_469 (Dense)            (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_470 (Dense)            (None, 600)               154200
# _________________________________________________________________
# dense_471 (Dense)            (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_472 (Dense)            (None, 1000)              257000
# _________________________________________________________________
# dense_473 (Dense)            (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________

# %%
####### Question 3 #########
import math

start = time.time()
print("Start of the script execution...")

### Hiden Layer ###
hidden=[10,50,100,300,600,1000]

### Number of simulation with different initial condtion ###
times=10

### Data for plot ####
data_val_loss=np.empty((len(hidden),times))
data_val_accuracy=np.empty((len(hidden),times))
data_train_loss=np.empty((len(hidden),times))
data_train_acc=np.empty((len(hidden),times))

### Model with different number of hidden neuron and with different initial condtition ###
for i in range (len(hidden)):
        for k in range (times):
            print('hidden =',hidden[i],' and k =',k)
            model= Sequential()
            model.add(Dense(hidden[i], activation='relu', input_shape=x_train.shape[1:], name='layer1'))
            model.add(Dense(5, activation='softmax', name='layer2'))
            model.summary()
            model.compile(loss='categorical_crossentropy',
                      optimizer=keras.optimizers.SGD(lr=0.05),
                      metrics=['accuracy'])
            history= model.fit(x_train, y_train,
                                batch_size=128,
                                epochs=200,
                                verbose=0,
                                validation_data=(x_test, y_test))
            score = model.evaluate(x_test, y_test, verbose=0)
            print('Test loss:', score[0])
            print('Test accuracy:', score[1])
            data_val_loss[i][k]= (history.history['val_loss'][-1])
            data_val_accuracy[i][k]=(history.history['val_acc'][-1])
            data_train_loss[i][k]=(history.history['loss'][-1])
            data_train_acc[i][k]=(history.history['acc'][-1])

print("End of the execution !")
end = time.time()
print("Execution time : {} seconds.".format(math.ceil(end - start)))

### Plot ###

plt.figure()
plt.boxplot(data_val_loss)
plt.title('Boxplot : Validation Loss Plot')
plt.xticks([1,2,3,4,5,6], ['10','50','100','300','600','1000'])
plt.xlabel('Number of hidden neurons')
plt.ylabel('Final Validation Loss')

plt.figure()
plt.boxplot(data_val_accuracy)
plt.title('Boxplot : Validation Accuracy Plot')
plt.xticks([1,2,3,4,5,6], ['10','50','100','300','600','1000'])
plt.xlabel('Number of hidden neurons')
plt.ylabel('Final Validation Accuracy')

plt.figure()
plt.boxplot(data_train_loss)
plt.title('Boxplot: Train Loss PLot')
plt.xticks([1,2,3,4,5,6], ['10','50','100','300','600','1000'])
plt.xlabel('Number of hidden neurons')
plt.ylabel('Final Train Loss')

plt.figure()
plt.boxplot(data_train_acc)
plt.title('Boxplot: Train Accuracy Plot')
plt.xticks([1,2,3,4,5,6], ['10','50','100','300','600','1000'])
plt.xlabel('Number of hidden neurons')
plt.ylabel('Final Train Accuracy')

plt.show()
# Out:
# Start of the script execution...
# hidden = 10  and k = 0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 10)                2570
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.874519506711
# Test accuracy: 0.733149171299
# hidden = 10  and k = 1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 10)                2570
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.845693740237
# Test accuracy: 0.752565114406
# hidden = 10  and k = 2
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 10)                2570
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.791029219761
# Test accuracy: 0.77332280974
# hidden = 10  and k = 3
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 10)                2570
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.850930830627
# Test accuracy: 0.738752959785
# hidden = 10  and k = 4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 10)                2570
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.914873335826
# Test accuracy: 0.714601420641
# hidden = 10  and k = 5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 10)                2570
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.924121037589
# Test accuracy: 0.714443567539
# hidden = 10  and k = 6
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 10)                2570
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.838761643904
# Test accuracy: 0.756985003984
# hidden = 10  and k = 7
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 10)                2570
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.808144452215
# Test accuracy: 0.76132596687
# hidden = 10  and k = 8
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 10)                2570
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.804092811484
# Test accuracy: 0.757537490106
# hidden = 10  and k = 9
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 10)                2570
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.805004266584
# Test accuracy: 0.760299921017
# hidden = 50  and k = 0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 50)                12850
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.512161190668
# Test accuracy: 0.870244672398
# hidden = 50  and k = 1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 50)                12850
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.504841300299
# Test accuracy: 0.874033149115
# hidden = 50  and k = 2
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 50)                12850
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.516485934612
# Test accuracy: 0.870402525595
# hidden = 50  and k = 3
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 50)                12850
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.516235034428
# Test accuracy: 0.873717442712
# hidden = 50  and k = 4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 50)                12850
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.503602872009
# Test accuracy: 0.87608524066
# hidden = 50  and k = 5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 50)                12850
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.516960357675
# Test accuracy: 0.871665351223
# hidden = 50  and k = 6
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 50)                12850
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.519206836272
# Test accuracy: 0.869928966071
# hidden = 50  and k = 7
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 50)                12850
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.5133283632
# Test accuracy: 0.876243093876
# hidden = 50  and k = 8
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 50)                12850
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.505003389323
# Test accuracy: 0.87379636932
# hidden = 50  and k = 9
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 50)                12850
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.50522273229
# Test accuracy: 0.87426992891
# hidden = 100  and k = 0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 100)               25700
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.468236671632
# Test accuracy: 0.885556432461
# hidden = 100  and k = 1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 100)               25700
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.473304204044
# Test accuracy: 0.886977111296
# hidden = 100  and k = 2
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 100)               25700
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.457792779519
# Test accuracy: 0.885477505929
# hidden = 100  and k = 3
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 100)               25700
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.477831326243
# Test accuracy: 0.884767166545
# hidden = 100  and k = 4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 100)               25700
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.465805747618
# Test accuracy: 0.885793212256
# hidden = 100  and k = 5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 100)               25700
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.464768523467
# Test accuracy: 0.885398579331
# hidden = 100  and k = 6
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 100)               25700
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.489873586996
# Test accuracy: 0.882320441998
# hidden = 100  and k = 7
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 100)               25700
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.464887095853
# Test accuracy: 0.886740331501
# hidden = 100  and k = 8
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 100)               25700
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.485183680436
# Test accuracy: 0.883188634579
# hidden = 100  and k = 9
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 100)               25700
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.471935102628
# Test accuracy: 0.885398579331
# hidden = 300  and k = 0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 300)               77100
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.436817780897
# Test accuracy: 0.893843725345
# hidden = 300  and k = 1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 300)               77100
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.43085591459
# Test accuracy: 0.891712707192
# hidden = 300  and k = 2
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 300)               77100
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.441239673598
# Test accuracy: 0.891870560388
# hidden = 300  and k = 3
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 300)               77100
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.45322901786
# Test accuracy: 0.888713496458
# hidden = 300  and k = 4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 300)               77100
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.437492181369
# Test accuracy: 0.892975532764
# hidden = 300  and k = 5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 300)               77100
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.42485823946
# Test accuracy: 0.895106550917
# hidden = 300  and k = 6
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 300)               77100
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.431999987639
# Test accuracy: 0.893843725279
# hidden = 300  and k = 7
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 300)               77100
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.44631490443
# Test accuracy: 0.88745067082
# hidden = 300  and k = 8
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 300)               77100
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.439223271566
# Test accuracy: 0.89179163379
# hidden = 300  and k = 9
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 300)               77100
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.45671753889
# Test accuracy: 0.889344909178
# hidden = 600  and k = 0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 600)               154200
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.429375420792
# Test accuracy: 0.894711917926
# hidden = 600  and k = 1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 600)               154200
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.440527508474
# Test accuracy: 0.895580110507
# hidden = 600  and k = 2
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 600)               154200
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.417082325817
# Test accuracy: 0.897158642472
# hidden = 600  and k = 3
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 600)               154200
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.427458018775
# Test accuracy: 0.894080505074
# hidden = 600  and k = 4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 600)               154200
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.417920609403
# Test accuracy: 0.898105761651
# hidden = 600  and k = 5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 600)               154200
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.421761085019
# Test accuracy: 0.895343330712
# hidden = 600  and k = 6
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 600)               154200
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.425108885713
# Test accuracy: 0.897474348865
# hidden = 600  and k = 7
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 600)               154200
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.422007809893
# Test accuracy: 0.898263614848
# hidden = 600  and k = 8
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 600)               154200
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.432568569915
# Test accuracy: 0.894001578476
# hidden = 600  and k = 9
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 600)               154200
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.437890770935
# Test accuracy: 0.89360694555
# hidden = 1000  and k = 0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 1000)              257000
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.418240583519
# Test accuracy: 0.897947908455
# hidden = 1000  and k = 1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 1000)              257000
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.423959094846
# Test accuracy: 0.895974743498
# hidden = 1000  and k = 2
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 1000)              257000
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.422143107813
# Test accuracy: 0.898579321241
# hidden = 1000  and k = 3
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 1000)              257000
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.421967620502
# Test accuracy: 0.896132596694
# hidden = 1000  and k = 4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 1000)              257000
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.428830875989
# Test accuracy: 0.897474348865
# hidden = 1000  and k = 5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 1000)              257000
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.465791939976
# Test accuracy: 0.884214680357
# hidden = 1000  and k = 6
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 1000)              257000
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.454926826273
# Test accuracy: 0.883977900496
# hidden = 1000  and k = 7
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 1000)              257000
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.418924527445
# Test accuracy: 0.897395422267
# hidden = 1000  and k = 8
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 1000)              257000
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.419197296875
# Test accuracy: 0.898105761651
# hidden = 1000  and k = 9
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 1000)              257000
# _________________________________________________________________
# layer2 (Dense)               (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.417644595281
# Test accuracy: 0.899052880764
# End of the execution !
# Execution time : 11029 seconds.

# %%
#### Question 4 ####

import math

start = time.time()
print("Start of the script execution...")

### Hiden Layer ###
hidden=[10,50,100,300,600,1000]

### Number of simulation with different initial condtion ###
times=10

### Data for plot ###
data_val_loss=np.zeros((len(hidden),times))
data_val_accuracy=np.zeros((len(hidden),times))
data_train_loss=np.zeros((len(hidden),times))
data_train_acc=np.zeros((len(hidden),times))


### Model with different number of hidden neuron and with different initial condtition ###
for i in range (len(hidden)):
    for k in range(times):
        print('hidden =',hidden[i],' and k =',k)
        model= Sequential()
        model.add(Dense(hidden[i], activation='relu', input_shape=x_train.shape[1:]))
        model.add(Dense(5, activation='softmax'))
        model.summary()
        call= keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.001, patience=5, verbose=0, mode='auto')
        model.compile(loss='categorical_crossentropy',
                  optimizer=keras.optimizers.SGD(lr=0.05),
                  metrics=['accuracy'])
        history= model.fit(x_train, y_train, callbacks=[call],
                            batch_size=128,
                            epochs=200,
                            verbose=0,
                            validation_data=(x_test, y_test))
        data_val_loss[i][k]= (history.history['val_loss'][-1])
        data_val_accuracy[i][k]=(history.history['val_acc'][-1])
        data_train_loss[i][k]=(history.history['loss'][-1])
        data_train_acc[i][k]=(history.history['acc'][-1])
        
print("End of the execution !")
end = time.time()
print("Execution time : {} seconds.".format(math.ceil(end - start)))

### Plot ###

plt.figure()
plt.boxplot(data_val_loss)
plt.title('Boxplot : Validation Loss Plot With Early Stopping')
plt.xticks([1,2,3,4,5,6], ['10','50','100','300','600','1000'])
plt.xlabel('Number of hidden neurons')
plt.ylabel('Final Validation Loss')

plt.figure()
plt.boxplot(data_val_accuracy)
plt.title('Boxplot : Validation Accuracy Plot With Early Stopping')
plt.xticks([1,2,3,4,5,6], ['10','50','100','300','600','1000'])
plt.xlabel('Number of hidden neurons')
plt.ylabel('Final Validation Accuracy')

plt.figure()
plt.boxplot(data_train_loss)
plt.title('Boxplot: Train Loss PLot With Early Stopping')
plt.xticks([1,2,3,4,5,6], ['10','50','100','300','600','1000'])
plt.xlabel('Number of hidden neurons')
plt.ylabel('Final Train Loss')

plt.figure()
plt.boxplot(data_train_acc)
plt.title('Boxplot: Train Accuracy Plot With Early Stopping')
plt.xticks([1,2,3,4,5,6], ['10','50','100','300','600','1000'])
plt.xlabel('Number of hidden neurons')
plt.ylabel('Final Train Accuracy')

plt.show()
# Out:
# Start of the script execution...
# hidden = 10  and k = 0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_474 (Dense)            (None, 10)                2570
# _________________________________________________________________
# dense_475 (Dense)            (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 10  and k = 1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_476 (Dense)            (None, 10)                2570
# _________________________________________________________________
# dense_477 (Dense)            (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 10  and k = 2
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_478 (Dense)            (None, 10)                2570
# _________________________________________________________________
# dense_479 (Dense)            (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 10  and k = 3
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_480 (Dense)            (None, 10)                2570
# _________________________________________________________________
# dense_481 (Dense)            (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 10  and k = 4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_482 (Dense)            (None, 10)                2570
# _________________________________________________________________
# dense_483 (Dense)            (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 10  and k = 5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_484 (Dense)            (None, 10)                2570
# _________________________________________________________________
# dense_485 (Dense)            (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 10  and k = 6
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_486 (Dense)            (None, 10)                2570
# _________________________________________________________________
# dense_487 (Dense)            (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 10  and k = 7
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_488 (Dense)            (None, 10)                2570
# _________________________________________________________________
# dense_489 (Dense)            (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 10  and k = 8
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_490 (Dense)            (None, 10)                2570
# _________________________________________________________________
# dense_491 (Dense)            (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 10  and k = 9
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_492 (Dense)            (None, 10)                2570
# _________________________________________________________________
# dense_493 (Dense)            (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 50  and k = 0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_494 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_495 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 50  and k = 1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_496 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_497 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 50  and k = 2
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_498 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_499 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 50  and k = 3
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_500 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_501 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 50  and k = 4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_502 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_503 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 50  and k = 5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_504 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_505 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 50  and k = 6
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_506 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_507 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 50  and k = 7
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_508 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_509 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 50  and k = 8
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_510 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_511 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 50  and k = 9
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_512 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_513 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 100  and k = 0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_514 (Dense)            (None, 100)               25700
# _________________________________________________________________
# dense_515 (Dense)            (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 100  and k = 1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_516 (Dense)            (None, 100)               25700
# _________________________________________________________________
# dense_517 (Dense)            (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 100  and k = 2
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_518 (Dense)            (None, 100)               25700
# _________________________________________________________________
# dense_519 (Dense)            (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 100  and k = 3
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_520 (Dense)            (None, 100)               25700
# _________________________________________________________________
# dense_521 (Dense)            (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 100  and k = 4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_522 (Dense)            (None, 100)               25700
# _________________________________________________________________
# dense_523 (Dense)            (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 100  and k = 5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_524 (Dense)            (None, 100)               25700
# _________________________________________________________________
# dense_525 (Dense)            (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 100  and k = 6
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_526 (Dense)            (None, 100)               25700
# _________________________________________________________________
# dense_527 (Dense)            (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 100  and k = 7
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_528 (Dense)            (None, 100)               25700
# _________________________________________________________________
# dense_529 (Dense)            (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 100  and k = 8
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_530 (Dense)            (None, 100)               25700
# _________________________________________________________________
# dense_531 (Dense)            (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 100  and k = 9
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_532 (Dense)            (None, 100)               25700
# _________________________________________________________________
# dense_533 (Dense)            (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 300  and k = 0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_534 (Dense)            (None, 300)               77100
# _________________________________________________________________
# dense_535 (Dense)            (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 300  and k = 1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_536 (Dense)            (None, 300)               77100
# _________________________________________________________________
# dense_537 (Dense)            (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 300  and k = 2
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_538 (Dense)            (None, 300)               77100
# _________________________________________________________________
# dense_539 (Dense)            (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 300  and k = 3
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_540 (Dense)            (None, 300)               77100
# _________________________________________________________________
# dense_541 (Dense)            (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 300  and k = 4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_542 (Dense)            (None, 300)               77100
# _________________________________________________________________
# dense_543 (Dense)            (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 300  and k = 5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_544 (Dense)            (None, 300)               77100
# _________________________________________________________________
# dense_545 (Dense)            (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 300  and k = 6
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_546 (Dense)            (None, 300)               77100
# _________________________________________________________________
# dense_547 (Dense)            (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 300  and k = 7
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_548 (Dense)            (None, 300)               77100
# _________________________________________________________________
# dense_549 (Dense)            (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 300  and k = 8
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_550 (Dense)            (None, 300)               77100
# _________________________________________________________________
# dense_551 (Dense)            (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 300  and k = 9
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_552 (Dense)            (None, 300)               77100
# _________________________________________________________________
# dense_553 (Dense)            (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 600  and k = 0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_554 (Dense)            (None, 600)               154200
# _________________________________________________________________
# dense_555 (Dense)            (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 600  and k = 1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_556 (Dense)            (None, 600)               154200
# _________________________________________________________________
# dense_557 (Dense)            (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 600  and k = 2
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_558 (Dense)            (None, 600)               154200
# _________________________________________________________________
# dense_559 (Dense)            (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 600  and k = 3
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_560 (Dense)            (None, 600)               154200
# _________________________________________________________________
# dense_561 (Dense)            (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 600  and k = 4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_562 (Dense)            (None, 600)               154200
# _________________________________________________________________
# dense_563 (Dense)            (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 600  and k = 5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_564 (Dense)            (None, 600)               154200
# _________________________________________________________________
# dense_565 (Dense)            (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 600  and k = 6
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_566 (Dense)            (None, 600)               154200
# _________________________________________________________________
# dense_567 (Dense)            (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 600  and k = 7
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_568 (Dense)            (None, 600)               154200
# _________________________________________________________________
# dense_569 (Dense)            (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 600  and k = 8
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_570 (Dense)            (None, 600)               154200
# _________________________________________________________________
# dense_571 (Dense)            (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 600  and k = 9
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_572 (Dense)            (None, 600)               154200
# _________________________________________________________________
# dense_573 (Dense)            (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 1000  and k = 0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_574 (Dense)            (None, 1000)              257000
# _________________________________________________________________
# dense_575 (Dense)            (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 1000  and k = 1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_576 (Dense)            (None, 1000)              257000
# _________________________________________________________________
# dense_577 (Dense)            (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 1000  and k = 2
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_578 (Dense)            (None, 1000)              257000
# _________________________________________________________________
# dense_579 (Dense)            (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 1000  and k = 3
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_580 (Dense)            (None, 1000)              257000
# _________________________________________________________________
# dense_581 (Dense)            (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 1000  and k = 4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_582 (Dense)            (None, 1000)              257000
# _________________________________________________________________
# dense_583 (Dense)            (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 1000  and k = 5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_584 (Dense)            (None, 1000)              257000
# _________________________________________________________________
# dense_585 (Dense)            (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 1000  and k = 6
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_586 (Dense)            (None, 1000)              257000
# _________________________________________________________________
# dense_587 (Dense)            (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 1000  and k = 7
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_588 (Dense)            (None, 1000)              257000
# _________________________________________________________________
# dense_589 (Dense)            (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 1000  and k = 8
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_590 (Dense)            (None, 1000)              257000
# _________________________________________________________________
# dense_591 (Dense)            (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# hidden = 1000  and k = 9
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_592 (Dense)            (None, 1000)              257000
# _________________________________________________________________
# dense_593 (Dense)            (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________
# End of the execution !
# Execution time : 6865 seconds.

# %% [markdown]
# ## Exercise 5: Comparison to deep models
#
# ### Description
#
# Instead of choosing one hidden layer (with many neurons) you experiment here with multiple hidden layers (each with not so many neurons).
#
# 1. Fit models with 2, 3 and 4 hidden layers with approximately the same number of parameters as a network with one hidden layer of 100 neurons. Hint: Calculate the number of parameters in a network with input dimensionality N_in, K hidden layers with N_h units, one output layer with N_out dimensions and solve for N_h. Confirm you result with the keras method model.summary().
# 2. Run each model multiple times with different initial conditions and plot summary statistics of the best validation loss and accuracy versus the number of hidden layers.
#
# ### Solution

# %%
################################################################
# 1.Summary statistics of models with different number of hidden layer keeping neuron count same as 100 Hidden layer model
#################################################################

data_loss=[]
data_accuracy=[]
times=10;

n_hidden = [100, 77, 66, 59]      # No of hidden neurons per layer
n_repeat = [1, 2, 3, 4]           # No of hidden layers

########################################
# Create parametric model with given hidden and repeat arguments
#########################################

def dynamic_model(neurons, repeat):
    y = Input(shape=x_train.shape[1:])
    input_img = y
    for j in range(repeat):
        y = Dense(neurons, activation='relu') (y)
    y = Dense(5, activation='softmax')(y)
    model = Model(input_img, y)
    return model

models=[]

for j in range(4):
    print("\n\nModel Summary with {} hidden layers".format(j))
    models.append(dynamic_model(n_hidden[j], n_repeat[j]))    
    models[j].summary()
# Out:
# Model Summary with 0 hidden layers
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               25700
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Model Summary with 1 hidden layers
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 77)                19789
# _________________________________________________________________
# dense_4 (Dense)              (None, 77)                6006
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 390
# =================================================================
# Total params: 26,185
# Trainable params: 26,185
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Model Summary with 2 hidden layers
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 66)                16962
# _________________________________________________________________
# dense_7 (Dense)              (None, 66)                4422
# _________________________________________________________________
# dense_8 (Dense)              (None, 66)                4422
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 335
# =================================================================
# Total params: 26,141
# Trainable params: 26,141
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Model Summary with 3 hidden layers
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 59)                15163
# _________________________________________________________________
# dense_11 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_12 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_13 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 300
# =================================================================
# Total params: 26,083
# Trainable params: 26,083
# Non-trainable params: 0
# _________________________________________________________________

# %%
##################################################
# Part 2 - Running experiment for 5 times with different initial conditions for fixed 250 epochs
###################################################


n_hidden = [100, 77, 66, 59]
n_repeat = [1, 2, 3, 4]
total_exps = len(n_hidden)
times = 5
num_epochs = 250

data_val_loss     = np.zeros((times,4))
data_val_accuracy = np.zeros((times,4))
data_train_loss   = np.zeros((times,4))
data_train_acc    = np.zeros((times,4))

summary_naive = {}


######################################################
# We dont use the early stopping criteria, however, we run for enough iterations and save the model with best validation accuracy
# using the modelcheckpoint callback
#In the output summary, you can see the values of best validation loss and accuracy
########################################################

for i in range(total_exps):
    for k in range(times):
        print("\n\n*****************************************************************************")
        print('Running experiment {}/{} : with {} hidden layers ({} neurons per hidden layer)'.format(k+1,times, i+1, n_hidden[i]))
        model = dynamic_model(n_hidden[i], n_repeat[i])
        model.summary()
        #call= keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.001, patience=15, verbose=0, mode='auto')
        saveBestModel = keras.callbacks.ModelCheckpoint("./best_weights.hdf5", monitor='val_acc', verbose=0, save_best_only=True, mode='auto',save_weights_only=True)
        model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.SGD(lr=0.05), metrics=['accuracy'])
        history= model.fit(x_train, y_train, callbacks=[saveBestModel],batch_size=128, epochs=num_epochs, verbose=0, 
                           validation_data=(x_test, y_test))
        model.load_weights("./best_weights.hdf5")
        score = model.evaluate(x_train, y_train, verbose=0)
        print("Train Loss: {} , Train Accuracy: {}".format(score[0], score[1]))
        score = model.evaluate(x_test, y_test, verbose=0)
        data_val_loss[k][i]= score[0]
        data_val_accuracy[k][i]=score[1]
        print("Valid Loss: {} , Valid Accuracy: {}".format(data_val_loss[k][i],data_val_accuracy[k][i]))
    summary_naive['hidden_{}'.format(n_repeat[i])] = history
        

plt.figure()
plt.boxplot(data_val_loss)
plt.title('Summary Statistics of Best Validation Loss')
plt.xticks([1,2,3,4], ['1','2','3','4'])
plt.xlabel('Number of hidden neurons')
plt.ylabel('Final Validation Loss')

plt.figure()
plt.boxplot(data_val_accuracy)
plt.title('Summary Statistics of Best Validation Accuracy')
plt.xticks([1,2,3,4], ['1','2','3','4'])
plt.xlabel('Number of hidden neurons')
plt.ylabel('Final Validation Accuracy')


plt.show()
# Out:
# *****************************************************************************
# Running experiment 1/5 : with 1 hidden layers ( 100 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 256)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 100)               25700
# _________________________________________________________________
# dense_24 (Dense)             (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.223876426708 , Train Accuracy: 0.93538611025
# Valid Loss: 0.448930487789 , Valid Accuracy: 0.891228515284
#
#
# *****************************************************************************
# Running experiment 2/5 : with 1 hidden layers ( 100 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 100)               25700
# _________________________________________________________________
# dense_26 (Dense)             (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.221325749529 , Train Accuracy: 0.934992828396
# Valid Loss: 0.44864147109 , Valid Accuracy: 0.891926174922
#
#
# *****************************************************************************
# Running experiment 3/5 : with 1 hidden layers ( 100 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 100)               25700
# _________________________________________________________________
# dense_28 (Dense)             (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.237937770186 , Train Accuracy: 0.931221949775
# Valid Loss: 0.450401701379 , Valid Accuracy: 0.889579501506
#
#
# *****************************************************************************
# Running experiment 4/5 : with 1 hidden layers ( 100 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 100)               25700
# _________________________________________________________________
# dense_30 (Dense)             (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.228191694814 , Train Accuracy: 0.933049553534
# Valid Loss: 0.453315888593 , Valid Accuracy: 0.889452654293
#
#
# *****************************************************************************
# Running experiment 5/5 : with 1 hidden layers ( 100 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 100)               25700
# _________________________________________________________________
# dense_32 (Dense)             (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.224427377562 , Train Accuracy: 0.934345070102
# Valid Loss: 0.448388199628 , Valid Accuracy: 0.890277161159
#
#
# *****************************************************************************
# Running experiment 1/5 : with 2 hidden layers ( 77 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_14 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 77)                19789
# _________________________________________________________________
# dense_34 (Dense)             (None, 77)                6006
# _________________________________________________________________
# dense_35 (Dense)             (None, 5)                 390
# =================================================================
# Total params: 26,185
# Trainable params: 26,185
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.160198813713 , Train Accuracy: 0.950562161701
# Valid Loss: 0.462189652092 , Valid Accuracy: 0.888691571018
#
#
# *****************************************************************************
# Running experiment 2/5 : with 2 hidden layers ( 77 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_15 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_36 (Dense)             (None, 77)                19789
# _________________________________________________________________
# dense_37 (Dense)             (None, 77)                6006
# _________________________________________________________________
# dense_38 (Dense)             (None, 5)                 390
# =================================================================
# Total params: 26,185
# Trainable params: 26,185
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.134085316003 , Train Accuracy: 0.957109147333
# Valid Loss: 0.493059492204 , Valid Accuracy: 0.888120758577
#
#
# *****************************************************************************
# Running experiment 3/5 : with 2 hidden layers ( 77 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_39 (Dense)             (None, 77)                19789
# _________________________________________________________________
# dense_40 (Dense)             (None, 77)                6006
# _________________________________________________________________
# dense_41 (Dense)             (None, 5)                 390
# =================================================================
# Total params: 26,185
# Trainable params: 26,185
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.14708745094 , Train Accuracy: 0.953361402901
# Valid Loss: 0.473866810274 , Valid Accuracy: 0.889452654278
#
#
# *****************************************************************************
# Running experiment 4/5 : with 2 hidden layers ( 77 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_42 (Dense)             (None, 77)                19789
# _________________________________________________________________
# dense_43 (Dense)             (None, 77)                6006
# _________________________________________________________________
# dense_44 (Dense)             (None, 5)                 390
# =================================================================
# Total params: 26,185
# Trainable params: 26,185
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.160560993211 , Train Accuracy: 0.948896497503
# Valid Loss: 0.435022696965 , Valid Accuracy: 0.892623834591
#
#
# *****************************************************************************
# Running experiment 5/5 : with 2 hidden layers ( 77 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_18 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_45 (Dense)             (None, 77)                19789
# _________________________________________________________________
# dense_46 (Dense)             (None, 77)                6006
# _________________________________________________________________
# dense_47 (Dense)             (None, 5)                 390
# =================================================================
# Total params: 26,185
# Trainable params: 26,185
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.122472595408 , Train Accuracy: 0.962800166605
# Valid Loss: 0.510323991194 , Valid Accuracy: 0.889769772339
#
#
# *****************************************************************************
# Running experiment 1/5 : with 3 hidden layers ( 66 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_19 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_48 (Dense)             (None, 66)                16962
# _________________________________________________________________
# dense_49 (Dense)             (None, 66)                4422
# _________________________________________________________________
# dense_50 (Dense)             (None, 66)                4422
# _________________________________________________________________
# dense_51 (Dense)             (None, 5)                 335
# =================================================================
# Total params: 26,141
# Trainable params: 26,141
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.135390515325 , Train Accuracy: 0.955466617316
# Valid Loss: 0.44969017517 , Valid Accuracy: 0.888628147427
#
#
# *****************************************************************************
# Running experiment 2/5 : with 3 hidden layers ( 66 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_20 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_52 (Dense)             (None, 66)                16962
# _________________________________________________________________
# dense_53 (Dense)             (None, 66)                4422
# _________________________________________________________________
# dense_54 (Dense)             (None, 66)                4422
# _________________________________________________________________
# dense_55 (Dense)             (None, 5)                 335
# =================================================================
# Total params: 26,141
# Trainable params: 26,141
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.157093765175 , Train Accuracy: 0.947115162193
# Valid Loss: 0.44561173736 , Valid Accuracy: 0.885076425476
#
#
# *****************************************************************************
# Running experiment 3/5 : with 3 hidden layers ( 66 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_21 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_56 (Dense)             (None, 66)                16962
# _________________________________________________________________
# dense_57 (Dense)             (None, 66)                4422
# _________________________________________________________________
# dense_58 (Dense)             (None, 66)                4422
# _________________________________________________________________
# dense_59 (Dense)             (None, 5)                 335
# =================================================================
# Total params: 26,141
# Trainable params: 26,141
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.154574242902 , Train Accuracy: 0.948942765947
# Valid Loss: 0.432063052187 , Valid Accuracy: 0.886979133664
#
#
# *****************************************************************************
# Running experiment 4/5 : with 3 hidden layers ( 66 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_22 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_60 (Dense)             (None, 66)                16962
# _________________________________________________________________
# dense_61 (Dense)             (None, 66)                4422
# _________________________________________________________________
# dense_62 (Dense)             (None, 66)                4422
# _________________________________________________________________
# dense_63 (Dense)             (None, 5)                 335
# =================================================================
# Total params: 26,141
# Trainable params: 26,141
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.136802891507 , Train Accuracy: 0.955559154254
# Valid Loss: 0.467842527574 , Valid Accuracy: 0.884632460232
#
#
# *****************************************************************************
# Running experiment 5/5 : with 3 hidden layers ( 66 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_23 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_64 (Dense)             (None, 66)                16962
# _________________________________________________________________
# dense_65 (Dense)             (None, 66)                4422
# _________________________________________________________________
# dense_66 (Dense)             (None, 66)                4422
# _________________________________________________________________
# dense_67 (Dense)             (None, 5)                 335
# =================================================================
# Total params: 26,141
# Trainable params: 26,141
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.149492644755 , Train Accuracy: 0.95028455097
# Valid Loss: 0.421980840671 , Valid Accuracy: 0.887549946135
#
#
# *****************************************************************************
# Running experiment 1/5 : with 4 hidden layers ( 59 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_24 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_68 (Dense)             (None, 59)                15163
# _________________________________________________________________
# dense_69 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_70 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_71 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_72 (Dense)             (None, 5)                 300
# =================================================================
# Total params: 26,083
# Trainable params: 26,083
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.170011468445 , Train Accuracy: 0.944986813495
# Valid Loss: 0.416448198529 , Valid Accuracy: 0.884378765777
#
#
# *****************************************************************************
# Running experiment 2/5 : with 4 hidden layers ( 59 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_25 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_73 (Dense)             (None, 59)                15163
# _________________________________________________________________
# dense_74 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_75 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_76 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_77 (Dense)             (None, 5)                 300
# =================================================================
# Total params: 26,083
# Trainable params: 26,083
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.176428467239 , Train Accuracy: 0.941678619349
# Valid Loss: 0.44883210571 , Valid Accuracy: 0.879558571746
#
#
# *****************************************************************************
# Running experiment 3/5 : with 4 hidden layers ( 59 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_26 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_78 (Dense)             (None, 59)                15163
# _________________________________________________________________
# dense_79 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_80 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_81 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_82 (Dense)             (None, 5)                 300
# =================================================================
# Total params: 26,083
# Trainable params: 26,083
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.126184158237 , Train Accuracy: 0.95870540882
# Valid Loss: 0.483286034482 , Valid Accuracy: 0.881271009085
#
#
# *****************************************************************************
# Running experiment 4/5 : with 4 hidden layers ( 59 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_27 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_83 (Dense)             (None, 59)                15163
# _________________________________________________________________
# dense_84 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_85 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_86 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_87 (Dense)             (None, 5)                 300
# =================================================================
# Total params: 26,083
# Trainable params: 26,083
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.134093832814 , Train Accuracy: 0.955859899157
# Valid Loss: 0.462806824056 , Valid Accuracy: 0.882856599241
#
#
# *****************************************************************************
# Running experiment 5/5 : with 4 hidden layers ( 59 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_28 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dense_88 (Dense)             (None, 59)                15163
# _________________________________________________________________
# dense_89 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_90 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_91 (Dense)             (None, 59)                3540
# _________________________________________________________________
# dense_92 (Dense)             (None, 5)                 300
# =================================================================
# Total params: 26,083
# Trainable params: 26,083
# Non-trainable params: 0
# _________________________________________________________________
# Train Loss: 0.162367783246 , Train Accuracy: 0.947693517829
# Valid Loss: 0.413116527285 , Valid Accuracy: 0.884695883853

# %% [markdown]
# ## Exercise 6: Tricks (regularization, batch normalization, dropout)
#
# ### Description
#
# Overfitting can also be counteracted with regularization and dropout. Batch normalization is supposed to mainly decrease convergence time.
#
# 1. Try to improve the best validation scores of the model with 1 layer and 100 hidden neurons and the model with 4 hidden layers. Experiment with batch_normalization layers, dropout layers and l1- and l2-regularization on weights (kernels) and biases.
# 2. After you have found good settings, plot for both models the learning curves of the naive model you fitted in the previous exercises together with the learning curves of the current version.
# 3. For proper comparison, plot also the learning curves of the two current models in a third figure.
#
# ### Solution

# %%
##########################################################################
# adding regularisation to the model in the form of weight decay, dropout and
# also batch normalization for reducing internal co-varaince shift
##########################################################################

n_hidden =[100, 59]
n_repeat =[1, 4]
l2_decay= 1e-4
l1_decay= 1e-4

#########################################################
# Custom architecture with additional dropout, batchnorm
#########################################################
def dynamic_model_regularised(neurons, repeat, adddropout=True, addbatchnorm=True):
    y = Input(shape=x_train.shape[1:])
    input_img = y
    for j in range(repeat):
        if adddropout:
            y = Dropout(0.1)(y)
        y = Dense(neurons, activation=None, kernel_regularizer=regularizers.l2(l2_decay), bias_regularizer=regularizers.l1(l1_decay))(y)
        if addbatchnorm:
            y = BatchNormalization()(y)
        y = Activation('relu')(y)
       
    y = Dense(5, activation='softmax')(y)
    model = Model(input_img, y)
    return model

models=[]
for j in range(2):
    print("\n\nModel Summary with {} hidden layers".format(n_repeat[j]))
    models.append(dynamic_model_regularised(n_hidden[j], n_repeat[j]))    
    models[j].summary()
# Out:
# Model Summary with 1 hidden layers
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_87 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dropout_116 (Dropout)        (None, 256)               0
# _________________________________________________________________
# dense_263 (Dense)            (None, 100)               25700
# _________________________________________________________________
# batch_normalization_118 (Bat (None, 100)               400
# _________________________________________________________________
# activation_110 (Activation)  (None, 100)               0
# _________________________________________________________________
# dense_264 (Dense)            (None, 5)                 505
# =================================================================
# Total params: 26,605
# Trainable params: 26,405
# Non-trainable params: 200
# _________________________________________________________________
#
#
# Model Summary with 4 hidden layers
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_88 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dropout_117 (Dropout)        (None, 256)               0
# _________________________________________________________________
# dense_265 (Dense)            (None, 59)                15163
# _________________________________________________________________
# batch_normalization_119 (Bat (None, 59)                236
# _________________________________________________________________
# activation_111 (Activation)  (None, 59)                0
# _________________________________________________________________
# dropout_118 (Dropout)        (None, 59)                0
# _________________________________________________________________
# dense_266 (Dense)            (None, 59)                3540
# _________________________________________________________________
# batch_normalization_120 (Bat (None, 59)                236
# _________________________________________________________________
# activation_112 (Activation)  (None, 59)                0
# _________________________________________________________________
# dropout_119 (Dropout)        (None, 59)                0
# _________________________________________________________________
# dense_267 (Dense)            (None, 59)                3540
# _________________________________________________________________
# batch_normalization_121 (Bat (None, 59)                236
# _________________________________________________________________
# activation_113 (Activation)  (None, 59)                0
# _________________________________________________________________
# dropout_120 (Dropout)        (None, 59)                0
# _________________________________________________________________
# dense_268 (Dense)            (None, 59)                3540
# _________________________________________________________________
# batch_normalization_122 (Bat (None, 59)                236
# _________________________________________________________________
# activation_114 (Activation)  (None, 59)                0
# _________________________________________________________________
# dense_269 (Dense)            (None, 5)                 300
# =================================================================
# Total params: 27,027
# Trainable params: 26,555
# Non-trainable params: 472
# _________________________________________________________________

# %%
############################################################################3#
# Run model for multiple times and plot the summary statistics of best validation loss and accuracy
##############################################################################
import math

lr_adam= 1e-3
n_hidden =[100, 59]
n_repeat =[1, 4]
total_exps = len(n_hidden)
times= 1
n_exps= len(n_hidden)
num_epochs = 500
print(" Running models with {} hidden layers for {} times\n\n".format(', '.join([str(i) for i in range(len(n_hidden))]), times))

data_val_loss     = np.zeros((times,n_exps))
data_val_accuracy = np.zeros((times,n_exps))
data_train_loss   = np.zeros((times,n_exps))
data_train_acc    = np.zeros((times,n_exps))
summary_reg={}


####################################
# Expriments are run for enough epochs and the best model is used to plot the summart statistics
####################################

for i in range(total_exps):
    for k in range(times):
        print("*****************************************************************************")
        print('\n\nRunning experiment {}/{} : with {} hidden layers ({} neurons per hidden layer)'.format(k+1,times, i+1, n_hidden[i]))
        model=dynamic_model_regularised(n_hidden[i], n_repeat[i])
        model.summary()
        #call= keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.001, patience=15, verbose=0, mode='auto')
        saveBestModel = keras.callbacks.ModelCheckpoint("./best_weights.hdf5", monitor='val_acc', verbose=0, save_best_only=True, mode='auto',save_weights_only=True)

        model.compile(loss='categorical_crossentropy',
                  optimizer=keras.optimizers.SGD(lr=0.005),metrics=['accuracy'])
        history= model.fit(x_train, y_train, callbacks=[saveBestModel],
                            batch_size=128, epochs=num_epochs, verbose=1, validation_data=(x_test, y_test))
        model.load_weights("./best_weights.hdf5")
        score = model.evaluate(x_train, y_train, verbose=0)
        print("Train Loss: {} , Train Accuracy: {}".format(score[0], score[1]))
        score = model.evaluate(x_test, y_test, verbose=0)
        print("Test loss: {} , Test accuracy: {}".format(score[0],score[1]))
      
    summary_reg['hidden_{}'.format(n_repeat[i])] = history
# Out:
#  Running models with 0, 1 hidden layers for 1 times
#
#
# *****************************************************************************
#
#
# Running experiment 1/1 : with 1 hidden layers (100 neurons per hidden layer)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_90 (InputLayer)        (None, 256)               0
# _________________________________________________________________
# dropout_122 (Dropout)        (None, 256)               0
# _________________________________________________________________
# dense_272 (Dense)            (None, 100)               25700
# _________________________________________________________________
# batch_normalization_124 (Bat (None, 100)               400
# _________________________________________________________________
# activation_116 (Activation)  (None, 100)               0
# _________________________________________________________________
# dense_273 (Dense)            (None, 5)                 505
# =================================================================
# Total params: 26,605
# Trainable params: 26,405
# Non-trainable params: 200
# _________________________________________________________________
# Train on 43226 samples, validate on 15767 samples
# Epoch 1/500
# 43226/43226 [==============================] - 5s - loss: 1.6696 - acc: 0.2778 - val_loss: 1.5258 - val_acc: 0.3630
# Epoch 2/500
# 43226/43226 [==============================] - 1s - loss: 1.5589 - acc: 0.3379 - val_loss: 1.4508 - val_acc: 0.4246
# Epoch 3/500
# 43226/43226 [==============================] - 1s - loss: 1.5080 - acc: 0.3695 - val_loss: 1.4010 - val_acc: 0.4615
# Epoch 4/500
# 43226/43226 [==============================] - 1s - loss: 1.4643 - acc: 0.3994 - val_loss: 1.3537 - val_acc: 0.4927
# Epoch 5/500
# 43226/43226 [==============================] - 1s - loss: 1.4217 - acc: 0.4245 - val_loss: 1.3060 - val_acc: 0.5164
# Epoch 6/500
# 43226/43226 [==============================] - 1s - loss: 1.3781 - acc: 0.4505 - val_loss: 1.2621 - val_acc: 0.5298
# Epoch 7/500
# 43226/43226 [==============================] - 1s - loss: 1.3364 - acc: 0.4758 - val_loss: 1.2161 - val_acc: 0.5678
# Epoch 8/500
# 43226/43226 [==============================] - 1s - loss: 1.2957 - acc: 0.4995 - val_loss: 1.1694 - val_acc: 0.5846
# Epoch 9/500
# 43226/43226 [==============================] - 1s - loss: 1.2565 - acc: 0.5215 - val_loss: 1.1320 - val_acc: 0.6042
# Epoch 10/500
# 43226/43226 [==============================] - 1s - loss: 1.2211 - acc: 0.5399 - val_loss: 1.1001 - val_acc: 0.6241
# Epoch 11/500
# 43226/43226 [==============================] - 1s - loss: 1.1799 - acc: 0.5669 - val_loss: 1.0651 - val_acc: 0.6353
# Epoch 12/500
# 43226/43226 [==============================] - 1s - loss: 1.1493 - acc: 0.5834 - val_loss: 1.0366 - val_acc: 0.6518
# Epoch 13/500
# 43226/43226 [==============================] - 1s - loss: 1.1222 - acc: 0.5956 - val_loss: 1.0122 - val_acc: 0.6688
# Epoch 14/500
# 43226/43226 [==============================] - 1s - loss: 1.0960 - acc: 0.6095 - val_loss: 0.9884 - val_acc: 0.6808
# Epoch 15/500
# 43226/43226 [==============================] - 1s - loss: 1.0681 - acc: 0.6267 - val_loss: 0.9686 - val_acc: 0.6870
# Epoch 16/500
# 43226/43226 [==============================] - 1s - loss: 1.0482 - acc: 0.6326 - val_loss: 0.9478 - val_acc: 0.6978
# Epoch 17/500
# 43226/43226 [==============================] - 1s - loss: 1.0237 - acc: 0.6470 - val_loss: 0.9346 - val_acc: 0.7031
# Epoch 18/500
# 43226/43226 [==============================] - 1s - loss: 1.0067 - acc: 0.6561 - val_loss: 0.9220 - val_acc: 0.7082
# Epoch 19/500
# 43226/43226 [==============================] - 1s - loss: 0.9868 - acc: 0.6609 - val_loss: 0.9007 - val_acc: 0.7138
# Epoch 20/500
# 43226/43226 [==============================] - 1s - loss: 0.9733 - acc: 0.6723 - val_loss: 0.8869 - val_acc: 0.7202
# Epoch 21/500
# 43226/43226 [==============================] - 1s - loss: 0.9567 - acc: 0.6776 - val_loss: 0.8804 - val_acc: 0.7281
# Epoch 22/500
# 43226/43226 [==============================] - 1s - loss: 0.9423 - acc: 0.6849 - val_loss: 0.8662 - val_acc: 0.7292
# Epoch 23/500
# 43226/43226 [==============================] - 1s - loss: 0.9293 - acc: 0.6912 - val_loss: 0.8548 - val_acc: 0.7352
# Epoch 24/500
# 43226/43226 [==============================] - 1s - loss: 0.9173 - acc: 0.6977 - val_loss: 0.8426 - val_acc: 0.7389
# Epoch 25/500
# 43226/43226 [==============================] - 1s - loss: 0.9090 - acc: 0.6990 - val_loss: 0.8402 - val_acc: 0.7419
# Epoch 26/500
# 43226/43226 [==============================] - 1s - loss: 0.8953 - acc: 0.7037 - val_loss: 0.8334 - val_acc: 0.7395
# Epoch 27/500
# 43226/43226 [==============================] - 1s - loss: 0.8911 - acc: 0.7061 - val_loss: 0.8216 - val_acc: 0.7450
# Epoch 28/500
# 43226/43226 [==============================] - 1s - loss: 0.8767 - acc: 0.7114 - val_loss: 0.8160 - val_acc: 0.7497
# Epoch 29/500
# 43226/43226 [==============================] - 1s - loss: 0.8704 - acc: 0.7140 - val_loss: 0.8056 - val_acc: 0.7546
# Epoch 30/500
# 43226/43226 [==============================] - 1s - loss: 0.8625 - acc: 0.7160 - val_loss: 0.8042 - val_acc: 0.7502
# Epoch 31/500
# 43226/43226 [==============================] - 1s - loss: 0.8582 - acc: 0.7200 - val_loss: 0.7945 - val_acc: 0.7556
# Epoch 32/500
# 43226/43226 [==============================] - 1s - loss: 0.8492 - acc: 0.7219 - val_loss: 0.7819 - val_acc: 0.7639
# Epoch 33/500
# 43226/43226 [==============================] - 1s - loss: 0.8408 - acc: 0.7268 - val_loss: 0.7782 - val_acc: 0.7620
# Epoch 34/500
# 43226/43226 [==============================] - 1s - loss: 0.8361 - acc: 0.7284 - val_loss: 0.7799 - val_acc: 0.7650
# Epoch 35/500
# 43226/43226 [==============================] - 1s - loss: 0.8301 - acc: 0.7296 - val_loss: 0.7656 - val_acc: 0.7682
# Epoch 36/500
# 43226/43226 [==============================] - 1s - loss: 0.8237 - acc: 0.7314 - val_loss: 0.7615 - val_acc: 0.7719
# Epoch 37/500
# 43226/43226 [==============================] - 1s - loss: 0.8170 - acc: 0.7341 - val_loss: 0.7616 - val_acc: 0.7690
# Epoch 38/500
# 43226/43226 [==============================] - 1s - loss: 0.8146 - acc: 0.7357 - val_loss: 0.7508 - val_acc: 0.7733
# Epoch 39/500
# 43226/43226 [==============================] - 1s - loss: 0.8048 - acc: 0.7387 - val_loss: 0.7457 - val_acc: 0.7761
# Epoch 40/500
# 43226/43226 [==============================] - 1s - loss: 0.8053 - acc: 0.7389 - val_loss: 0.7422 - val_acc: 0.7782
# Epoch 41/500
# 43226/43226 [==============================] - 1s - loss: 0.7995 - acc: 0.7423 - val_loss: 0.7362 - val_acc: 0.7803
# Epoch 42/500
# 43226/43226 [==============================] - 1s - loss: 0.7925 - acc: 0.7416 - val_loss: 0.7362 - val_acc: 0.7777
# Epoch 43/500
# 43226/43226 [==============================] - 1s - loss: 0.7892 - acc: 0.7446 - val_loss: 0.7302 - val_acc: 0.7818
# Epoch 44/500
# 43226/43226 [==============================] - 1s - loss: 0.7887 - acc: 0.7442 - val_loss: 0.7219 - val_acc: 0.7835
# Epoch 45/500
# 43226/43226 [==============================] - 1s - loss: 0.7833 - acc: 0.7460 - val_loss: 0.7167 - val_acc: 0.7873
# Epoch 46/500
# 43226/43226 [==============================] - 1s - loss: 0.7828 - acc: 0.7445 - val_loss: 0.7133 - val_acc: 0.7882
# Epoch 47/500
# 43226/43226 [==============================] - 1s - loss: 0.7770 - acc: 0.7504 - val_loss: 0.7143 - val_acc: 0.7875
# Epoch 48/500
# 43226/43226 [==============================] - 1s - loss: 0.7729 - acc: 0.7517 - val_loss: 0.7099 - val_acc: 0.7891
# Epoch 49/500
# 43226/43226 [==============================] - 1s - loss: 0.7717 - acc: 0.7522 - val_loss: 0.7051 - val_acc: 0.7904
# Epoch 50/500
# 43226/43226 [==============================] - 1s - loss: 0.7654 - acc: 0.7526 - val_loss: 0.6984 - val_acc: 0.7924
# Epoch 51/500
# 43226/43226 [==============================] - 1s - loss: 0.7630 - acc: 0.7526 - val_loss: 0.7071 - val_acc: 0.7840
# Epoch 52/500
# 43226/43226 [==============================] - 1s - loss: 0.7586 - acc: 0.7539 - val_loss: 0.6957 - val_acc: 0.7911
# Epoch 53/500
# 43226/43226 [==============================] - 1s - loss: 0.7545 - acc: 0.7573 - val_loss: 0.6911 - val_acc: 0.7970
# Epoch 54/500
# 43226/43226 [==============================] - 1s - loss: 0.7539 - acc: 0.7562 - val_loss: 0.6900 - val_acc: 0.7946
# Epoch 55/500
# 43226/43226 [==============================] - 1s - loss: 0.7510 - acc: 0.7596 - val_loss: 0.6872 - val_acc: 0.7966
# Epoch 56/500
# 43226/43226 [==============================] - 1s - loss: 0.7503 - acc: 0.7584 - val_loss: 0.6905 - val_acc: 0.7962
# Epoch 57/500
# 43226/43226 [==============================] - 1s - loss: 0.7455 - acc: 0.7587 - val_loss: 0.6809 - val_acc: 0.7982
# Epoch 58/500
# 43226/43226 [==============================] - 1s - loss: 0.7402 - acc: 0.7602 - val_loss: 0.6733 - val_acc: 0.8018
# Epoch 59/500
# 43226/43226 [==============================] - 1s - loss: 0.7427 - acc: 0.7610 - val_loss: 0.6752 - val_acc: 0.8002
# Epoch 60/500
# 43226/43226 [==============================] - 1s - loss: 0.7347 - acc: 0.7641 - val_loss: 0.6651 - val_acc: 0.8053
# Epoch 61/500
# 43226/43226 [==============================] - 1s - loss: 0.7333 - acc: 0.7643 - val_loss: 0.6623 - val_acc: 0.8051
# Epoch 62/500
# 43226/43226 [==============================] - 1s - loss: 0.7280 - acc: 0.7671 - val_loss: 0.6611 - val_acc: 0.8059
# Epoch 63/500
# 43226/43226 [==============================] - 1s - loss: 0.7325 - acc: 0.7640 - val_loss: 0.6603 - val_acc: 0.8079
# Epoch 64/500
# 43226/43226 [==============================] - 1s - loss: 0.7239 - acc: 0.7672 - val_loss: 0.6522 - val_acc: 0.8106
# Epoch 65/500
# 43226/43226 [==============================] - 1s - loss: 0.7255 - acc: 0.7668 - val_loss: 0.6495 - val_acc: 0.8123
# Epoch 66/500
# 43226/43226 [==============================] - 1s - loss: 0.7234 - acc: 0.7675 - val_loss: 0.6501 - val_acc: 0.8126
# Epoch 67/500
# 43226/43226 [==============================] - 1s - loss: 0.7184 - acc: 0.7699 - val_loss: 0.6491 - val_acc: 0.8113
# Epoch 68/500
# 43226/43226 [==============================] - 1s - loss: 0.7164 - acc: 0.7710 - val_loss: 0.6484 - val_acc: 0.8073
# Epoch 69/500
# 43226/43226 [==============================] - 1s - loss: 0.7166 - acc: 0.7687 - val_loss: 0.6669 - val_acc: 0.7975
# Epoch 70/500
# 43226/43226 [==============================] - 1s - loss: 0.7102 - acc: 0.7700 - val_loss: 0.6389 - val_acc: 0.8144
# Epoch 71/500
# 43226/43226 [==============================] - 1s - loss: 0.7067 - acc: 0.7719 - val_loss: 0.6419 - val_acc: 0.8126
# Epoch 72/500
# 43226/43226 [==============================] - 1s - loss: 0.7085 - acc: 0.7732 - val_loss: 0.6368 - val_acc: 0.8119
# Epoch 73/500
# 43226/43226 [==============================] - 1s - loss: 0.7058 - acc: 0.7749 - val_loss: 0.6312 - val_acc: 0.8194
# Epoch 74/500
# 43226/43226 [==============================] - 1s - loss: 0.7013 - acc: 0.7769 - val_loss: 0.6280 - val_acc: 0.8194
# Epoch 75/500
# 43226/43226 [==============================] - 1s - loss: 0.7021 - acc: 0.7750 - val_loss: 0.6330 - val_acc: 0.8133
# Epoch 76/500
# 43226/43226 [==============================] - 1s - loss: 0.7021 - acc: 0.7749 - val_loss: 0.6338 - val_acc: 0.8138
# Epoch 77/500
# 43226/43226 [==============================] - 1s - loss: 0.6975 - acc: 0.7777 - val_loss: 0.6229 - val_acc: 0.8226
# Epoch 78/500
# 43226/43226 [==============================] - 1s - loss: 0.6958 - acc: 0.7778 - val_loss: 0.6177 - val_acc: 0.8255
# Epoch 79/500
# 43226/43226 [==============================] - 1s - loss: 0.6994 - acc: 0.7762 - val_loss: 0.6184 - val_acc: 0.8250
# Epoch 80/500
# 43226/43226 [==============================] - 1s - loss: 0.6874 - acc: 0.7821 - val_loss: 0.6142 - val_acc: 0.8232
# Epoch 81/500
# 43226/43226 [==============================] - 1s - loss: 0.6884 - acc: 0.7806 - val_loss: 0.6269 - val_acc: 0.8192
# Epoch 82/500
# 43226/43226 [==============================] - 1s - loss: 0.6884 - acc: 0.7804 - val_loss: 0.6224 - val_acc: 0.8177
# Epoch 83/500
# 43226/43226 [==============================] - 1s - loss: 0.6801 - acc: 0.7841 - val_loss: 0.6070 - val_acc: 0.8307
# Epoch 84/500
# 43226/43226 [==============================] - 1s - loss: 0.6850 - acc: 0.7806 - val_loss: 0.6056 - val_acc: 0.8267
# Epoch 85/500
# 43226/43226 [==============================] - 1s - loss: 0.6851 - acc: 0.7825 - val_loss: 0.6020 - val_acc: 0.8278
# Epoch 86/500
# 43226/43226 [==============================] - 1s - loss: 0.6805 - acc: 0.7824 - val_loss: 0.6029 - val_acc: 0.8296
# Epoch 87/500
# 43226/43226 [==============================] - 1s - loss: 0.6806 - acc: 0.7829 - val_loss: 0.5993 - val_acc: 0.8274
# Epoch 88/500
# 43226/43226 [==============================] - 1s - loss: 0.6791 - acc: 0.7834 - val_loss: 0.5956 - val_acc: 0.8321
# Epoch 89/500
# 43226/43226 [==============================] - 1s - loss: 0.6759 - acc: 0.7849 - val_loss: 0.6079 - val_acc: 0.8270
# Epoch 90/500
# 43226/43226 [==============================] - 1s - loss: 0.6752 - acc: 0.7836 - val_loss: 0.5992 - val_acc: 0.8306
# Epoch 91/500
# 43226/43226 [==============================] - 1s - loss: 0.6708 - acc: 0.7868 - val_loss: 0.5924 - val_acc: 0.8303
# Epoch 92/500
# 43226/43226 [==============================] - 1s - loss: 0.6738 - acc: 0.7868 - val_loss: 0.5858 - val_acc: 0.8373
# Epoch 93/500
# 43226/43226 [==============================] - 1s - loss: 0.6675 - acc: 0.7898 - val_loss: 0.5854 - val_acc: 0.8366
# Epoch 94/500
# 43226/43226 [==============================] - 1s - loss: 0.6665 - acc: 0.7897 - val_loss: 0.5903 - val_acc: 0.8341
# Epoch 95/500
# 43226/43226 [==============================] - 1s - loss: 0.6666 - acc: 0.7898 - val_loss: 0.5873 - val_acc: 0.8384
# Epoch 96/500
# 43226/43226 [==============================] - 1s - loss: 0.6643 - acc: 0.7887 - val_loss: 0.5806 - val_acc: 0.8382
# Epoch 97/500
# 43226/43226 [==============================] - 1s - loss: 0.6603 - acc: 0.7904 - val_loss: 0.5855 - val_acc: 0.8343
# Epoch 98/500
# 43226/43226 [==============================] - 1s - loss: 0.6607 - acc: 0.7924 - val_loss: 0.5780 - val_acc: 0.8400
# Epoch 99/500
# 43226/43226 [==============================] - 1s - loss: 0.6637 - acc: 0.7907 - val_loss: 0.5850 - val_acc: 0.8331
# Epoch 100/500
# 43226/43226 [==============================] - 1s - loss: 0.6619 - acc: 0.7916 - val_loss: 0.5941 - val_acc: 0.8289
# Epoch 101/500
# 43226/43226 [==============================] - 1s - loss: 0.6605 - acc: 0.7909 - val_loss: 0.5721 - val_acc: 0.8413
# Epoch 102/500
# 43226/43226 [==============================] - 1s - loss: 0.6562 - acc: 0.7926 - val_loss: 0.5778 - val_acc: 0.8352
# Epoch 103/500
# 43226/43226 [==============================] - 1s - loss: 0.6561 - acc: 0.7927 - val_loss: 0.5838 - val_acc: 0.8355
# Epoch 104/500
# 43226/43226 [==============================] - 1s - loss: 0.6566 - acc: 0.7925 - val_loss: 0.5705 - val_acc: 0.8428
# Epoch 105/500
# 43226/43226 [==============================] - 1s - loss: 0.6503 - acc: 0.7960 - val_loss: 0.5649 - val_acc: 0.8456
# Epoch 106/500
# 43226/43226 [==============================] - 1s - loss: 0.6557 - acc: 0.7932 - val_loss: 0.5694 - val_acc: 0.8450
# Epoch 107/500
# 43226/43226 [==============================] - 1s - loss: 0.6490 - acc: 0.7934 - val_loss: 0.5706 - val_acc: 0.8416
# Epoch 108/500
# 43226/43226 [==============================] - 1s - loss: 0.6498 - acc: 0.7935 - val_loss: 0.5657 - val_acc: 0.8438
# Epoch 109/500
# 43226/43226 [==============================] - 1s - loss: 0.6449 - acc: 0.7960 - val_loss: 0.5629 - val_acc: 0.8435
# Epoch 110/500
# 43226/43226 [==============================] - 1s - loss: 0.6508 - acc: 0.7940 - val_loss: 0.5626 - val_acc: 0.8489
# Epoch 111/500
# 43226/43226 [==============================] - 1s - loss: 0.6411 - acc: 0.7962 - val_loss: 0.5572 - val_acc: 0.8463
# Epoch 112/500
# 43226/43226 [==============================] - 1s - loss: 0.6484 - acc: 0.7936 - val_loss: 0.5665 - val_acc: 0.8413
# Epoch 113/500
# 43226/43226 [==============================] - 1s - loss: 0.6450 - acc: 0.7970 - val_loss: 0.5580 - val_acc: 0.8459
# Epoch 114/500
# 43226/43226 [==============================] - 1s - loss: 0.6400 - acc: 0.7979 - val_loss: 0.5561 - val_acc: 0.8475
# Epoch 115/500
# 43226/43226 [==============================] - 1s - loss: 0.6393 - acc: 0.7979 - val_loss: 0.5632 - val_acc: 0.8401
# Epoch 116/500
# 43226/43226 [==============================] - 1s - loss: 0.6375 - acc: 0.7989 - val_loss: 0.5522 - val_acc: 0.8503
# Epoch 117/500
# 43226/43226 [==============================] - 1s - loss: 0.6384 - acc: 0.7990 - val_loss: 0.5538 - val_acc: 0.8492
# Epoch 118/500
# 43226/43226 [==============================] - 2s - loss: 0.6403 - acc: 0.7984 - val_loss: 0.5502 - val_acc: 0.8530
# Epoch 119/500
# 43226/43226 [==============================] - 1s - loss: 0.6385 - acc: 0.7984 - val_loss: 0.5564 - val_acc: 0.8469
# Epoch 120/500
# 43226/43226 [==============================] - 1s - loss: 0.6351 - acc: 0.8007 - val_loss: 0.5538 - val_acc: 0.8490
# Epoch 121/500
# 43226/43226 [==============================] - 1s - loss: 0.6307 - acc: 0.7996 - val_loss: 0.5524 - val_acc: 0.8510
# Epoch 122/500
# 43226/43226 [==============================] - 1s - loss: 0.6321 - acc: 0.8018 - val_loss: 0.5437 - val_acc: 0.8530
# Epoch 123/500
# 43226/43226 [==============================] - 1s - loss: 0.6285 - acc: 0.7997 - val_loss: 0.5452 - val_acc: 0.8510
# Epoch 124/500
# 43226/43226 [==============================] - 1s - loss: 0.6305 - acc: 0.8014 - val_loss: 0.5413 - val_acc: 0.8553
# Epoch 125/500
# 43226/43226 [==============================] - 1s - loss: 0.6295 - acc: 0.8028 - val_loss: 0.5451 - val_acc: 0.8501
# Epoch 126/500
# 43226/43226 [==============================] - 1s - loss: 0.6241 - acc: 0.8029 - val_loss: 0.5395 - val_acc: 0.8528
# Epoch 127/500
# 43226/43226 [==============================] - 1s - loss: 0.6300 - acc: 0.8016 - val_loss: 0.5442 - val_acc: 0.8502
# Epoch 128/500
# 43226/43226 [==============================] - 1s - loss: 0.6271 - acc: 0.8032 - val_loss: 0.5359 - val_acc: 0.8567
# Epoch 129/500
# 43226/43226 [==============================] - 1s - loss: 0.6241 - acc: 0.8037 - val_loss: 0.5383 - val_acc: 0.8550
# Epoch 130/500
# 43226/43226 [==============================] - 1s - loss: 0.6256 - acc: 0.8047 - val_loss: 0.5346 - val_acc: 0.8522
# Epoch 131/500
# 43226/43226 [==============================] - 1s - loss: 0.6271 - acc: 0.8002 - val_loss: 0.5331 - val_acc: 0.8562
# Epoch 132/500
# 43226/43226 [==============================] - 1s - loss: 0.6245 - acc: 0.8044 - val_loss: 0.5343 - val_acc: 0.8542
# Epoch 133/500
# 43226/43226 [==============================] - 1s - loss: 0.6226 - acc: 0.8039 - val_loss: 0.5420 - val_acc: 0.8495
# Epoch 134/500
# 43226/43226 [==============================] - 1s - loss: 0.6178 - acc: 0.8045 - val_loss: 0.5489 - val_acc: 0.8447
# Epoch 135/500
# 43226/43226 [==============================] - 1s - loss: 0.6227 - acc: 0.8060 - val_loss: 0.5307 - val_acc: 0.8537
# Epoch 136/500
# 43226/43226 [==============================] - 1s - loss: 0.6213 - acc: 0.8042 - val_loss: 0.5278 - val_acc: 0.8569
# Epoch 137/500
# 43226/43226 [==============================] - 1s - loss: 0.6226 - acc: 0.8043 - val_loss: 0.5326 - val_acc: 0.8579
# Epoch 138/500
# 43226/43226 [==============================] - 1s - loss: 0.6164 - acc: 0.8059 - val_loss: 0.5309 - val_acc: 0.8534
# Epoch 139/500
# 43226/43226 [==============================] - 1s - loss: 0.6129 - acc: 0.8089 - val_loss: 0.5300 - val_acc: 0.8534
# Epoch 140/500
# 43226/43226 [==============================] - 1s - loss: 0.6178 - acc: 0.8055 - val_loss: 0.5279 - val_acc: 0.8553
# Epoch 141/500
# 43226/43226 [==============================] - 1s - loss: 0.6198 - acc: 0.8043 - val_loss: 0.5249 - val_acc: 0.8583
# Epoch 142/500
# 43226/43226 [==============================] - 1s - loss: 0.6153 - acc: 0.8066 - val_loss: 0.5312 - val_acc: 0.8560
# Epoch 143/500
# 43226/43226 [==============================] - 1s - loss: 0.6129 - acc: 0.8066 - val_loss: 0.5219 - val_acc: 0.8594
# Epoch 144/500
# 43226/43226 [==============================] - 1s - loss: 0.6131 - acc: 0.8086 - val_loss: 0.5222 - val_acc: 0.8583
# Epoch 145/500
# 43226/43226 [==============================] - 1s - loss: 0.6152 - acc: 0.8070 - val_loss: 0.5222 - val_acc: 0.8608
# Epoch 146/500
# 43226/43226 [==============================] - 1s - loss: 0.6076 - acc: 0.8095 - val_loss: 0.5248 - val_acc: 0.8600
# Epoch 147/500
# 43226/43226 [==============================] - 1s - loss: 0.6111 - acc: 0.8089 - val_loss: 0.5178 - val_acc: 0.8591
# Epoch 148/500
# 43226/43226 [==============================] - 1s - loss: 0.6073 - acc: 0.8093 - val_loss: 0.5167 - val_acc: 0.8605
# Epoch 149/500
# 43226/43226 [==============================] - 1s - loss: 0.6043 - acc: 0.8100 - val_loss: 0.5190 - val_acc: 0.8597
# Epoch 150/500
# 43226/43226 [==============================] - 1s - loss: 0.6064 - acc: 0.8081 - val_loss: 0.5268 - val_acc: 0.8539
# Epoch 151/500
# 43226/43226 [==============================] - 1s - loss: 0.6096 - acc: 0.8084 - val_loss: 0.5248 - val_acc: 0.8562
# Epoch 152/500
# 43226/43226 [==============================] - 1s - loss: 0.6106 - acc: 0.8084 - val_loss: 0.5194 - val_acc: 0.8573
# Epoch 153/500
# 43226/43226 [==============================] - 1s - loss: 0.6028 - acc: 0.8139 - val_loss: 0.5172 - val_acc: 0.8593
# Epoch 154/500
# 43226/43226 [==============================] - 1s - loss: 0.6055 - acc: 0.8094 - val_loss: 0.5197 - val_acc: 0.8602
# Epoch 155/500
# 43226/43226 [==============================] - 1s - loss: 0.6077 - acc: 0.8081 - val_loss: 0.5230 - val_acc: 0.8584
# Epoch 156/500
# 43226/43226 [==============================] - 1s - loss: 0.6045 - acc: 0.8104 - val_loss: 0.5161 - val_acc: 0.8588
# Epoch 157/500
# 43226/43226 [==============================] - 1s - loss: 0.6071 - acc: 0.8096 - val_loss: 0.5141 - val_acc: 0.8636
# Epoch 158/500
# 43226/43226 [==============================] - 1s - loss: 0.6046 - acc: 0.8095 - val_loss: 0.5173 - val_acc: 0.8610
# Epoch 159/500
# 43226/43226 [==============================] - 1s - loss: 0.6040 - acc: 0.8121 - val_loss: 0.5155 - val_acc: 0.8617
# Epoch 160/500
# 43226/43226 [==============================] - 1s - loss: 0.6066 - acc: 0.8109 - val_loss: 0.5175 - val_acc: 0.8584
# Epoch 161/500
# 43226/43226 [==============================] - 1s - loss: 0.5986 - acc: 0.8124 - val_loss: 0.5094 - val_acc: 0.8646
# Epoch 162/500
# 43226/43226 [==============================] - 1s - loss: 0.5933 - acc: 0.8138 - val_loss: 0.5114 - val_acc: 0.8607
# Epoch 163/500
# 43226/43226 [==============================] - 1s - loss: 0.6005 - acc: 0.8138 - val_loss: 0.5181 - val_acc: 0.8589
# Epoch 164/500
# 43226/43226 [==============================] - 1s - loss: 0.5986 - acc: 0.8118 - val_loss: 0.5037 - val_acc: 0.8674
# Epoch 165/500
# 43226/43226 [==============================] - 1s - loss: 0.6013 - acc: 0.8130 - val_loss: 0.5093 - val_acc: 0.8640
# Epoch 166/500
# 43226/43226 [==============================] - 1s - loss: 0.5998 - acc: 0.8134 - val_loss: 0.5081 - val_acc: 0.8649
# Epoch 167/500
# 43226/43226 [==============================] - 1s - loss: 0.5965 - acc: 0.8124 - val_loss: 0.5042 - val_acc: 0.8651
# Epoch 168/500
# 43226/43226 [==============================] - 1s - loss: 0.5969 - acc: 0.8130 - val_loss: 0.5107 - val_acc: 0.8626
# Epoch 169/500
# 43226/43226 [==============================] - 1s - loss: 0.5907 - acc: 0.8159 - val_loss: 0.5096 - val_acc: 0.8644
# Epoch 170/500
# 43226/43226 [==============================] - 1s - loss: 0.5959 - acc: 0.8138 - val_loss: 0.5132 - val_acc: 0.8619
# Epoch 171/500
# 43226/43226 [==============================] - 1s - loss: 0.6005 - acc: 0.8137 - val_loss: 0.5092 - val_acc: 0.8609
# Epoch 172/500
# 43226/43226 [==============================] - 1s - loss: 0.5960 - acc: 0.8147 - val_loss: 0.5037 - val_acc: 0.8662
# Epoch 173/500
# 43226/43226 [==============================] - 1s - loss: 0.5975 - acc: 0.8132 - val_loss: 0.5018 - val_acc: 0.8648
# Epoch 174/500
# 43226/43226 [==============================] - 1s - loss: 0.5938 - acc: 0.8130 - val_loss: 0.5003 - val_acc: 0.8663
# Epoch 175/500
# 43226/43226 [==============================] - 1s - loss: 0.5939 - acc: 0.8132 - val_loss: 0.5066 - val_acc: 0.8633
# Epoch 176/500
# 43226/43226 [==============================] - 1s - loss: 0.5932 - acc: 0.8133 - val_loss: 0.5112 - val_acc: 0.8595
# Epoch 177/500
# 43226/43226 [==============================] - 1s - loss: 0.5917 - acc: 0.8156 - val_loss: 0.5003 - val_acc: 0.8688
# Epoch 178/500
# 43226/43226 [==============================] - 1s - loss: 0.5953 - acc: 0.8140 - val_loss: 0.4936 - val_acc: 0.8699
# Epoch 179/500
# 43226/43226 [==============================] - 1s - loss: 0.5954 - acc: 0.8128 - val_loss: 0.5045 - val_acc: 0.8638
# Epoch 180/500
# 43226/43226 [==============================] - 1s - loss: 0.5909 - acc: 0.8152 - val_loss: 0.4957 - val_acc: 0.8676
# Epoch 181/500
# 43226/43226 [==============================] - 1s - loss: 0.5907 - acc: 0.8149 - val_loss: 0.5037 - val_acc: 0.8654
# Epoch 182/500
# 43226/43226 [==============================] - 1s - loss: 0.5921 - acc: 0.8164 - val_loss: 0.4979 - val_acc: 0.8662
# Epoch 183/500
# 43226/43226 [==============================] - 1s - loss: 0.5883 - acc: 0.8169 - val_loss: 0.4914 - val_acc: 0.8698
# Epoch 184/500
# 43226/43226 [==============================] - 1s - loss: 0.5866 - acc: 0.8166 - val_loss: 0.4965 - val_acc: 0.8676
# Epoch 185/500
# 43226/43226 [==============================] - 1s - loss: 0.5902 - acc: 0.8153 - val_loss: 0.4980 - val_acc: 0.8667
# Epoch 186/500
# 43226/43226 [==============================] - 1s - loss: 0.5878 - acc: 0.8178 - val_loss: 0.4929 - val_acc: 0.8689
# Epoch 187/500
# 43226/43226 [==============================] - 1s - loss: 0.5869 - acc: 0.8149 - val_loss: 0.4946 - val_acc: 0.8685
# Epoch 188/500
# 43226/43226 [==============================] - 1s - loss: 0.5905 - acc: 0.8153 - val_loss: 0.4962 - val_acc: 0.8661
# Epoch 189/500
# 43226/43226 [==============================] - 1s - loss: 0.5910 - acc: 0.8172 - val_loss: 0.4987 - val_acc: 0.8676
# Epoch 190/500
# 43226/43226 [==============================] - 1s - loss: 0.5878 - acc: 0.8163 - val_loss: 0.4937 - val_acc: 0.8692
# Epoch 191/500
# 43226/43226 [==============================] - 1s - loss: 0.5841 - acc: 0.8163 - val_loss: 0.5027 - val_acc: 0.8643
# Epoch 192/500
# 43226/43226 [==============================] - 1s - loss: 0.5870 - acc: 0.8169 - val_loss: 0.4916 - val_acc: 0.8701
# Epoch 193/500
# 43226/43226 [==============================] - 1s - loss: 0.5797 - acc: 0.8190 - val_loss: 0.4957 - val_acc: 0.8679
# Epoch 194/500
# 43226/43226 [==============================] - 1s - loss: 0.5824 - acc: 0.8152 - val_loss: 0.4899 - val_acc: 0.8706
# Epoch 195/500
# 43226/43226 [==============================] - 1s - loss: 0.5901 - acc: 0.8152 - val_loss: 0.4869 - val_acc: 0.8702
# Epoch 196/500
# 43226/43226 [==============================] - 1s - loss: 0.5774 - acc: 0.8202 - val_loss: 0.5004 - val_acc: 0.8645
# Epoch 197/500
# 43226/43226 [==============================] - 1s - loss: 0.5773 - acc: 0.8186 - val_loss: 0.4985 - val_acc: 0.8688
# Epoch 198/500
# 43226/43226 [==============================] - 1s - loss: 0.5775 - acc: 0.8211 - val_loss: 0.4898 - val_acc: 0.8704
# Epoch 199/500
# 43226/43226 [==============================] - 1s - loss: 0.5813 - acc: 0.8162 - val_loss: 0.4960 - val_acc: 0.8674
# Epoch 200/500
# 43226/43226 [==============================] - 1s - loss: 0.5827 - acc: 0.8189 - val_loss: 0.4918 - val_acc: 0.8688
# Epoch 201/500
# 43226/43226 [==============================] - 1s - loss: 0.5820 - acc: 0.8176 - val_loss: 0.4901 - val_acc: 0.8688
# Epoch 202/500
# 43226/43226 [==============================] - 1s - loss: 0.5757 - acc: 0.8202 - val_loss: 0.4918 - val_acc: 0.8695
# Epoch 203/500
# 43226/43226 [==============================] - 1s - loss: 0.5814 - acc: 0.8196 - val_loss: 0.5012 - val_acc: 0.8630
# Epoch 204/500
# 43226/43226 [==============================] - 1s - loss: 0.5785 - acc: 0.8191 - val_loss: 0.4878 - val_acc: 0.8713
# Epoch 205/500
# 43226/43226 [==============================] - 1s - loss: 0.5799 - acc: 0.8179 - val_loss: 0.4816 - val_acc: 0.8728
# Epoch 206/500
# 43226/43226 [==============================] - 1s - loss: 0.5749 - acc: 0.8190 - val_loss: 0.5004 - val_acc: 0.8629
# Epoch 207/500
# 43226/43226 [==============================] - 1s - loss: 0.5773 - acc: 0.8187 - val_loss: 0.4894 - val_acc: 0.8721
# Epoch 208/500
# 43226/43226 [==============================] - 1s - loss: 0.5742 - acc: 0.8203 - val_loss: 0.4926 - val_acc: 0.8688
# Epoch 209/500
# 43226/43226 [==============================] - 1s - loss: 0.5735 - acc: 0.8195 - val_loss: 0.4848 - val_acc: 0.8699
# Epoch 210/500
# 43226/43226 [==============================] - 1s - loss: 0.5763 - acc: 0.8233 - val_loss: 0.4908 - val_acc: 0.8674
# Epoch 211/500
# 43226/43226 [==============================] - 1s - loss: 0.5752 - acc: 0.8192 - val_loss: 0.4844 - val_acc: 0.8726
# Epoch 212/500
# 43226/43226 [==============================] - 1s - loss: 0.5762 - acc: 0.8217 - val_loss: 0.4921 - val_acc: 0.8678
# Epoch 213/500
# 43226/43226 [==============================] - 1s - loss: 0.5774 - acc: 0.8205 - val_loss: 0.4860 - val_acc: 0.8716
# Epoch 214/500
# 43226/43226 [==============================] - 1s - loss: 0.5761 - acc: 0.8221 - val_loss: 0.4834 - val_acc: 0.8721
# Epoch 215/500
# 43226/43226 [==============================] - 1s - loss: 0.5789 - acc: 0.8197 - val_loss: 0.4895 - val_acc: 0.8700
# Epoch 216/500
# 43226/43226 [==============================] - 1s - loss: 0.5687 - acc: 0.8212 - val_loss: 0.4866 - val_acc: 0.8707
# Epoch 217/500
# 43226/43226 [==============================] - 1s - loss: 0.5734 - acc: 0.8204 - val_loss: 0.4834 - val_acc: 0.8704
# Epoch 218/500
# 43226/43226 [==============================] - 1s - loss: 0.5708 - acc: 0.8237 - val_loss: 0.4870 - val_acc: 0.8704
# Epoch 219/500
# 43226/43226 [==============================] - 1s - loss: 0.5726 - acc: 0.8215 - val_loss: 0.4893 - val_acc: 0.8673
# Epoch 220/500
# 43226/43226 [==============================] - 1s - loss: 0.5762 - acc: 0.8198 - val_loss: 0.4870 - val_acc: 0.8726
# Epoch 221/500
# 43226/43226 [==============================] - 1s - loss: 0.5732 - acc: 0.8209 - val_loss: 0.4753 - val_acc: 0.8750
# Epoch 222/500
# 43226/43226 [==============================] - 1s - loss: 0.5665 - acc: 0.8257 - val_loss: 0.4899 - val_acc: 0.8698
# Epoch 223/500
# 43226/43226 [==============================] - 1s - loss: 0.5657 - acc: 0.8220 - val_loss: 0.4799 - val_acc: 0.8737
# Epoch 224/500
# 43226/43226 [==============================] - 1s - loss: 0.5717 - acc: 0.8205 - val_loss: 0.4867 - val_acc: 0.8704
# Epoch 225/500
# 43226/43226 [==============================] - 1s - loss: 0.5673 - acc: 0.8205 - val_loss: 0.4764 - val_acc: 0.8739
# Epoch 226/500
# 43226/43226 [==============================] - 1s - loss: 0.5642 - acc: 0.8253 - val_loss: 0.4754 - val_acc: 0.8725
# Epoch 227/500
# 43226/43226 [==============================] - 1s - loss: 0.5663 - acc: 0.8233 - val_loss: 0.4759 - val_acc: 0.8730
# Epoch 228/500
# 43226/43226 [==============================] - 1s - loss: 0.5672 - acc: 0.8240 - val_loss: 0.4772 - val_acc: 0.8732
# Epoch 229/500
# 43226/43226 [==============================] - 1s - loss: 0.5689 - acc: 0.8227 - val_loss: 0.4750 - val_acc: 0.8748
# Epoch 230/500
# 43226/43226 [==============================] - 1s - loss: 0.5680 - acc: 0.8224 - val_loss: 0.4817 - val_acc: 0.8720
# Epoch 231/500
# 43226/43226 [==============================] - 1s - loss: 0.5680 - acc: 0.8233 - val_loss: 0.4837 - val_acc: 0.8705
# Epoch 232/500
# 43226/43226 [==============================] - 1s - loss: 0.5690 - acc: 0.8232 - val_loss: 0.4747 - val_acc: 0.8745
# Epoch 233/500
# 43226/43226 [==============================] - 1s - loss: 0.5633 - acc: 0.8246 - val_loss: 0.4755 - val_acc: 0.8746
# Epoch 234/500
# 43226/43226 [==============================] - 1s - loss: 0.5653 - acc: 0.8228 - val_loss: 0.4860 - val_acc: 0.8671
# Epoch 235/500
# 43226/43226 [==============================] - 1s - loss: 0.5664 - acc: 0.8227 - val_loss: 0.4814 - val_acc: 0.8698
# Epoch 236/500
# 43226/43226 [==============================] - 1s - loss: 0.5650 - acc: 0.8223 - val_loss: 0.4768 - val_acc: 0.8736
# Epoch 237/500
# 43226/43226 [==============================] - 1s - loss: 0.5664 - acc: 0.8240 - val_loss: 0.4819 - val_acc: 0.8693
# Epoch 238/500
# 43226/43226 [==============================] - 1s - loss: 0.5614 - acc: 0.8229 - val_loss: 0.4853 - val_acc: 0.8700
# Epoch 239/500
# 43226/43226 [==============================] - 1s - loss: 0.5616 - acc: 0.8266 - val_loss: 0.4771 - val_acc: 0.8738
# Epoch 240/500
# 43226/43226 [==============================] - 1s - loss: 0.5602 - acc: 0.8247 - val_loss: 0.4746 - val_acc: 0.8754
# Epoch 241/500
# 43226/43226 [==============================] - 1s - loss: 0.5679 - acc: 0.8213 - val_loss: 0.4822 - val_acc: 0.8756
# Epoch 242/500
# 43226/43226 [==============================] - 1s - loss: 0.5703 - acc: 0.8201 - val_loss: 0.4695 - val_acc: 0.8764
# Epoch 243/500
# 43226/43226 [==============================] - 1s - loss: 0.5611 - acc: 0.8257 - val_loss: 0.4783 - val_acc: 0.8707
# Epoch 244/500
# 43226/43226 [==============================] - 1s - loss: 0.5631 - acc: 0.8245 - val_loss: 0.4731 - val_acc: 0.8746
# Epoch 245/500
# 43226/43226 [==============================] - 1s - loss: 0.5668 - acc: 0.8207 - val_loss: 0.4866 - val_acc: 0.8706
# Epoch 246/500
# 43226/43226 [==============================] - 1s - loss: 0.5640 - acc: 0.8242 - val_loss: 0.4699 - val_acc: 0.8773
# Epoch 247/500
# 43226/43226 [==============================] - 1s - loss: 0.5649 - acc: 0.8233 - val_loss: 0.4760 - val_acc: 0.8745
# Epoch 248/500
# 43226/43226 [==============================] - 1s - loss: 0.5607 - acc: 0.8244 - val_loss: 0.4731 - val_acc: 0.8744
# Epoch 249/500
# 43226/43226 [==============================] - 1s - loss: 0.5570 - acc: 0.8259 - val_loss: 0.4689 - val_acc: 0.8766
# Epoch 250/500
# 43226/43226 [==============================] - 1s - loss: 0.5647 - acc: 0.8238 - val_loss: 0.4805 - val_acc: 0.8713
# Epoch 251/500
# 43226/43226 [==============================] - 1s - loss: 0.5581 - acc: 0.8253 - val_loss: 0.4665 - val_acc: 0.8785
# Epoch 252/500
# 43226/43226 [==============================] - 1s - loss: 0.5636 - acc: 0.8251 - val_loss: 0.4712 - val_acc: 0.8759
# Epoch 253/500
# 43226/43226 [==============================] - 1s - loss: 0.5612 - acc: 0.8264 - val_loss: 0.4708 - val_acc: 0.8764
# Epoch 254/500
# 43226/43226 [==============================] - 1s - loss: 0.5615 - acc: 0.8236 - val_loss: 0.4710 - val_acc: 0.8753
# Epoch 255/500
# 43226/43226 [==============================] - 1s - loss: 0.5577 - acc: 0.8272 - val_loss: 0.4854 - val_acc: 0.8739
# Epoch 256/500
# 43226/43226 [==============================] - 1s - loss: 0.5527 - acc: 0.8268 - val_loss: 0.4654 - val_acc: 0.8773
# Epoch 257/500
# 43226/43226 [==============================] - 1s - loss: 0.5561 - acc: 0.8272 - val_loss: 0.4667 - val_acc: 0.8778
# Epoch 258/500
# 43226/43226 [==============================] - 1s - loss: 0.5558 - acc: 0.8260 - val_loss: 0.4694 - val_acc: 0.8751
# Epoch 259/500
# 43226/43226 [==============================] - 1s - loss: 0.5573 - acc: 0.8257 - val_loss: 0.4689 - val_acc: 0.8760
# Epoch 260/500
# 43226/43226 [==============================] - 1s - loss: 0.5605 - acc: 0.8235 - val_loss: 0.4681 - val_acc: 0.8767
# Epoch 261/500
# 43226/43226 [==============================] - 1s - loss: 0.5563 - acc: 0.8258 - val_loss: 0.4789 - val_acc: 0.8721
# Epoch 262/500
# 43226/43226 [==============================] - 1s - loss: 0.5596 - acc: 0.8243 - val_loss: 0.4673 - val_acc: 0.8773
# Epoch 263/500
# 43226/43226 [==============================] - 1s - loss: 0.5544 - acc: 0.8256 - val_loss: 0.4682 - val_acc: 0.8754
# Epoch 264/500
# 43226/43226 [==============================] - 1s - loss: 0.5584 - acc: 0.8239 - val_loss: 0.4667 - val_acc: 0.8768
# Epoch 265/500
# 43226/43226 [==============================] - 1s - loss: 0.5608 - acc: 0.8242 - val_loss: 0.4603 - val_acc: 0.8792
# Epoch 266/500
# 43226/43226 [==============================] - 1s - loss: 0.5571 - acc: 0.8266 - val_loss: 0.4712 - val_acc: 0.8745
# Epoch 267/500
# 43226/43226 [==============================] - 1s - loss: 0.5604 - acc: 0.8256 - val_loss: 0.4654 - val_acc: 0.8792
# Epoch 268/500
# 43226/43226 [==============================] - 1s - loss: 0.5541 - acc: 0.8278 - val_loss: 0.4665 - val_acc: 0.8773
# Epoch 269/500
# 43226/43226 [==============================] - 1s - loss: 0.5574 - acc: 0.8254 - val_loss: 0.4688 - val_acc: 0.8774
# Epoch 270/500
# 43226/43226 [==============================] - 1s - loss: 0.5532 - acc: 0.8273 - val_loss: 0.4632 - val_acc: 0.8799
# Epoch 271/500
# 43226/43226 [==============================] - 1s - loss: 0.5566 - acc: 0.8251 - val_loss: 0.4671 - val_acc: 0.8788
# Epoch 272/500
# 43226/43226 [==============================] - 1s - loss: 0.5574 - acc: 0.8242 - val_loss: 0.4586 - val_acc: 0.8796
# Epoch 273/500
# 43226/43226 [==============================] - 1s - loss: 0.5595 - acc: 0.8246 - val_loss: 0.4810 - val_acc: 0.8717
# Epoch 274/500
# 43226/43226 [==============================] - 1s - loss: 0.5566 - acc: 0.8261 - val_loss: 0.4625 - val_acc: 0.8796
# Epoch 275/500
# 43226/43226 [==============================] - 1s - loss: 0.5527 - acc: 0.8267 - val_loss: 0.4631 - val_acc: 0.8780
# Epoch 276/500
# 43226/43226 [==============================] - 1s - loss: 0.5549 - acc: 0.8274 - val_loss: 0.4650 - val_acc: 0.8773
# Epoch 277/500
# 43226/43226 [==============================] - 1s - loss: 0.5508 - acc: 0.8277 - val_loss: 0.4668 - val_acc: 0.8756
# Epoch 278/500
# 43226/43226 [==============================] - 1s - loss: 0.5518 - acc: 0.8272 - val_loss: 0.4734 - val_acc: 0.8732
# Epoch 279/500
# 43226/43226 [==============================] - 1s - loss: 0.5491 - acc: 0.8282 - val_loss: 0.4691 - val_acc: 0.8776
# Epoch 280/500
# 43226/43226 [==============================] - 1s - loss: 0.5552 - acc: 0.8268 - val_loss: 0.4666 - val_acc: 0.8780
# Epoch 281/500
# 43226/43226 [==============================] - 1s - loss: 0.5509 - acc: 0.8277 - val_loss: 0.4611 - val_acc: 0.8784
# Epoch 282/500
# 43226/43226 [==============================] - 1s - loss: 0.5495 - acc: 0.8276 - val_loss: 0.4575 - val_acc: 0.8796
# Epoch 283/500
# 43226/43226 [==============================] - 1s - loss: 0.5502 - acc: 0.8300 - val_loss: 0.4619 - val_acc: 0.8787
# Epoch 284/500
# 43226/43226 [==============================] - 1s - loss: 0.5517 - acc: 0.8283 - val_loss: 0.4672 - val_acc: 0.8766
# Epoch 285/500
# 43226/43226 [==============================] - 1s - loss: 0.5541 - acc: 0.8256 - val_loss: 0.4632 - val_acc: 0.8786
# Epoch 286/500
# 43226/43226 [==============================] - 1s - loss: 0.5537 - acc: 0.8279 - val_loss: 0.4632 - val_acc: 0.8776
# Epoch 287/500
# 43226/43226 [==============================] - 1s - loss: 0.5538 - acc: 0.8282 - val_loss: 0.4657 - val_acc: 0.8799
# Epoch 288/500
# 43226/43226 [==============================] - 1s - loss: 0.5517 - acc: 0.8284 - val_loss: 0.4614 - val_acc: 0.8797
# Epoch 289/500
# 43226/43226 [==============================] - 1s - loss: 0.5536 - acc: 0.8297 - val_loss: 0.4661 - val_acc: 0.8778
# Epoch 290/500
# 43226/43226 [==============================] - 1s - loss: 0.5529 - acc: 0.8265 - val_loss: 0.4629 - val_acc: 0.8775
# Epoch 291/500
# 43226/43226 [==============================] - 1s - loss: 0.5532 - acc: 0.8280 - val_loss: 0.4629 - val_acc: 0.8768
# Epoch 292/500
# 43226/43226 [==============================] - 1s - loss: 0.5462 - acc: 0.8293 - val_loss: 0.4694 - val_acc: 0.8754
# Epoch 293/500
# 43226/43226 [==============================] - 1s - loss: 0.5471 - acc: 0.8299 - val_loss: 0.4645 - val_acc: 0.8787
# Epoch 294/500
# 43226/43226 [==============================] - 1s - loss: 0.5498 - acc: 0.8274 - val_loss: 0.4657 - val_acc: 0.8767
# Epoch 295/500
# 43226/43226 [==============================] - 1s - loss: 0.5475 - acc: 0.8296 - val_loss: 0.4645 - val_acc: 0.8758
# Epoch 296/500
# 43226/43226 [==============================] - 1s - loss: 0.5548 - acc: 0.8259 - val_loss: 0.4605 - val_acc: 0.8782
# Epoch 297/500
# 43226/43226 [==============================] - 1s - loss: 0.5467 - acc: 0.8294 - val_loss: 0.4607 - val_acc: 0.8768
# Epoch 298/500
# 43226/43226 [==============================] - 1s - loss: 0.5523 - acc: 0.8273 - val_loss: 0.4714 - val_acc: 0.8763
# Epoch 299/500
# 43226/43226 [==============================] - 1s - loss: 0.5485 - acc: 0.8286 - val_loss: 0.4570 - val_acc: 0.8796
# Epoch 300/500
# 43226/43226 [==============================] - 1s - loss: 0.5460 - acc: 0.8284 - val_loss: 0.4691 - val_acc: 0.8739
# Epoch 301/500
# 43226/43226 [==============================] - 1s - loss: 0.5469 - acc: 0.8289 - val_loss: 0.4732 - val_acc: 0.8738
# Epoch 302/500
# 43226/43226 [==============================] - 1s - loss: 0.5507 - acc: 0.8283 - val_loss: 0.4681 - val_acc: 0.8773
# Epoch 303/500
# 43226/43226 [==============================] - 1s - loss: 0.5476 - acc: 0.8292 - val_loss: 0.4603 - val_acc: 0.8795
# Epoch 304/500
# 43226/43226 [==============================] - 1s - loss: 0.5484 - acc: 0.8289 - val_loss: 0.4637 - val_acc: 0.8760
# Epoch 305/500
# 43226/43226 [==============================] - 1s - loss: 0.5456 - acc: 0.8301 - val_loss: 0.4669 - val_acc: 0.8785
# Epoch 306/500
# 43226/43226 [==============================] - 1s - loss: 0.5471 - acc: 0.8286 - val_loss: 0.4601 - val_acc: 0.8789
# Epoch 307/500
# 43226/43226 [==============================] - 1s - loss: 0.5421 - acc: 0.8297 - val_loss: 0.4616 - val_acc: 0.8787
# Epoch 308/500
# 43226/43226 [==============================] - 1s - loss: 0.5453 - acc: 0.8281 - val_loss: 0.4599 - val_acc: 0.8794
# Epoch 309/500
# 43226/43226 [==============================] - 1s - loss: 0.5474 - acc: 0.8298 - val_loss: 0.4625 - val_acc: 0.8792
# Epoch 310/500
# 43226/43226 [==============================] - 1s - loss: 0.5471 - acc: 0.8287 - val_loss: 0.4608 - val_acc: 0.8798
# Epoch 311/500
# 43226/43226 [==============================] - 1s - loss: 0.5470 - acc: 0.8289 - val_loss: 0.4653 - val_acc: 0.8770
# Epoch 312/500
# 43226/43226 [==============================] - 1s - loss: 0.5478 - acc: 0.8291 - val_loss: 0.4678 - val_acc: 0.8758
# Epoch 313/500
# 43226/43226 [==============================] - 1s - loss: 0.5475 - acc: 0.8290 - val_loss: 0.4540 - val_acc: 0.8818
# Epoch 314/500
# 43226/43226 [==============================] - 1s - loss: 0.5487 - acc: 0.8273 - val_loss: 0.4547 - val_acc: 0.8799
# Epoch 315/500
# 43226/43226 [==============================] - 1s - loss: 0.5470 - acc: 0.8299 - val_loss: 0.4507 - val_acc: 0.8818
# Epoch 316/500
# 43226/43226 [==============================] - 1s - loss: 0.5504 - acc: 0.8261 - val_loss: 0.4574 - val_acc: 0.8799
# Epoch 317/500
# 43226/43226 [==============================] - 1s - loss: 0.5408 - acc: 0.8320 - val_loss: 0.4537 - val_acc: 0.8803
# Epoch 318/500
# 43226/43226 [==============================] - 1s - loss: 0.5454 - acc: 0.8283 - val_loss: 0.4583 - val_acc: 0.8797
# Epoch 319/500
# 43226/43226 [==============================] - 1s - loss: 0.5439 - acc: 0.8283 - val_loss: 0.4538 - val_acc: 0.8804
# Epoch 320/500
# 43226/43226 [==============================] - 1s - loss: 0.5392 - acc: 0.8310 - val_loss: 0.4687 - val_acc: 0.8745
# Epoch 321/500
# 43226/43226 [==============================] - 1s - loss: 0.5424 - acc: 0.8305 - val_loss: 0.4612 - val_acc: 0.8765
# Epoch 322/500
# 43226/43226 [==============================] - 1s - loss: 0.5433 - acc: 0.8305 - val_loss: 0.4561 - val_acc: 0.8792
# Epoch 323/500
# 43226/43226 [==============================] - 1s - loss: 0.5400 - acc: 0.8325 - val_loss: 0.4604 - val_acc: 0.8785
# Epoch 324/500
# 43226/43226 [==============================] - 1s - loss: 0.5440 - acc: 0.8302 - val_loss: 0.4558 - val_acc: 0.8800
# Epoch 325/500
# 43226/43226 [==============================] - 1s - loss: 0.5478 - acc: 0.8300 - val_loss: 0.4620 - val_acc: 0.8788
# Epoch 326/500
# 43226/43226 [==============================] - 1s - loss: 0.5400 - acc: 0.8300 - val_loss: 0.4524 - val_acc: 0.8803
# Epoch 327/500
# 43226/43226 [==============================] - 1s - loss: 0.5394 - acc: 0.8301 - val_loss: 0.4547 - val_acc: 0.8809
# Epoch 328/500
# 43226/43226 [==============================] - 1s - loss: 0.5405 - acc: 0.8313 - val_loss: 0.4512 - val_acc: 0.8801
# Epoch 329/500
# 43226/43226 [==============================] - 1s - loss: 0.5414 - acc: 0.8293 - val_loss: 0.4587 - val_acc: 0.8782
# Epoch 330/500
# 43226/43226 [==============================] - 1s - loss: 0.5437 - acc: 0.8297 - val_loss: 0.4557 - val_acc: 0.8793
# Epoch 331/500
# 43226/43226 [==============================] - 1s - loss: 0.5392 - acc: 0.8298 - val_loss: 0.4682 - val_acc: 0.8726
# Epoch 332/500
# 43226/43226 [==============================] - 1s - loss: 0.5397 - acc: 0.8328 - val_loss: 0.4614 - val_acc: 0.8769
# Epoch 333/500
# 43226/43226 [==============================] - 1s - loss: 0.5392 - acc: 0.8331 - val_loss: 0.4555 - val_acc: 0.8784
# Epoch 334/500
# 43226/43226 [==============================] - 1s - loss: 0.5417 - acc: 0.8305 - val_loss: 0.4478 - val_acc: 0.8832
# Epoch 335/500
# 43226/43226 [==============================] - 1s - loss: 0.5375 - acc: 0.8310 - val_loss: 0.4609 - val_acc: 0.8780
# Epoch 336/500
# 43226/43226 [==============================] - 1s - loss: 0.5377 - acc: 0.8303 - val_loss: 0.4532 - val_acc: 0.8786
# Epoch 337/500
# 43226/43226 [==============================] - 1s - loss: 0.5370 - acc: 0.8313 - val_loss: 0.4591 - val_acc: 0.8794
# Epoch 338/500
# 43226/43226 [==============================] - 1s - loss: 0.5374 - acc: 0.8298 - val_loss: 0.4648 - val_acc: 0.8769
# Epoch 339/500
# 43226/43226 [==============================] - 1s - loss: 0.5400 - acc: 0.8308 - val_loss: 0.4543 - val_acc: 0.8802
# Epoch 340/500
# 43226/43226 [==============================] - 1s - loss: 0.5429 - acc: 0.8296 - val_loss: 0.4496 - val_acc: 0.8820
# Epoch 341/500
# 43226/43226 [==============================] - 1s - loss: 0.5372 - acc: 0.8319 - val_loss: 0.4563 - val_acc: 0.8804
# Epoch 342/500
# 43226/43226 [==============================] - 1s - loss: 0.5448 - acc: 0.8299 - val_loss: 0.4521 - val_acc: 0.8813
# Epoch 343/500
# 43226/43226 [==============================] - 1s - loss: 0.5391 - acc: 0.8320 - val_loss: 0.4537 - val_acc: 0.8793
# Epoch 344/500
# 43226/43226 [==============================] - 1s - loss: 0.5434 - acc: 0.8301 - val_loss: 0.4477 - val_acc: 0.8828
# Epoch 345/500
# 43226/43226 [==============================] - 1s - loss: 0.5381 - acc: 0.8313 - val_loss: 0.4527 - val_acc: 0.8809
# Epoch 346/500
# 43226/43226 [==============================] - 1s - loss: 0.5361 - acc: 0.8315 - val_loss: 0.4506 - val_acc: 0.8804
# Epoch 347/500
# 43226/43226 [==============================] - 1s - loss: 0.5362 - acc: 0.8313 - val_loss: 0.4484 - val_acc: 0.8813
# Epoch 348/500
# 43226/43226 [==============================] - 1s - loss: 0.5357 - acc: 0.8332 - val_loss: 0.4601 - val_acc: 0.8780
# Epoch 349/500
# 43226/43226 [==============================] - 1s - loss: 0.5350 - acc: 0.8297 - val_loss: 0.4542 - val_acc: 0.8803
# Epoch 350/500
# 43226/43226 [==============================] - 1s - loss: 0.5398 - acc: 0.8304 - val_loss: 0.4528 - val_acc: 0.8793
# Epoch 351/500
# 43226/43226 [==============================] - 1s - loss: 0.5322 - acc: 0.8343 - val_loss: 0.4512 - val_acc: 0.8801
# Epoch 352/500
# 43226/43226 [==============================] - 1s - loss: 0.5344 - acc: 0.8335 - val_loss: 0.4500 - val_acc: 0.8833
# Epoch 353/500
# 43226/43226 [==============================] - 1s - loss: 0.5366 - acc: 0.8317 - val_loss: 0.4526 - val_acc: 0.8797
# Epoch 354/500
# 43226/43226 [==============================] - 1s - loss: 0.5435 - acc: 0.8296 - val_loss: 0.4578 - val_acc: 0.8768
# Epoch 355/500
# 43226/43226 [==============================] - 1s - loss: 0.5362 - acc: 0.8324 - val_loss: 0.4533 - val_acc: 0.8820
# Epoch 356/500
# 43226/43226 [==============================] - 1s - loss: 0.5359 - acc: 0.8323 - val_loss: 0.4528 - val_acc: 0.8815
# Epoch 357/500
# 43226/43226 [==============================] - 1s - loss: 0.5365 - acc: 0.8320 - val_loss: 0.4658 - val_acc: 0.8738
# Epoch 358/500
# 43226/43226 [==============================] - 1s - loss: 0.5335 - acc: 0.8325 - val_loss: 0.4588 - val_acc: 0.8780
# Epoch 359/500
# 43226/43226 [==============================] - 1s - loss: 0.5342 - acc: 0.8330 - val_loss: 0.4544 - val_acc: 0.8787
# Epoch 360/500
# ...
# Epoch 379/500
# 43226/43226 [==============================] - 3s - loss: 0.5947 - acc: 0.7978 - val_loss: 0.4422 - val_acc: 0.8584
# Epoch 380/500
# 43226/43226 [==============================] - 3s - loss: 0.5995 - acc: 0.7978 - val_loss: 0.4414 - val_acc: 0.8587
# Epoch 381/500
# 43226/43226 [==============================] - 3s - loss: 0.5940 - acc: 0.7978 - val_loss: 0.4425 - val_acc: 0.8581
# Epoch 382/500
# 43226/43226 [==============================] - 3s - loss: 0.5941 - acc: 0.7979 - val_loss: 0.4444 - val_acc: 0.8583
# Epoch 383/500
# 43226/43226 [==============================] - 3s - loss: 0.5964 - acc: 0.7957 - val_loss: 0.4407 - val_acc: 0.8588
# Epoch 384/500
# 43226/43226 [==============================] - 3s - loss: 0.5989 - acc: 0.7971 - val_loss: 0.4462 - val_acc: 0.8549
# Epoch 385/500
# 43226/43226 [==============================] - 3s - loss: 0.5926 - acc: 0.7993 - val_loss: 0.4395 - val_acc: 0.8602
# Epoch 386/500
# 43226/43226 [==============================] - 3s - loss: 0.5952 - acc: 0.7965 - val_loss: 0.4454 - val_acc: 0.8547
# Epoch 387/500
# 43226/43226 [==============================] - 3s - loss: 0.5980 - acc: 0.7957 - val_loss: 0.4447 - val_acc: 0.8562
# Epoch 388/500
# 43226/43226 [==============================] - 3s - loss: 0.5969 - acc: 0.7980 - val_loss: 0.4394 - val_acc: 0.8593
# Epoch 389/500
# 43226/43226 [==============================] - 3s - loss: 0.5976 - acc: 0.7967 - val_loss: 0.4405 - val_acc: 0.8581
# Epoch 390/500
# 43226/43226 [==============================] - 3s - loss: 0.5961 - acc: 0.7990 - val_loss: 0.4442 - val_acc: 0.8571
# Epoch 391/500
# 43226/43226 [==============================] - 3s - loss: 0.5956 - acc: 0.7978 - val_loss: 0.4393 - val_acc: 0.8596
# Epoch 392/500
# 43226/43226 [==============================] - 3s - loss: 0.5932 - acc: 0.7984 - val_loss: 0.4420 - val_acc: 0.8582
# Epoch 393/500
# 43226/43226 [==============================] - 3s - loss: 0.5914 - acc: 0.7991 - val_loss: 0.4453 - val_acc: 0.8565
# Epoch 394/500
# 43226/43226 [==============================] - 3s - loss: 0.5918 - acc: 0.7997 - val_loss: 0.4454 - val_acc: 0.8556
# Epoch 395/500
# 43226/43226 [==============================] - 3s - loss: 0.5923 - acc: 0.7988 - val_loss: 0.4399 - val_acc: 0.8577
# Epoch 396/500
# 43226/43226 [==============================] - 3s - loss: 0.5898 - acc: 0.7986 - val_loss: 0.4433 - val_acc: 0.8567
# Epoch 397/500
# 43226/43226 [==============================] - 3s - loss: 0.5944 - acc: 0.7986 - val_loss: 0.4413 - val_acc: 0.8583
# Epoch 398/500
# 43226/43226 [==============================] - 3s - loss: 0.5948 - acc: 0.7983 - val_loss: 0.4361 - val_acc: 0.8611
# Epoch 399/500
# 43226/43226 [==============================] - 3s - loss: 0.5909 - acc: 0.7984 - val_loss: 0.4390 - val_acc: 0.8583
# Epoch 400/500
# 43226/43226 [==============================] - 3s - loss: 0.5927 - acc: 0.7993 - val_loss: 0.4390 - val_acc: 0.8614
# Epoch 401/500
# 43226/43226 [==============================] - 3s - loss: 0.5900 - acc: 0.7988 - val_loss: 0.4401 - val_acc: 0.8584
# Epoch 402/500
# 43226/43226 [==============================] - 3s - loss: 0.5935 - acc: 0.8002 - val_loss: 0.4370 - val_acc: 0.8611
# Epoch 403/500
# 43226/43226 [==============================] - 3s - loss: 0.5888 - acc: 0.7984 - val_loss: 0.4424 - val_acc: 0.8570
# Epoch 404/500
# 43226/43226 [==============================] - 3s - loss: 0.5860 - acc: 0.8022 - val_loss: 0.4402 - val_acc: 0.8570
# Epoch 405/500
# 43226/43226 [==============================] - 3s - loss: 0.5907 - acc: 0.7996 - val_loss: 0.4378 - val_acc: 0.8614
# Epoch 406/500
# 43226/43226 [==============================] - 3s - loss: 0.5920 - acc: 0.7970 - val_loss: 0.4322 - val_acc: 0.8619
# Epoch 407/500
# 43226/43226 [==============================] - 3s - loss: 0.5939 - acc: 0.7970 - val_loss: 0.4353 - val_acc: 0.8628
# Epoch 408/500
# 43226/43226 [==============================] - 3s - loss: 0.5938 - acc: 0.7986 - val_loss: 0.4457 - val_acc: 0.8547
# Epoch 409/500
# 43226/43226 [==============================] - 3s - loss: 0.5929 - acc: 0.7987 - val_loss: 0.4399 - val_acc: 0.8576
# Epoch 410/500
# 43226/43226 [==============================] - 3s - loss: 0.5898 - acc: 0.7999 - val_loss: 0.4370 - val_acc: 0.8600
# Epoch 411/500
# 43226/43226 [==============================] - 3s - loss: 0.5908 - acc: 0.7978 - val_loss: 0.4370 - val_acc: 0.8603
# Epoch 412/500
# 43226/43226 [==============================] - 3s - loss: 0.5885 - acc: 0.7985 - val_loss: 0.4398 - val_acc: 0.8576
# Epoch 413/500
# 43226/43226 [==============================] - 3s - loss: 0.5900 - acc: 0.7992 - val_loss: 0.4354 - val_acc: 0.8618
# Epoch 414/500
# 43226/43226 [==============================] - 3s - loss: 0.5893 - acc: 0.8003 - val_loss: 0.4376 - val_acc: 0.8600
# Epoch 415/500
# 43226/43226 [==============================] - 3s - loss: 0.5913 - acc: 0.7989 - val_loss: 0.4376 - val_acc: 0.8615
# Epoch 416/500
# 43226/43226 [==============================] - 3s - loss: 0.5844 - acc: 0.8015 - val_loss: 0.4300 - val_acc: 0.8650
# Epoch 417/500
# 43226/43226 [==============================] - 3s - loss: 0.5869 - acc: 0.8000 - val_loss: 0.4325 - val_acc: 0.8626
# Epoch 418/500
# 43226/43226 [==============================] - 3s - loss: 0.5863 - acc: 0.8016 - val_loss: 0.4367 - val_acc: 0.8588
# Epoch 419/500
# 43226/43226 [==============================] - 3s - loss: 0.5930 - acc: 0.7969 - val_loss: 0.4355 - val_acc: 0.8611
# Epoch 420/500
# 43226/43226 [==============================] - 3s - loss: 0.5931 - acc: 0.7973 - val_loss: 0.4345 - val_acc: 0.8602
# Epoch 421/500
# 43226/43226 [==============================] - 3s - loss: 0.5883 - acc: 0.8010 - val_loss: 0.4340 - val_acc: 0.8634
# Epoch 422/500
# 43226/43226 [==============================] - 3s - loss: 0.5875 - acc: 0.8016 - val_loss: 0.4341 - val_acc: 0.8599
# Epoch 423/500
# 43226/43226 [==============================] - 3s - loss: 0.5874 - acc: 0.8004 - val_loss: 0.4328 - val_acc: 0.8615
# Epoch 424/500
# 43226/43226 [==============================] - 3s - loss: 0.5807 - acc: 0.8017 - val_loss: 0.4382 - val_acc: 0.8595
# Epoch 425/500
# 43226/43226 [==============================] - 3s - loss: 0.5832 - acc: 0.8020 - val_loss: 0.4312 - val_acc: 0.8634
# Epoch 426/500
# 43226/43226 [==============================] - 3s - loss: 0.5833 - acc: 0.8018 - val_loss: 0.4318 - val_acc: 0.8638
# Epoch 427/500
# 43226/43226 [==============================] - 3s - loss: 0.5893 - acc: 0.8003 - val_loss: 0.4322 - val_acc: 0.8618
# Epoch 428/500
# 43226/43226 [==============================] - 3s - loss: 0.5871 - acc: 0.7994 - val_loss: 0.4367 - val_acc: 0.8596
# Epoch 429/500
# 43226/43226 [==============================] - 3s - loss: 0.5880 - acc: 0.8010 - val_loss: 0.4359 - val_acc: 0.8584
# Epoch 430/500
# 43226/43226 [==============================] - 3s - loss: 0.5840 - acc: 0.8014 - val_loss: 0.4347 - val_acc: 0.8610
# Epoch 431/500
# 43226/43226 [==============================] - 3s - loss: 0.5866 - acc: 0.8011 - val_loss: 0.4339 - val_acc: 0.8613
# Epoch 432/500
# 43226/43226 [==============================] - 3s - loss: 0.5815 - acc: 0.8030 - val_loss: 0.4313 - val_acc: 0.8623
# Epoch 433/500
# 43226/43226 [==============================] - 3s - loss: 0.5795 - acc: 0.8033 - val_loss: 0.4353 - val_acc: 0.8603
# Epoch 434/500
# 43226/43226 [==============================] - 3s - loss: 0.5835 - acc: 0.7994 - val_loss: 0.4347 - val_acc: 0.8598
# Epoch 435/500
# 43226/43226 [==============================] - 3s - loss: 0.5841 - acc: 0.8036 - val_loss: 0.4249 - val_acc: 0.8666
# Epoch 436/500
# 43226/43226 [==============================] - 3s - loss: 0.5793 - acc: 0.8035 - val_loss: 0.4321 - val_acc: 0.8625
# Epoch 437/500
# 43226/43226 [==============================] - 3s - loss: 0.5852 - acc: 0.8000 - val_loss: 0.4321 - val_acc: 0.8608
# Epoch 438/500
# 43226/43226 [==============================] - 3s - loss: 0.5825 - acc: 0.8008 - val_loss: 0.4285 - val_acc: 0.8634
# Epoch 439/500
# 43226/43226 [==============================] - 3s - loss: 0.5845 - acc: 0.7997 - val_loss: 0.4273 - val_acc: 0.8647
# Epoch 440/500
# 43226/43226 [==============================] - 3s - loss: 0.5831 - acc: 0.8005 - val_loss: 0.4319 - val_acc: 0.8615
# Epoch 441/500
# 43226/43226 [==============================] - 3s - loss: 0.5839 - acc: 0.8019 - val_loss: 0.4306 - val_acc: 0.8629
# Epoch 442/500
# 43226/43226 [==============================] - 3s - loss: 0.5792 - acc: 0.8031 - val_loss: 0.4306 - val_acc: 0.8622
# Epoch 443/500
# 43226/43226 [==============================] - 3s - loss: 0.5853 - acc: 0.8005 - val_loss: 0.4274 - val_acc: 0.8644
# Epoch 444/500
# 43226/43226 [==============================] - 3s - loss: 0.5785 - acc: 0.8043 - val_loss: 0.4316 - val_acc: 0.8613
# Epoch 445/500
# 43226/43226 [==============================] - 3s - loss: 0.5826 - acc: 0.8019 - val_loss: 0.4296 - val_acc: 0.8621
# Epoch 446/500
# 43226/43226 [==============================] - 3s - loss: 0.5824 - acc: 0.8007 - val_loss: 0.4283 - val_acc: 0.8636
# Epoch 447/500
# 43226/43226 [==============================] - 3s - loss: 0.5823 - acc: 0.8018 - val_loss: 0.4297 - val_acc: 0.8634
# Epoch 448/500
# 43226/43226 [==============================] - 3s - loss: 0.5844 - acc: 0.8032 - val_loss: 0.4313 - val_acc: 0.8635
# Epoch 449/500
# 43226/43226 [==============================] - 3s - loss: 0.5781 - acc: 0.8017 - val_loss: 0.4261 - val_acc: 0.8647
# Epoch 450/500
# 43226/43226 [==============================] - 3s - loss: 0.5796 - acc: 0.8039 - val_loss: 0.4289 - val_acc: 0.8627
# Epoch 451/500
# 43226/43226 [==============================] - 3s - loss: 0.5778 - acc: 0.8028 - val_loss: 0.4225 - val_acc: 0.8663
# Epoch 452/500
# 43226/43226 [==============================] - 3s - loss: 0.5827 - acc: 0.8030 - val_loss: 0.4277 - val_acc: 0.8648
# Epoch 453/500
# 43226/43226 [==============================] - 3s - loss: 0.5801 - acc: 0.8024 - val_loss: 0.4295 - val_acc: 0.8615
# Epoch 454/500
# 43226/43226 [==============================] - 3s - loss: 0.5783 - acc: 0.8039 - val_loss: 0.4278 - val_acc: 0.8626
# Epoch 455/500
# 43226/43226 [==============================] - 3s - loss: 0.5762 - acc: 0.8048 - val_loss: 0.4262 - val_acc: 0.8629
# Epoch 456/500
# 43226/43226 [==============================] - 3s - loss: 0.5786 - acc: 0.8020 - val_loss: 0.4236 - val_acc: 0.8657
# Epoch 457/500
# 43226/43226 [==============================] - 3s - loss: 0.5740 - acc: 0.8052 - val_loss: 0.4307 - val_acc: 0.8610
# Epoch 458/500
# 43226/43226 [==============================] - 3s - loss: 0.5788 - acc: 0.8029 - val_loss: 0.4278 - val_acc: 0.8626
# Epoch 459/500
# 43226/43226 [==============================] - 3s - loss: 0.5834 - acc: 0.8022 - val_loss: 0.4263 - val_acc: 0.8643
# Epoch 460/500
# 43226/43226 [==============================] - 3s - loss: 0.5785 - acc: 0.8018 - val_loss: 0.4324 - val_acc: 0.8612
# Epoch 461/500
# 43226/43226 [==============================] - 3s - loss: 0.5831 - acc: 0.8019 - val_loss: 0.4264 - val_acc: 0.8626
# Epoch 462/500
# 43226/43226 [==============================] - 3s - loss: 0.5731 - acc: 0.8061 - val_loss: 0.4259 - val_acc: 0.8642
# Epoch 463/500
# 43226/43226 [==============================] - 3s - loss: 0.5790 - acc: 0.8027 - val_loss: 0.4241 - val_acc: 0.8673
# Epoch 464/500
# 43226/43226 [==============================] - 3s - loss: 0.5771 - acc: 0.8015 - val_loss: 0.4220 - val_acc: 0.8673
# Epoch 465/500
# 43226/43226 [==============================] - 3s - loss: 0.5777 - acc: 0.8039 - val_loss: 0.4216 - val_acc: 0.8660
# Epoch 466/500
# 43226/43226 [==============================] - 3s - loss: 0.5789 - acc: 0.8050 - val_loss: 0.4229 - val_acc: 0.8646
# Epoch 467/500
# 43226/43226 [==============================] - 3s - loss: 0.5779 - acc: 0.8040 - val_loss: 0.4252 - val_acc: 0.8645
# Epoch 468/500
# 43226/43226 [==============================] - 3s - loss: 0.5756 - acc: 0.8063 - val_loss: 0.4244 - val_acc: 0.8660
# Epoch 469/500
# 43226/43226 [==============================] - 3s - loss: 0.5740 - acc: 0.8063 - val_loss: 0.4203 - val_acc: 0.8669
# Epoch 470/500
# 43226/43226 [==============================] - 3s - loss: 0.5793 - acc: 0.8017 - val_loss: 0.4231 - val_acc: 0.8655
# Epoch 471/500
# 43226/43226 [==============================] - 3s - loss: 0.5709 - acc: 0.8063 - val_loss: 0.4200 - val_acc: 0.8660
# Epoch 472/500
# 43226/43226 [==============================] - 3s - loss: 0.5792 - acc: 0.8024 - val_loss: 0.4235 - val_acc: 0.8656
# Epoch 473/500
# 43226/43226 [==============================] - 3s - loss: 0.5716 - acc: 0.8039 - val_loss: 0.4265 - val_acc: 0.8633
# Epoch 474/500
# 43226/43226 [==============================] - 3s - loss: 0.5703 - acc: 0.8075 - val_loss: 0.4231 - val_acc: 0.8643
# Epoch 475/500
# 43226/43226 [==============================] - 3s - loss: 0.5819 - acc: 0.8020 - val_loss: 0.4245 - val_acc: 0.8648
# Epoch 476/500
# 43226/43226 [==============================] - 3s - loss: 0.5785 - acc: 0.8037 - val_loss: 0.4185 - val_acc: 0.8675
# Epoch 477/500
# 43226/43226 [==============================] - 3s - loss: 0.5758 - acc: 0.8047 - val_loss: 0.4243 - val_acc: 0.8637
# Epoch 478/500
# 43226/43226 [==============================] - 3s - loss: 0.5728 - acc: 0.8043 - val_loss: 0.4236 - val_acc: 0.8664
# Epoch 479/500
# 43226/43226 [==============================] - 3s - loss: 0.5714 - acc: 0.8066 - val_loss: 0.4189 - val_acc: 0.8685
# Epoch 480/500
# 43226/43226 [==============================] - 3s - loss: 0.5750 - acc: 0.8038 - val_loss: 0.4242 - val_acc: 0.8645
# Epoch 481/500
# 43226/43226 [==============================] - 3s - loss: 0.5680 - acc: 0.8054 - val_loss: 0.4246 - val_acc: 0.8631
# Epoch 482/500
# 43226/43226 [==============================] - 3s - loss: 0.5697 - acc: 0.8060 - val_loss: 0.4213 - val_acc: 0.8646
# Epoch 483/500
# 43226/43226 [==============================] - 3s - loss: 0.5740 - acc: 0.8044 - val_loss: 0.4193 - val_acc: 0.8684
# Epoch 484/500
# 43226/43226 [==============================] - 3s - loss: 0.5783 - acc: 0.8054 - val_loss: 0.4237 - val_acc: 0.8641
# Epoch 485/500
# 43226/43226 [==============================] - 3s - loss: 0.5767 - acc: 0.8032 - val_loss: 0.4194 - val_acc: 0.8670
# Epoch 486/500
# 43226/43226 [==============================] - 3s - loss: 0.5771 - acc: 0.8011 - val_loss: 0.4235 - val_acc: 0.8643
# Epoch 487/500
# 43226/43226 [==============================] - 3s - loss: 0.5753 - acc: 0.8044 - val_loss: 0.4267 - val_acc: 0.8607
# Epoch 488/500
# 43226/43226 [==============================] - 3s - loss: 0.5737 - acc: 0.8057 - val_loss: 0.4187 - val_acc: 0.8688
# Epoch 489/500
# 43226/43226 [==============================] - 3s - loss: 0.5723 - acc: 0.8066 - val_loss: 0.4215 - val_acc: 0.8659
# Epoch 490/500
# 43226/43226 [==============================] - 3s - loss: 0.5748 - acc: 0.8041 - val_loss: 0.4224 - val_acc: 0.8645
# Epoch 491/500
# 43226/43226 [==============================] - 3s - loss: 0.5710 - acc: 0.8064 - val_loss: 0.4195 - val_acc: 0.8668
# Epoch 492/500
# 43226/43226 [==============================] - 3s - loss: 0.5718 - acc: 0.8031 - val_loss: 0.4199 - val_acc: 0.8676
# Epoch 493/500
# 43226/43226 [==============================] - 3s - loss: 0.5692 - acc: 0.8057 - val_loss: 0.4237 - val_acc: 0.8633
# Epoch 494/500
# 43226/43226 [==============================] - 3s - loss: 0.5656 - acc: 0.8078 - val_loss: 0.4178 - val_acc: 0.8666
# Epoch 495/500
# 43226/43226 [==============================] - 3s - loss: 0.5693 - acc: 0.8063 - val_loss: 0.4304 - val_acc: 0.8610
# Epoch 496/500
# 43226/43226 [==============================] - 3s - loss: 0.5698 - acc: 0.8062 - val_loss: 0.4188 - val_acc: 0.8669
# Epoch 497/500
# 43226/43226 [==============================] - 3s - loss: 0.5743 - acc: 0.8049 - val_loss: 0.4202 - val_acc: 0.8654
# Epoch 498/500
# 43226/43226 [==============================] - 3s - loss: 0.5742 - acc: 0.8047 - val_loss: 0.4235 - val_acc: 0.8628
# Epoch 499/500
# 43226/43226 [==============================] - 3s - loss: 0.5759 - acc: 0.8039 - val_loss: 0.4190 - val_acc: 0.8665
# Epoch 500/500
# 43226/43226 [==============================] - 3s - loss: 0.5707 - acc: 0.8069 - val_loss: 0.4186 - val_acc: 0.8665
# Train Loss: 0.341353992644 , Train Accuracy: 0.894345995491
# Test loss: 0.418699075411 , Test accuracy: 0.86877655865

# %%
##################################################
#Part 2 plots of Regulairsed model vs Naive model
####################################################
title='Learning Curve and Accuracy of Regularised model vs Naive model (1 Hidden layer)'
history_reg=summary_reg['hidden_1']
history_naive=summary_naive['hidden_1']
fig, ax1, ax2 = prepare_standardplot(title, 'epoch')
ax1.plot(history_reg.history['loss'][:250], label = "train reg")
ax1.plot(history_reg.history['val_loss'][:250], label = "val reg")
ax1.plot(history_naive.history['loss'], label = "train naive")
ax1.plot(history_naive.history['val_loss'], label = "val naive")


ax2.plot(history_reg.history['acc'][:250], label = "train reg.")
ax2.plot(history_reg.history['val_acc'][:250], label = "vali reg.")
ax2.plot(history_naive.history['acc'], label = "train naive")
ax2.plot(history_naive.history['val_acc'], label = "val naive")
finalize_standardplot(fig, ax1, ax2)
plt.show()

title='Loss Curve and Accuracy of Regularised model vs Naive model (4 hidden layers)'
history_reg=summary_reg['hidden_4']
history_naive=summary_naive['hidden_4']
fig, ax1, ax2 = prepare_standardplot(title, 'epoch')
ax1.plot(history_reg.history['loss'][:250], label = "train reg")
ax1.plot(history_reg.history['val_loss'][:250], label = "val reg")
ax1.plot(history_naive.history['loss'], label = "train naive")
ax1.plot(history_naive.history['val_loss'], label = "val naive")


ax2.plot(history_reg.history['acc'][:250], label = "train reg.")
ax2.plot(history_reg.history['val_acc'][:250], label = "val reg.")
ax2.plot(history_naive.history['acc'], label = "train naive")
ax2.plot(history_naive.history['val_acc'], label = "val naive")
finalize_standardplot(fig, ax1, ax2)

plt.show()

# %%
######################################################
#Plots of the Regularised model only
#######################################################
title='Learning Curve and Accuracy of Regularised (1 Hidden layer)'
history_reg=summary_reg['hidden_1']
history_naive=summary_naive['hidden_1']
fig, ax1, ax2 = prepare_standardplot(title, 'epoch')
ax1.plot(history_reg.history['loss'][:250], label = "train reg")
ax1.plot(history_reg.history['val_loss'][:250], label = "val reg")


ax2.plot(history_reg.history['acc'][:250], label = "train reg.")
ax2.plot(history_reg.history['val_acc'][:250], label = "vali reg.")
finalize_standardplot(fig, ax1, ax2)
plt.show()

title='Learning Curve and Accuracy of Regularised model (4 hidden layers)'
history_reg=summary_reg['hidden_4']
history_naive=summary_naive['hidden_4']
fig, ax1, ax2 = prepare_standardplot(title, 'epoch')
ax1.plot(history_reg.history['loss'][:250], label = "train reg")
ax1.plot(history_reg.history['val_loss'][:250], label = "val reg")


ax2.plot(history_reg.history['acc'][:250], label = "train reg.")
ax2.plot(history_reg.history['val_acc'][:250], label = "val reg.")
finalize_standardplot(fig, ax1, ax2)

plt.show()

# %% [markdown]
# ## Exercise 7: Convolutional networks
#
# ### Description
#
# Convolutional neural networks have an inductive bias that is well adapted to image classification.
#
# 1. Design a convolutional neural network, play with the parameters and fit it. Hint: You may get valuable inspiration from the keras [examples](https://github.com/keras-team/keras/tree/master/examples), e.g. [mnist_cnn](https://github.com/keras-team/keras/blob/master/examples/mnist_cnn.py).
# 2. Plot the learning curves of the convolutional neural network together with the so far best performing model.
#
# ## Solution

# %%
############################################################################
# Run simple shallow model with a sequene of convolutional and pooling layers
###############################################################################
epochs = 250

img_rows, img_cols = 16, 16

x_train_ = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
x_test_ = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
input_shape = (img_rows, img_cols, 1)

x_train_ = x_train_.astype('float32')
x_test_  = x_test_.astype('float32')

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

l2_decay=1e-4
l1_decay=1e-3
lr_adam =1e-3

w_reg = regularizers.l2(l2_decay)
b_reg = regularizers.l1(l1_decay)
summary_conv={}

###########################
# Simple shallow model 
#############################
def conv_model():
    Inp = Input(shape=input_shape)
    y = Conv2D(32, kernel_size=(3, 3), activation='relu', kernel_regularizer=w_reg, bias_regularizer=b_reg)(Inp)
    y = BatchNormalization()(y)
    y = Conv2D(64, (3, 3), activation='relu', kernel_regularizer=w_reg, bias_regularizer=b_reg)(y)
    y = BatchNormalization()(y)
    y = MaxPooling2D(pool_size=(2, 2))(y)
    y = Conv2D(64, (3, 3), activation='relu', kernel_regularizer=w_reg, bias_regularizer=b_reg)(y)
    y = BatchNormalization()(y)
    y = MaxPooling2D(pool_size=(2, 2))(y)
    y = Dropout(0.25)(y)
    y = Flatten()(y)
    y = Dense(128, activation='relu',kernel_regularizer=w_reg, bias_regularizer=b_reg)(y)
    y = Dropout(0.5)(y)
    y = Dense(5, activation='softmax',kernel_regularizer=w_reg, bias_regularizer=b_reg)(y)
    model = Model(Inp,y)
    return model

model=conv_model()
model.summary()

callbacks= keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.001, patience=5, verbose=0, mode='auto')
saveBestModel = keras.callbacks.ModelCheckpoint("./best_weights.hdf5", monitor='val_acc', verbose=0, save_best_only=True, mode='auto',save_weights_only=True)
model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.adam(lr=lr_adam, decay=1e-5), metrics=['accuracy'])
history = model.fit(x_train_, y_train, batch_size = 128,callbacks=[saveBestModel], epochs=epochs, verbose=0, validation_data=(x_test_, y_test))

summary_conv['shallow_conv_model'] =history
model.load_weights("./best_weights.hdf5")
score = model.evaluate(x_train_, y_train, verbose=0)
print("Train Loss: {} , Train Accuracy: {}".format(score[0], score[1]))
score = model.evaluate(x_test_, y_test, verbose=0)
print("Test loss: {} , Test accuracy: {}".format(score[0],score[1]))
# Out:
# ('x_train shape:', (43226, 256))
# (43226, 'train samples')
# (15767, 'test samples')
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_31 (InputLayer)        (None, 16, 16, 1)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 32)        320
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 14, 14, 32)        128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 4, 4, 64)          256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_97 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_98 (Dense)             (None, 5)                 645
# =================================================================
# Total params: 89,925
# Trainable params: 89,605
# Non-trainable params: 320
# _________________________________________________________________
# Train Loss: 0.0655565871607 , Train Accuracy: 0.995234349697
# Test loss: 0.242892597456 , Test accuracy: 0.957633031014

# %%
###################################
#Part 2- plots of CNN vs deep models
####################################

title='Learning Curve and Accuracy of CNN vs Non-CNN'
history=summary_conv['shallow_conv_model'] 
history_old_best= summary_naive['hidden_4']
fig, ax1, ax2 = prepare_standardplot(title, 'epoch')
ax1.plot(history.history['loss'], label = "train CNN")
ax1.plot(history.history['val_loss'], label = "val CNN")
ax1.plot(history_old_best.history['loss'][:250], label = "train FC")
ax1.plot(history_old_best.history['val_loss'][:250], label = "val FC")


ax2.plot(history.history['acc'], label = "train CNN")
ax2.plot(history.history['val_acc'], label = "val CNN")
ax2.plot(history_old_best.history['acc'][:250], label = "train FC")
ax2.plot(history_old_best.history['val_acc'][:250], label = "val FC")

finalize_standardplot(fig, ax1, ax2)
plt.show()
